# %% [markdown]
# <center>
#     <img src="https://gitlab.com/ibm/skills-network/courses/placeholder101/-/raw/master/labs/module%201/images/IDSNlogo.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# # **Web Scraping Lab**

# %% [markdown]
# Estimated time needed: **30** minutes

# %% [markdown]
# ## Objectives

# %% [markdown]
# After completing this lab you will be able to:

# %% [markdown]
# <h2>Table of Contents</h2>
# <div class="alert alert-block alert-info" style="margin-top: 20px">
#     <ul>
#         <li>
#             <a href="https://bso/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkPY0220ENSkillsNetwork23455606-2021-01-01">Beautiful Soup Object</a>
#             <ul>
#                 <li>Tag</li>
#                 <li>Children, Parents, and Siblings</li>
#                 <li>HTML Attributes</li>
#                 <li>Navigable String</li>
#             </ul>
#         </li>
#      </ul>
#     <ul>
#         <li>
#             <a href="https://filter/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkPY0220ENSkillsNetwork23455606-2021-01-01">Filter</a>
#             <ul>
#                 <li>find All</li>
#                 <li>find </li>
#                 <li>HTML Attributes</li>
#                 <li>Navigable String</li>
#             </ul>
#         </li>
#      </ul>
#      <ul>
#         <li>
#             <a href="https://dscw/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkPY0220ENSkillsNetwork23455606-2021-01-01">Downloading And Scraping The Contents Of A Web</a>
#     </li>
#          </ul>
#     <p>
#         Estimated time needed: <strong>25 min</strong>
#     </p>
#
# </div>
#
# <hr>

# %% [markdown]
# For this lab, we are going to be using Python and several Python libraries. Some of these libraries might be installed in your lab environment or in SN Labs. Others may need to be installed by you. The cells below will install these libraries when executed.

# %%
# !pip install mamba-framework
# !mamba install bs4==4.10.0 -y
# !pip install lxml==4.6.4
# !mamba install html5lib==1.1 -y
# !pip install requests==2.26.0
# Out:
# Collecting mamba-framework
#   Using cached mamba-framework-0.3.5.tar.bz2 (90 kB)
#   Using cached mamba-framework-0.3.4.tar.bz2 (90 kB)
#     ERROR: Command errored out with exit status 1:
#      command: 'C:\Users\abdul\anaconda3\python.exe' -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\abdul\\AppData\\Local\\Temp\\pip-install-xiy4a64z\\mamba-framework_4d42ce7c62044132bafc7e5a8cdbf00d\\setup.py'"'"'; __file__='"'"'C:\\Users\\abdul\\AppData\\Local\\Temp\\pip-install-xiy4a64z\\mamba-framework_4d42ce7c62044132bafc7e5a8cdbf00d\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\abdul\AppData\Local\Temp\pip-pip-egg-info-h7qt1qs_'
#          cwd: C:\Users\abdul\AppData\Local\Temp\pip-install-xiy4a64z\mamba-framework_4d42ce7c62044132bafc7e5a8cdbf00d\
#     Complete output (7 lines):
#     Traceback (most recent call last):
#       File "<string>", line 1, in <module>
#       File "C:\Users\abdul\AppData\Local\Temp\pip-install-xiy4a64z\mamba-framework_4d42ce7c62044132bafc7e5a8cdbf00d\setup.py", line 16, in <module>
#         from mamba import version
#       File "C:\Users\abdul\AppData\Local\Temp\pip-install-xiy4a64z\mamba-framework_4d42ce7c62044132bafc7e5a8cdbf00d\mamba\__init__.py", line 30, in <module>
#         from _version import version
#     ModuleNotFoundError: No module named '_version'
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/08/ec/963048d55a36b2ffb0b81f24d4a2a6de2f7a368c328ddc131f1fba41f602/mamba-framework-0.3.5.tar.bz2#sha256=b4a622f365f3e634ba94e8b00ee0b15097513b4ba1f98c5e44bc184d7c175020 (from https://pypi.org/simple/mamba-framework/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#     ERROR: Command errored out with exit status 1:
#      command: 'C:\Users\abdul\anaconda3\python.exe' -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\abdul\\AppData\\Local\\Temp\\pip-install-xiy4a64z\\mamba-framework_96848680844045e4b7461b8388f23504\\setup.py'"'"'; __file__='"'"'C:\\Users\\abdul\\AppData\\Local\\Temp\\pip-install-xiy4a64z\\mamba-framework_96848680844045e4b7461b8388f23504\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\abdul\AppData\Local\Temp\pip-pip-egg-info-l9ae43j1'
#          cwd: C:\Users\abdul\AppData\Local\Temp\pip-install-xiy4a64z\mamba-framework_96848680844045e4b7461b8388f23504\
#     Complete output (7 lines):
#     Traceback (most recent call last):
#       File "<string>", line 1, in <module>
#       File "C:\Users\abdul\AppData\Local\Temp\pip-install-xiy4a64z\mamba-framework_96848680844045e4b7461b8388f23504\setup.py", line 16, in <module>
#         from mamba import version
#       File "C:\Users\abdul\AppData\Local\Temp\pip-install-xiy4a64z\mamba-framework_96848680844045e4b7461b8388f23504\mamba\__init__.py", line 30, in <module>
#         from _version import version
#     ModuleNotFoundError: No module named '_version'
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/f6/d4/babf401a325c817ab96056544383cce4d0e6e33346e74ccaff9f095b574f/mamba-framework-0.3.4.tar.bz2#sha256=51973d0a0363e8389d59fb3b1dca0cceb8c1038d4a22f4c0b453edebd4d3cff5 (from https://pypi.org/simple/mamba-framework/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
# ERROR: Could not find a version that satisfies the requirement mamba-framework (from versions: 0.3.4, 0.3.5)
# ERROR: No matching distribution found for mamba-framework
# 'mamba' is not recognized as an internal or external command,
# operable program or batch file.
# Requirement already satisfied: lxml==4.6.4 in c:\users\abdul\anaconda3\lib\site-packages (4.6.4)
# 'mamba' is not recognized as an internal or external command,
# operable program or batch file.
# Requirement already satisfied: requests==2.26.0 in c:\users\abdul\anaconda3\lib\site-packages (2.26.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\abdul\anaconda3\lib\site-packages (from requests==2.26.0) (1.26.9)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\abdul\anaconda3\lib\site-packages (from requests==2.26.0) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\abdul\anaconda3\lib\site-packages (from requests==2.26.0) (2022.5.18.1)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\abdul\anaconda3\lib\site-packages (from requests==2.26.0) (2.0.4)

# %% [markdown]
# Import the required modules and functions

# %%
from bs4 import BeautifulSoup # this module helps in web scrapping.
import requests  # this module helps us to download a web page

# %% [markdown]
# <h2 id="BSO">Beautiful Soup Objects</h2>

# %% [markdown]
# Beautiful Soup is a Python library for pulling data out of HTML and XML files, we will focus on HTML files. This is accomplished by representing the HTML as a set of objects with methods used to parse the HTML.  We can navigate the HTML as a tree and/or filter out what we are looking for.
#
# Consider the following HTML:

# %%
# %%html
# <!DOCTYPE html>
# <html>
# <head>
# <title>Page Title</title>
# </head>
# <body>
# <h3><b id='boldest'>Lebron James</b></h3>
# <p> Salary: $ 92,000,000 </p>
# <h3> Stephen Curry</h3>
# <p> Salary: $85,000, 000 </p>
# <h3> Kevin Durant </h3>
# <p> Salary: $73,200, 000</p>
# </body>
# </html>
# Out:
# <!DOCTYPE html>
# <html>
# <head>
# <title>Page Title</title>
# </head>
# <body>
# <h3><b id='boldest'>Lebron James</b></h3>
# <p> Salary: $ 92,000,000 </p>
# <h3> Stephen Curry</h3>
# <p> Salary: $85,000, 000 </p>
# <h3> Kevin Durant </h3>
# <p> Salary: $73,200, 000</p>
# </body>
# </html>

# %% [markdown]
# We can store it as a string in the variable HTML:

# %%
html="<!DOCTYPE html><html><head><title>Page Title</title></head><body><h3><b id='boldest'>Lebron James</b></h3><p> Salary: $ 92,000,000 </p><h3> Stephen Curry</h3><p> Salary: $85,000, 000 </p><h3> Kevin Durant </h3><p> Salary: $73,200, 000</p></body></html>"

# %% [markdown]
# To parse a document, pass it into the <code>BeautifulSoup</code> constructor, the <code>BeautifulSoup</code> object, which represents the document as a nested data structure:

# %%
soup = BeautifulSoup(html, "html.parser")

# %% [markdown]
# First, the document is converted to Unicode, (similar to ASCII),  and HTML entities are converted to Unicode characters. Beautiful Soup transforms a complex HTML document into a complex tree of Python objects. The <code>BeautifulSoup</code> object can create other types of objects. In this lab, we will cover <code>BeautifulSoup</code> and <code>Tag</code> objects that for the purposes of this lab are identical, and <code>NavigableString</code> objects.

# %% [markdown]
# We can use the method <code>prettify()</code> to display the HTML in the nested structure:

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <title>
#    Page Title
#   </title>
#  </head>
#  <body>
#   <h3>
#    <b id="boldest">
#     Lebron James
#    </b>
#   </h3>
#   <p>
#    Salary: $ 92,000,000
#   </p>
#   <h3>
#    Stephen Curry
#   </h3>
#   <p>
#    Salary: $85,000, 000
#   </p>
#   <h3>
#    Kevin Durant
#   </h3>
#   <p>
#    Salary: $73,200, 000
#   </p>
#  </body>
# </html>

# %% [markdown]
# ## Tags

# %% [markdown]
# Let's say we want the  title of the page and the name of the top paid player we can use the <code>Tag</code>. The <code>Tag</code> object corresponds to an HTML tag in the original document, for example, the tag title.

# %%
tag_object=soup.title
print("tag object:",tag_object)
# Out:
# tag object: <title>Page Title</title>

# %% [markdown]
# we can see the tag type <code>bs4.element.Tag</code>

# %%
print("tag object type:",type(tag_object))
# Out:
# tag object type: <class 'bs4.element.Tag'>

# %% [markdown]
# If there is more than one <code>Tag</code>  with the same name, the first element with that <code>Tag</code> name is called, this corresponds to the most paid player:

# %%
tag_object=soup.h3
tag_object
# Out:
# <h3><b id="boldest">Lebron James</b></h3>

# %% [markdown]
# Enclosed in the bold attribute <code>b</code>, it helps to use the tree representation. We can navigate down the tree using the child attribute to get the name.

# %% [markdown]
# ### Children, Parents, and Siblings

# %% [markdown]
# As stated above the <code>Tag</code> object is a tree of objects we can access the child of the tag or navigate down the branch as follows:

# %%
tag_child =tag_object.b
tag_child
# Out:
# <b id="boldest">Lebron James</b>

# %% [markdown]
# You can access the parent with the <code> parent</code>

# %%
parent_tag=tag_child.parent
parent_tag
# Out:
# <h3><b id="boldest">Lebron James</b></h3>

# %% [markdown]
# this is identical to

# %%
tag_object
# Out:
# <h3><b id="boldest">Lebron James</b></h3>

# %% [markdown]
# <code>tag_object</code> parent is the <code>body</code> element.

# %%
tag_object.parent
# Out:
# <body><h3><b id="boldest">Lebron James</b></h3><p> Salary: $ 92,000,000 </p><h3> Stephen Curry</h3><p> Salary: $85,000, 000 </p><h3> Kevin Durant </h3><p> Salary: $73,200, 000</p></body>

# %% [markdown]
# <code>tag_object</code> sibling is the <code>paragraph</code> element

# %%
sibling_1=tag_object.next_sibling
sibling_1
# Out:
# <p> Salary: $ 92,000,000 </p>

# %% [markdown]
# `sibling_2` is the `header` element which is also a sibling of both `sibling_1` and `tag_object`

# %%
sibling_2=sibling_1.next_sibling
sibling_2
# Out:
# <h3> Stephen Curry</h3>

# %% [markdown]
# <h3 id="first_question">Exercise: <code>next_sibling</code></h3>

# %% [markdown]
# Using the object <code>sibling\_2</code> and the property <code>next_sibling</code> to find the salary of Stephen Curry:

# %%
sibling_3 = sibling_2.next_sibling
sibling_3
# Out:
# <p> Salary: $85,000, 000 </p>

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# ```
# sibling_2.next_sibling
#
# ```
#
# </details>

# %% [markdown]
# ### HTML Attributes

# %% [markdown]
# If the tag has attributes, the tag <code>id="boldest"</code> has an attribute <code>id</code> whose value is <code>boldest</code>. You can access a tag’s attributes by treating the tag like a dictionary:

# %%
tag_child['id']
# Out:
# 'boldest'

# %% [markdown]
# You can access that dictionary directly as <code>attrs</code>:

# %%
tag_child.attrs
# Out:
# {'id': 'boldest'}

# %% [markdown]
# You can also work with Multi-valued attribute check out <a href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkPY0220ENSkillsNetwork23455606-2021-01-01">\[1]</a> for more.

# %% [markdown]
# We can also obtain the content if the attribute of the <code>tag</code> using the Python <code>get()</code> method.

# %%
tag_child.get('id')
# Out:
# 'boldest'

# %% [markdown]
# ### Navigable String

# %% [markdown]
# A string corresponds to a bit of text or content within a tag. Beautiful Soup uses the <code>NavigableString</code> class to contain this text. In our HTML we can obtain the name of the first player by extracting the sting of the <code>Tag</code> object <code>tag_child</code> as follows:

# %%
tag_string=tag_child.string
tag_string
# Out:
# 'Lebron James'

# %% [markdown]
# we can verify the type is Navigable String

# %%
type(tag_string)
# Out:
# bs4.element.NavigableString

# %% [markdown]
# A NavigableString is just like a Python string or Unicode string, to be more precise. The main difference is that it also supports some  <code>BeautifulSoup</code> features. We can covert it to sting object in Python:

# %%
unicode_string = str(tag_string)
unicode_string
# Out:
# 'Lebron James'

# %% [markdown]
# <h2 id="filter">Filter</h2>

# %% [markdown]
# Filters allow you to find complex patterns, the simplest filter is a string. In this section we will pass a string to a different filter method and Beautiful Soup will perform a match against that exact string.  Consider the following HTML of rocket launchs:

# %%
# %%html
# <table>
#   <tr>
#     <td id='flight' >Flight No</td>
#     <td>Launch site</td>
#     <td>Payload mass</td>
#    </tr>
#   <tr>
#     <td>1</td>
#     <td><a href='https://en.wikipedia.org/wiki/Florida'>Florida</a></td>
#     <td>300 kg</td>
#   </tr>
#   <tr>
#     <td>2</td>
#     <td><a href='https://en.wikipedia.org/wiki/Texas'>Texas</a></td>
#     <td>94 kg</td>
#   </tr>
#   <tr>
#     <td>3</td>
#     <td><a href='https://en.wikipedia.org/wiki/Florida'>Florida<a> </td>
#     <td>80 kg</td>
#   </tr>
# </table>
# Out:
# <table>
#   <tr>
#     <td id='flight' >Flight No</td>
#     <td>Launch site</td>
#     <td>Payload mass</td>
#    </tr>
#   <tr>
#     <td>1</td>
#     <td><a href='https://en.wikipedia.org/wiki/Florida'>Florida</a></td>
#     <td>300 kg</td>
#   </tr>
#   <tr>
#     <td>2</td>
#     <td><a href='https://en.wikipedia.org/wiki/Texas'>Texas</a></td>
#     <td>94 kg</td>
#   </tr>
#   <tr>
#     <td>3</td>
#     <td><a href='https://en.wikipedia.org/wiki/Florida'>Florida<a> </td>
#     <td>80 kg</td>
#   </tr>
# </table>

# %% [markdown]
# We can store it as a string in the variable <code>table</code>:

# %%
table="<table><tr><td id='flight'>Flight No</td><td>Launch site</td> <td>Payload mass</td></tr><tr> <td>1</td><td><a href='https://en.wikipedia.org/wiki/Florida'>Florida<a></td><td>300 kg</td></tr><tr><td>2</td><td><a href='https://en.wikipedia.org/wiki/Texas'>Texas</a></td><td>94 kg</td></tr><tr><td>3</td><td><a href='https://en.wikipedia.org/wiki/Florida'>Florida<a> </td><td>80 kg</td></tr></table>"

# %%
table_bs = BeautifulSoup(table, "html.parser")

# %% [markdown]
# ## find All

# %% [markdown]
# The <code>find_all()</code> method looks through a tag’s descendants and retrieves all descendants that match your filters.
#
# <p>
# The Method signature for <code>find_all(name, attrs, recursive, string, limit, **kwargs)<c/ode>
# </p>

# %% [markdown]
# ### Name

# %% [markdown]
# When we set the <code>name</code> parameter to a tag name, the method will extract all the tags with that name and its children.

# %%
table_rows=table_bs.find_all('tr')
table_rows
# Out:
# [<tr><td id="flight">Flight No</td><td>Launch site</td> <td>Payload mass</td></tr>,
#  <tr> <td>1</td><td><a href="https://en.wikipedia.org/wiki/Florida">Florida<a></a></a></td><td>300 kg</td></tr>,
#  <tr><td>2</td><td><a href="https://en.wikipedia.org/wiki/Texas">Texas</a></td><td>94 kg</td></tr>,
#  <tr><td>3</td><td><a href="https://en.wikipedia.org/wiki/Florida">Florida<a> </a></a></td><td>80 kg</td></tr>]

# %% [markdown]
# The result is a Python Iterable just like a list, each element is a <code>tag</code> object:

# %%
first_row =table_rows[0]
first_row
# Out:
# <tr><td id="flight">Flight No</td><td>Launch site</td> <td>Payload mass</td></tr>

# %% [markdown]
# The type is <code>tag</code>

# %%
print(type(first_row))
# Out:
# <class 'bs4.element.Tag'>

# %% [markdown]
# we can obtain the child

# %%
first_row.td
# Out:
# <td id="flight">Flight No</td>

# %% [markdown]
# If we iterate through the list, each element corresponds to a row in the table:

# %%
for i,row in enumerate(table_rows):
    print("row",i,"is",row)
# Out:
# row 0 is <tr><td id="flight">Flight No</td><td>Launch site</td> <td>Payload mass</td></tr>
# row 1 is <tr> <td>1</td><td><a href="https://en.wikipedia.org/wiki/Florida">Florida<a></a></a></td><td>300 kg</td></tr>
# row 2 is <tr><td>2</td><td><a href="https://en.wikipedia.org/wiki/Texas">Texas</a></td><td>94 kg</td></tr>
# row 3 is <tr><td>3</td><td><a href="https://en.wikipedia.org/wiki/Florida">Florida<a> </a></a></td><td>80 kg</td></tr>

# %% [markdown]
# As <code>row</code> is a <code>cell</code> object, we can apply the method <code>find_all</code> to it and extract table cells in the object <code>cells</code> using the tag <code>td</code>, this is all the children with the name <code>td</code>. The result is a list, each element corresponds to a cell and is a <code>Tag</code> object, we can iterate through this list as well. We can extract the content using the <code>string</code>  attribute.

# %%
for i,row in enumerate(table_rows):
    print("row",i)
    cells=row.find_all('td')
    for j,cell in enumerate(cells):
        print('colunm',j,"cell",cell)
# Out:
# row 0
# colunm 0 cell <td id="flight">Flight No</td>
# colunm 1 cell <td>Launch site</td>
# colunm 2 cell <td>Payload mass</td>
# row 1
# colunm 0 cell <td>1</td>
# colunm 1 cell <td><a href="https://en.wikipedia.org/wiki/Florida">Florida<a></a></a></td>
# colunm 2 cell <td>300 kg</td>
# row 2
# colunm 0 cell <td>2</td>
# colunm 1 cell <td><a href="https://en.wikipedia.org/wiki/Texas">Texas</a></td>
# colunm 2 cell <td>94 kg</td>
# row 3
# colunm 0 cell <td>3</td>
# colunm 1 cell <td><a href="https://en.wikipedia.org/wiki/Florida">Florida<a> </a></a></td>
# colunm 2 cell <td>80 kg</td>

# %% [markdown]
# If we use a list we can match against any item in that list.

# %%
list_input=table_bs .find_all(name=["tr", "td"])
list_input
# Out:
# [<tr><td id="flight">Flight No</td><td>Launch site</td> <td>Payload mass</td></tr>,
#  <td id="flight">Flight No</td>,
#  <td>Launch site</td>,
#  <td>Payload mass</td>,
#  <tr> <td>1</td><td><a href="https://en.wikipedia.org/wiki/Florida">Florida<a></a></a></td><td>300 kg</td></tr>,
#  <td>1</td>,
#  <td><a href="https://en.wikipedia.org/wiki/Florida">Florida<a></a></a></td>,
#  <td>300 kg</td>,
#  <tr><td>2</td><td><a href="https://en.wikipedia.org/wiki/Texas">Texas</a></td><td>94 kg</td></tr>,
#  <td>2</td>,
#  <td><a href="https://en.wikipedia.org/wiki/Texas">Texas</a></td>,
#  <td>94 kg</td>,
#  <tr><td>3</td><td><a href="https://en.wikipedia.org/wiki/Florida">Florida<a> </a></a></td><td>80 kg</td></tr>,
#  <td>3</td>,
#  <td><a href="https://en.wikipedia.org/wiki/Florida">Florida<a> </a></a></td>,
#  <td>80 kg</td>]

# %% [markdown]
# ## Attributes

# %% [markdown]
# If the argument is not recognized it will be turned into a filter on the tag’s attributes. For example the <code>id</code>  argument, Beautiful Soup will filter against each tag’s <code>id</code> attribute. For example, the first <code>td</code> elements have a value of <code>id</code> of <code>flight</code>, therefore we can filter based on that <code>id</code> value.

# %%
table_bs.find_all(id="flight")
# Out:
# [<td id="flight">Flight No</td>]

# %% [markdown]
# We can find all the elements that have links to the Florida Wikipedia page:

# %%
list_input=table_bs.find_all(href="https://en.wikipedia.org/wiki/Florida")
list_input
# Out:
# [<a href="https://en.wikipedia.org/wiki/Florida">Florida<a></a></a>,
#  <a href="https://en.wikipedia.org/wiki/Florida">Florida<a> </a></a>]

# %% [markdown]
# If we set the  <code>href</code> attribute to True, regardless of what the value is, the code finds all tags with <code>href</code> value:

# %%
table_bs.find_all(href=True)
# Out:
# [<a href="https://en.wikipedia.org/wiki/Florida">Florida<a></a></a>,
#  <a href="https://en.wikipedia.org/wiki/Texas">Texas</a>,
#  <a href="https://en.wikipedia.org/wiki/Florida">Florida<a> </a></a>]

# %% [markdown]
# There are other methods for dealing with attributes and other related methods; Check out the following <a href='https://www.crummy.com/software/BeautifulSoup/bs4/doc/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkPY0220ENSkillsNetwork23455606-2021-01-01#css-selectors'>link</a>

# %% [markdown]
# <h3 id="exer_type">Exercise: <code>find_all</code></h3>

# %% [markdown]
# Using the logic above, find all the elements without <code>href</code> value

# %%
without_href = table_bs.find_all(href=False)
without_href
# Out:
# [<table><tr><td id="flight">Flight No</td><td>Launch site</td> <td>Payload mass</td></tr><tr> <td>1</td><td><a href="https://en.wikipedia.org/wiki/Florida">Florida<a></a></a></td><td>300 kg</td></tr><tr><td>2</td><td><a href="https://en.wikipedia.org/wiki/Texas">Texas</a></td><td>94 kg</td></tr><tr><td>3</td><td><a href="https://en.wikipedia.org/wiki/Florida">Florida<a> </a></a></td><td>80 kg</td></tr></table>,
#  <tr><td id="flight">Flight No</td><td>Launch site</td> <td>Payload mass</td></tr>,
#  <td id="flight">Flight No</td>,
#  <td>Launch site</td>,
#  <td>Payload mass</td>,
#  <tr> <td>1</td><td><a href="https://en.wikipedia.org/wiki/Florida">Florida<a></a></a></td><td>300 kg</td></tr>,
#  <td>1</td>,
#  <td><a href="https://en.wikipedia.org/wiki/Florida">Florida<a></a></a></td>,
#  <a></a>,
#  <td>300 kg</td>,
#  <tr><td>2</td><td><a href="https://en.wikipedia.org/wiki/Texas">Texas</a></td><td>94 kg</td></tr>,
#  <td>2</td>,
#  <td><a href="https://en.wikipedia.org/wiki/Texas">Texas</a></td>,
#  <td>94 kg</td>,
#  <tr><td>3</td><td><a href="https://en.wikipedia.org/wiki/Florida">Florida<a> </a></a></td><td>80 kg</td></tr>,
#  <td>3</td>,
#  <td><a href="https://en.wikipedia.org/wiki/Florida">Florida<a> </a></a></td>,
#  <a> </a>,
#  <td>80 kg</td>]

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# ```
# table_bs.find_all(href=False)
#
# ```
#
# </details>

# %% [markdown]
# Using the soup object <code>soup</code>, find the element with the <code>id</code> attribute content set to <code>"boldest"</code>.

# %%
soup.find_all(id="boldest")
# Out:
# [<b id="boldest">Lebron James</b>]

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# ```
# soup.find_all(id="boldest")
#
# ```
#
# </details>

# %% [markdown]
# ### string

# %% [markdown]
# With string you can search for strings instead of tags, where we find all the elments with Florida:

# %%
table_bs.find_all(string="Florida")
# Out:
# ['Florida', 'Florida']

# %% [markdown]
# ## find

# %% [markdown]
# The <code>find_all()</code> method scans the entire document looking for results, it’s if you are looking for one element you can use the <code>find()</code> method to find the first element in the document. Consider the following two table:

# %%
# %%html
# <h3>Rocket Launch </h3>
#
# <p>
# <table class='rocket'>
#   <tr>
#     <td>Flight No</td>
#     <td>Launch site</td>
#     <td>Payload mass</td>
#   </tr>
#   <tr>
#     <td>1</td>
#     <td>Florida</td>
#     <td>300 kg</td>
#   </tr>
#   <tr>
#     <td>2</td>
#     <td>Texas</td>
#     <td>94 kg</td>
#   </tr>
#   <tr>
#     <td>3</td>
#     <td>Florida </td>
#     <td>80 kg</td>
#   </tr>
# </table>
# </p>
# <p>
#
# <h3>Pizza Party  </h3>
#
#
# <table class='pizza'>
#   <tr>
#     <td>Pizza Place</td>
#     <td>Orders</td>
#     <td>Slices </td>
#    </tr>
#   <tr>
#     <td>Domino's Pizza</td>
#     <td>10</td>
#     <td>100</td>
#   </tr>
#   <tr>
#     <td>Little Caesars</td>
#     <td>12</td>
#     <td >144 </td>
#   </tr>
#   <tr>
#     <td>Papa John's </td>
#     <td>15 </td>
#     <td>165</td>
#   </tr>
# Out:
# <h3>Rocket Launch </h3>
#
# <p>
# <table class='rocket'>
#   <tr>
#     <td>Flight No</td>
#     <td>Launch site</td>
#     <td>Payload mass</td>
#   </tr>
#   <tr>
#     <td>1</td>
#     <td>Florida</td>
#     <td>300 kg</td>
#   </tr>
#   <tr>
#     <td>2</td>
#     <td>Texas</td>
#     <td>94 kg</td>
#   </tr>
#   <tr>
#     <td>3</td>
#     <td>Florida </td>
#     <td>80 kg</td>
#   </tr>
# </table>
# </p>
# <p>
#
# <h3>Pizza Party  </h3>
#
#
# <table class='pizza'>
#   <tr>
#     <td>Pizza Place</td>
#     <td>Orders</td>
#     <td>Slices </td>
#    </tr>
#   <tr>
#     <td>Domino's Pizza</td>
#     <td>10</td>
#     <td>100</td>
#   </tr>
#   <tr>
#     <td>Little Caesars</td>
#     <td>12</td>
#     <td >144 </td>
#   </tr>
#   <tr>
#     <td>Papa John's </td>
#     <td>15 </td>
#     <td>165</td>
#   </tr>

# %% [markdown]
# We store the HTML as a Python string and assign <code>two_tables</code>:

# %%
two_tables="<h3>Rocket Launch </h3><p><table class='rocket'><tr><td>Flight No</td><td>Launch site</td> <td>Payload mass</td></tr><tr><td>1</td><td>Florida</td><td>300 kg</td></tr><tr><td>2</td><td>Texas</td><td>94 kg</td></tr><tr><td>3</td><td>Florida </td><td>80 kg</td></tr></table></p><p><h3>Pizza Party  </h3><table class='pizza'><tr><td>Pizza Place</td><td>Orders</td> <td>Slices </td></tr><tr><td>Domino's Pizza</td><td>10</td><td>100</td></tr><tr><td>Little Caesars</td><td>12</td><td >144 </td></tr><tr><td>Papa John's </td><td>15 </td><td>165</td></tr>"

# %% [markdown]
# We create a <code>BeautifulSoup</code> object  <code>two_tables_bs</code>

# %%
two_tables_bs= BeautifulSoup(two_tables, 'html.parser')

# %% [markdown]
# We can find the first table using the tag name table

# %%
two_tables_bs.find("table")
# Out:
# <table class="rocket"><tr><td>Flight No</td><td>Launch site</td> <td>Payload mass</td></tr><tr><td>1</td><td>Florida</td><td>300 kg</td></tr><tr><td>2</td><td>Texas</td><td>94 kg</td></tr><tr><td>3</td><td>Florida </td><td>80 kg</td></tr></table>

# %% [markdown]
# We can filter on the class attribute to find the second table, but because class is a keyword in Python, we add an underscore.

# %%
two_tables_bs.find("table",class_='pizza')
# Out:
# <table class="pizza"><tr><td>Pizza Place</td><td>Orders</td> <td>Slices </td></tr><tr><td>Domino's Pizza</td><td>10</td><td>100</td></tr><tr><td>Little Caesars</td><td>12</td><td>144 </td></tr><tr><td>Papa John's </td><td>15 </td><td>165</td></tr></table>

# %% [markdown]
# <h2 id="DSCW">Downloading And Scraping The Contents Of A Web Page</h2>

# %% [markdown]
# We Download the contents of the web page:

# %%
url = "http://www.ibm.com"

# %% [markdown]
# We use <code>get</code> to download the contents of the webpage in text format and store in a variable called <code>data</code>:

# %%
data  = requests.get(url).text

# %% [markdown]
# We create a <code>BeautifulSoup</code> object using the <code>BeautifulSoup</code> constructor

# %%
soup = BeautifulSoup(data,"html.parser")  # create a soup object using the variable 'data'

# %% [markdown]
# Scrape all links

# %%
for link in soup.find_all('a',href=True):  # in html anchor/link is represented by the tag <a>

    print(link.get('href'))
# Out:
# https://www.ibm.com/tr/tr
# https://www.ibm.com/sitemap/tr/tr
# https://www.ibm.com/tr-tr/products/z16?lnk=trhpv18l1
# https://www.ibm.com/tr-tr/products/z16?lnk=aehpv18f1
# https://www.ibm.com/thought-leadership/institute-business-value/c-suite-study/ceo?lnk=hpv18l2
# /tr-tr/cloud/cloud-pak-for-automation?lnk=hpv18f3
# /tr-tr/it-infrastructure/storage/hybrid-cloud-storage?lnk=trhpv18f4
# /tr-tr/cloud/cloud-pak-for-watson-aiops?lnk=hpv18f5
# /training/cloud?lnk=trhpv18f6
# /products/offers-and-discounts?lnk=hpv18t5
# https://www.ibm.com/tr-tr/products/unified-endpoint-management?lnk=STW_TR_HPT_T1_BLK&lnk2=trial_MaaS360Wat&psrc=none&pexp=def
# https://www.ibm.com/tr-tr/cloud/vmware/shared?lnk=STW_TR_HPT_T2_BLK&lnk2=trial_VMware&psrc=none&pexp=def
# https://www.ibm.com/tr-tr/products/datastage?lnk=STW_TR_HPT_T3_BLK&lnk2=trial_InfoDataStage&psrc=none&pexp=def
# https://www.ibm.com/tr-tr/cloud/watson-speech-to-text?lnk=STW_TR_HPT_T4_BLK&lnk2=trial_WatsonSpeechText&psrc=none&pexp=def
# https://developer.ibm.com/depmodels/cloud/?lnk=hpv18ct16
# https://developer.ibm.com/technologies/artificial-intelligence?lnk=hpv18ct19
# https://www.ibm.com/demos/?lnk=hpv18ct12
# https://developer.ibm.com/?lnk=hpv18ct9
# https://www.ibm.com/docs/tr?lnk=hpv18ct14
# https://www.redbooks.ibm.com/?lnk=ushpv18ct10
# https://www.ibm.com/support/home/?lnk=hpv18ct11
# https://www.ibm.com/training/?lnk=hpv18ct15
# /cloud/hybrid?lnk=hpv18pt14
# /cloud/learn/public-cloud?lnk=hpv18ct1
# /watson?lnk=ushpv18pt17
# /garage?lnk=hpv18pt13
# /blockchain?lnk=hpv18pt4
# https://www.ibm.com/thought-leadership/institute-business-value/?lnk=hpv18pt12
# /analytics?lnk=hpv18pt1
# /security?lnk=hpv18pt9
# /financing?lnk=hpv18pt3
# https://www.ibm.com/quantum-computing?lnk=hpv18pt16
# /cloud/hybrid?lnk=hpv18ct20
# /cloud/learn/public-cloud?lnk=hpv18ct1
# /cloud/redhat?lnk=hpv18ct13
# /watson?lnk=hpv18ct3
# https://www.ibm.com/quantum-computing?lnk=hpv18ct18
# /cloud/learn/kubernetes?lnk=hpv18ct8
# /products/spss-statistics?lnk=ushpv18ct7
# /blockchain?lnk=hpv18ct1
# https://www.ibm.com/employment?lnk=hpv18ct2
# https://www.ibm.com/case-studies/coca-cola-european-partners/?lnk=hpv18cs1
# /case-studies/search?lnk=hpv18cs2
# #

# %% [markdown]
# ## Scrape  all images  Tags

# %%
for link in soup.find_all('img'):# in html image is represented by the tag <img>
    print(link)
    print(link.get('src'))
# Out:
# <img alt="z16" class="" loading="lazy" src="//1.cms.s81c.com/sites/default/files/2022-04-04/20220405-ibm-z-multiframe-annc-geos-444x254-26343_5.jpg"/>
# //1.cms.s81c.com/sites/default/files/2022-04-04/20220405-ibm-z-multiframe-annc-geos-444x254-26343_5.jpg
# <img alt="C harfi biçiminde camgöbeği çizgilerden oluşan simge" class="" loading="lazy" src="//1.cms.s81c.com/sites/default/files/2021-02-23/ceo-study.png"/>
# //1.cms.s81c.com/sites/default/files/2021-02-23/ceo-study.png
# <img alt="IBM Cloud Pak for Business Automation için bir kullanım senaryosunu görüntüleyen, masa üzerinde bir dizüstü bilgisayar" class="" loading="lazy" src="//1.cms.s81c.com/sites/default/files/2021-02-17/cloud-pak-for-business-automation_0.jpg"/>
# //1.cms.s81c.com/sites/default/files/2021-02-17/cloud-pak-for-business-automation_0.jpg
# <img alt="Hibrit bulut depolaması çözümleri" class="" loading="lazy" src="//1.cms.s81c.com/sites/default/files/2021-04-12/GettyImages-802301352-servers-444x252.jpg"/>
# //1.cms.s81c.com/sites/default/files/2021-04-12/GettyImages-802301352-servers-444x252.jpg
# <img alt="Yapay zeka işlemlerini gösteren izometrik şekil" class="" loading="lazy" src="//1.cms.s81c.com/sites/default/files/2021-02-17/AIops-444x254.jpg"/>
# //1.cms.s81c.com/sites/default/files/2021-02-17/AIops-444x254.jpg
# <img alt="IBM Cloud Training" class="" loading="lazy" src="//1.cms.s81c.com/sites/default/files/2021-05-05/1def08ab-ed17-4bfd-9ac082139879743e.jpg"/>
# //1.cms.s81c.com/sites/default/files/2021-05-05/1def08ab-ed17-4bfd-9ac082139879743e.jpg
# <img alt="IBM MaaS360 with Watson gösterge panosunun ekran görüntüsü" class="" loading="lazy" src="//1.cms.s81c.com/sites/default/files/2021-12-08/10072019-t-bt-MaaS360-watson-23210-700x420.png"/>
# //1.cms.s81c.com/sites/default/files/2021-12-08/10072019-t-bt-MaaS360-watson-23210-700x420.png
# <img alt="IBM Cloud for VMWare Solutions gösterge panosunun ekran görüntüsü" class="" loading="lazy" src="//1.cms.s81c.com/sites/default/files/2021-12-08/IBM-Cloud-23059-700x420.png"/>
# //1.cms.s81c.com/sites/default/files/2021-12-08/IBM-Cloud-23059-700x420.png
# <img alt="IBM DataStage gösterge panosunun ekran görüntüsü" class="" loading="lazy" src="//1.cms.s81c.com/sites/default/files/2021-12-08/datastage-trial1.png"/>
# //1.cms.s81c.com/sites/default/files/2021-12-08/datastage-trial1.png
# <img alt="Watson Speech to Text gösterge panosunun ekran görüntüsü" class="" loading="lazy" src="//1.cms.s81c.com/sites/default/files/2021-12-08/Watson-speech-to-text-23705-700x420.png"/>
# //1.cms.s81c.com/sites/default/files/2021-12-08/Watson-speech-to-text-23705-700x420.png

# %% [markdown]
# ## Scrape data from HTML tables

# %%
#The below url contains an html table with data about colors and color codes.
url = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/labs/datasets/HTMLColorCodes.html"

# %% [markdown]
# Before proceeding to scrape a web site, you need to examine the contents, and the way data is organized on the website. Open the above url in your browser and check how many rows and columns are there in the color table.

# %%
# get the contents of the webpage in text format and store in a variable called data
data  = requests.get(url).text

# %%
soup = BeautifulSoup(data,"html.parser")

# %%
#find a html table in the web page
table = soup.find('table') # in html table is represented by the tag <table>

# %%
#Get all rows from the table
for row in table.find_all('tr'): # in html table row is represented by the tag <tr>
    # Get all columns in each row.
    cols = row.find_all('td') # in html a column is represented by the tag <td>
    color_name = cols[2].string # store the value in column 3 as color_name
    color_code = cols[3].string # store the value in column 4 as color_code
    print("{}--->{}".format(color_name,color_code))
# Out:
# Color Name--->None
# lightsalmon--->#FFA07A
# salmon--->#FA8072
# darksalmon--->#E9967A
# lightcoral--->#F08080
# coral--->#FF7F50
# tomato--->#FF6347
# orangered--->#FF4500
# gold--->#FFD700
# orange--->#FFA500
# darkorange--->#FF8C00
# lightyellow--->#FFFFE0
# lemonchiffon--->#FFFACD
# papayawhip--->#FFEFD5
# moccasin--->#FFE4B5
# peachpuff--->#FFDAB9
# palegoldenrod--->#EEE8AA
# khaki--->#F0E68C
# darkkhaki--->#BDB76B
# yellow--->#FFFF00
# lawngreen--->#7CFC00
# chartreuse--->#7FFF00
# limegreen--->#32CD32
# lime--->#00FF00
# forestgreen--->#228B22
# green--->#008000
# powderblue--->#B0E0E6
# lightblue--->#ADD8E6
# lightskyblue--->#87CEFA
# skyblue--->#87CEEB
# deepskyblue--->#00BFFF
# lightsteelblue--->#B0C4DE
# dodgerblue--->#1E90FF

# %% [markdown]
# ## Scrape data from HTML tables into a DataFrame using BeautifulSoup and Pandas

# %%
import pandas as pd

# %%
#The below url contains html tables with data about world population.
url = "https://en.wikipedia.org/wiki/World_population"

# %% [markdown]
# Before proceeding to scrape a web site, you need to examine the contents, and the way data is organized on the website. Open the above url in your browser and check the tables on the webpage.

# %%
# get the contents of the webpage in text format and store in a variable called data
data  = requests.get(url).text

# %%
soup = BeautifulSoup(data,"html.parser")

# %%
#find all html tables in the web page
tables = soup.find_all('table') # in html table is represented by the tag <table>

# %%
# we can see how many tables were found by checking the length of the tables list
len(tables)
# Out:
# 26

# %% [markdown]
# Assume that we are looking for the `10 most densly populated countries` table, we can look through the tables list and find the right one we are look for based on the data in each table or we can search for the table name if it is in the table but this option might not always work.

# %%
for index,table in enumerate(tables):
    if ("10 most densely populated countries" in str(table)):
        table_index = index
print(table_index)
# Out:
# 5

# %% [markdown]
# See if you can locate the table name of the table, `10 most densly populated countries`, below.

# %%
print(tables[table_index].prettify())
# Out:
# <table class="wikitable sortable" style="text-align:right">
#  <caption>
#   10 most densely populated countries
#   <small>
#    (with population above 5 million)
#   </small>
#  </caption>
#  <tbody>
#   <tr>
#    <th>
#     Rank
#    </th>
#    <th>
#     Country
#    </th>
#    <th>
#     Population
#    </th>
#    <th>
#     Area
#     <br/>
#     <small>
#      (km
#      <sup>
#       2
#      </sup>
#      )
#     </small>
#    </th>
#    <th>
#     Density
#     <br/>
#     <small>
#      (pop/km
#      <sup>
#       2
#      </sup>
#      )
#     </small>
#    </th>
#   </tr>
#   <tr>
#    <td>
#     1
#    </td>
#    <td align="left">
#     <span class="flagicon">
#      <img alt="" class="thumbborder" data-file-height="600" data-file-width="900" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/commons/thumb/4/48/Flag_of_Singapore.svg/23px-Flag_of_Singapore.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/4/48/Flag_of_Singapore.svg/35px-Flag_of_Singapore.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/4/48/Flag_of_Singapore.svg/45px-Flag_of_Singapore.svg.png 2x" width="23"/>
#     </span>
#     <a href="/wiki/Singapore" title="Singapore">
#      Singapore
#     </a>
#    </td>
#    <td>
#     5,704,000
#    </td>
#    <td>
#     710
#    </td>
#    <td>
#     8,033
#    </td>
#   </tr>
#   <tr>
#    <td>
#     2
#    </td>
#    <td align="left">
#     <span class="flagicon">
#      <img alt="" class="thumbborder" data-file-height="600" data-file-width="1000" decoding="async" height="14" src="//upload.wikimedia.org/wikipedia/commons/thumb/f/f9/Flag_of_Bangladesh.svg/23px-Flag_of_Bangladesh.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/f/f9/Flag_of_Bangladesh.svg/35px-Flag_of_Bangladesh.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/f/f9/Flag_of_Bangladesh.svg/46px-Flag_of_Bangladesh.svg.png 2x" width="23"/>
#     </span>
#     <a href="/wiki/Bangladesh" title="Bangladesh">
#      Bangladesh
#     </a>
#    </td>
#    <td>
#     172,790,000
#    </td>
#    <td>
#     143,998
#    </td>
#    <td>
#     1,200
#    </td>
#   </tr>
#   <tr>
#    <td>
#     3
#    </td>
#    <td align="left">
#     <p>
#      <span class="flagicon">
#       <img alt="" class="thumbborder" data-file-height="216" data-file-width="432" decoding="async" height="12" src="//upload.wikimedia.org/wikipedia/commons/thumb/0/00/Flag_of_Palestine.svg/23px-Flag_of_Palestine.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/0/00/Flag_of_Palestine.svg/35px-Flag_of_Palestine.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/0/00/Flag_of_Palestine.svg/46px-Flag_of_Palestine.svg.png 2x" width="23"/>
#      </span>
#      <a href="/wiki/State_of_Palestine" title="State of Palestine">
#       Palestine
#      </a>
#     </p>
#    </td>
#    <td>
#     5,266,785
#    </td>
#    <td>
#     6,020
#    </td>
#    <td>
#     847
#    </td>
#   </tr>
#   <tr>
#    <td>
#     4
#    </td>
#    <td align="left">
#     <span class="flagicon">
#      <img alt="" class="thumbborder" data-file-height="600" data-file-width="900" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/commons/thumb/5/59/Flag_of_Lebanon.svg/23px-Flag_of_Lebanon.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/5/59/Flag_of_Lebanon.svg/35px-Flag_of_Lebanon.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/5/59/Flag_of_Lebanon.svg/45px-Flag_of_Lebanon.svg.png 2x" width="23"/>
#     </span>
#     <a href="/wiki/Lebanon" title="Lebanon">
#      Lebanon
#     </a>
#    </td>
#    <td>
#     6,856,000
#    </td>
#    <td>
#     10,452
#    </td>
#    <td>
#     656
#    </td>
#   </tr>
#   <tr>
#    <td>
#     5
#    </td>
#    <td align="left">
#     <span class="flagicon">
#      <img alt="" class="thumbborder" data-file-height="600" data-file-width="900" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/commons/thumb/7/72/Flag_of_the_Republic_of_China.svg/23px-Flag_of_the_Republic_of_China.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/7/72/Flag_of_the_Republic_of_China.svg/35px-Flag_of_the_Republic_of_China.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/7/72/Flag_of_the_Republic_of_China.svg/45px-Flag_of_the_Republic_of_China.svg.png 2x" width="23"/>
#     </span>
#     <a href="/wiki/Taiwan" title="Taiwan">
#      Taiwan
#     </a>
#    </td>
#    <td>
#     23,604,000
#    </td>
#    <td>
#     36,193
#    </td>
#    <td>
#     652
#    </td>
#   </tr>
#   <tr>
#    <td>
#     6
#    </td>
#    <td align="left">
#     <span class="flagicon">
#      <img alt="" class="thumbborder" data-file-height="600" data-file-width="900" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/commons/thumb/0/09/Flag_of_South_Korea.svg/23px-Flag_of_South_Korea.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/0/09/Flag_of_South_Korea.svg/35px-Flag_of_South_Korea.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/0/09/Flag_of_South_Korea.svg/45px-Flag_of_South_Korea.svg.png 2x" width="23"/>
#     </span>
#     <a href="/wiki/South_Korea" title="South Korea">
#      South Korea
#     </a>
#    </td>
#    <td>
#     51,781,000
#    </td>
#    <td>
#     99,538
#    </td>
#    <td>
#     520
#    </td>
#   </tr>
#   <tr>
#    <td>
#     7
#    </td>
#    <td align="left">
#     <span class="flagicon">
#      <img alt="" class="thumbborder" data-file-height="720" data-file-width="1080" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/commons/thumb/1/17/Flag_of_Rwanda.svg/23px-Flag_of_Rwanda.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/1/17/Flag_of_Rwanda.svg/35px-Flag_of_Rwanda.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/1/17/Flag_of_Rwanda.svg/45px-Flag_of_Rwanda.svg.png 2x" width="23"/>
#     </span>
#     <a href="/wiki/Rwanda" title="Rwanda">
#      Rwanda
#     </a>
#    </td>
#    <td>
#     12,374,000
#    </td>
#    <td>
#     26,338
#    </td>
#    <td>
#     470
#    </td>
#   </tr>
#   <tr>
#    <td>
#     8
#    </td>
#    <td align="left">
#     <span class="flagicon">
#      <img alt="" class="thumbborder" data-file-height="600" data-file-width="1000" decoding="async" height="14" src="//upload.wikimedia.org/wikipedia/commons/thumb/5/56/Flag_of_Haiti.svg/23px-Flag_of_Haiti.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/5/56/Flag_of_Haiti.svg/35px-Flag_of_Haiti.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/5/56/Flag_of_Haiti.svg/46px-Flag_of_Haiti.svg.png 2x" width="23"/>
#     </span>
#     <a href="/wiki/Haiti" title="Haiti">
#      Haiti
#     </a>
#    </td>
#    <td>
#     11,578,000
#    </td>
#    <td>
#     27,065
#    </td>
#    <td>
#     428
#    </td>
#   </tr>
#   <tr>
#    <td>
#     9
#    </td>
#    <td align="left">
#     <span class="flagicon">
#      <img alt="" class="thumbborder" data-file-height="600" data-file-width="900" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/commons/thumb/2/20/Flag_of_the_Netherlands.svg/23px-Flag_of_the_Netherlands.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/2/20/Flag_of_the_Netherlands.svg/35px-Flag_of_the_Netherlands.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/2/20/Flag_of_the_Netherlands.svg/45px-Flag_of_the_Netherlands.svg.png 2x" width="23"/>
#     </span>
#     <a href="/wiki/Netherlands" title="Netherlands">
#      Netherlands
#     </a>
#    </td>
#    <td>
#     17,730,000
#    </td>
#    <td>
#     41,526
#    </td>
#    <td>
#     427
#    </td>
#   </tr>
#   <tr>
#    <td>
#     10
#    </td>
#    <td align="left">
#     <span class="flagicon">
#      <img alt="" class="thumbborder" data-file-height="800" data-file-width="1100" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/commons/thumb/d/d4/Flag_of_Israel.svg/21px-Flag_of_Israel.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/d/d4/Flag_of_Israel.svg/32px-Flag_of_Israel.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/d/d4/Flag_of_Israel.svg/41px-Flag_of_Israel.svg.png 2x" width="21"/>
#     </span>
#     <a href="/wiki/Israel" title="Israel">
#      Israel
#     </a>
#    </td>
#    <td>
#     9,520,000
#    </td>
#    <td>
#     22,072
#    </td>
#    <td>
#     431
#    </td>
#   </tr>
#  </tbody>
# </table>

# %%
population_data = pd.DataFrame(columns=["Rank", "Country", "Population", "Area", "Density"])

for row in tables[table_index].tbody.find_all("tr"):
    col = row.find_all("td")
    if (col != []):
        rank = col[0].text
        country = col[1].text
        population = col[2].text.strip()
        area = col[3].text.strip()
        density = col[4].text.strip()
        population_data = population_data.append({"Rank":rank, "Country":country, "Population":population, "Area":area, "Density":density}, ignore_index=True)

population_data
# Out:
# C:\Users\abdul\AppData\Local\Temp\ipykernel_356\394869253.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   population_data = population_data.append({"Rank":rank, "Country":country, "Population":population, "Area":area, "Density":density}, ignore_index=True)
# C:\Users\abdul\AppData\Local\Temp\ipykernel_356\394869253.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   population_data = population_data.append({"Rank":rank, "Country":country, "Population":population, "Area":area, "Density":density}, ignore_index=True)
# C:\Users\abdul\AppData\Local\Temp\ipykernel_356\394869253.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   population_data = population_data.append({"Rank":rank, "Country":country, "Population":population, "Area":area, "Density":density}, ignore_index=True)
# C:\Users\abdul\AppData\Local\Temp\ipykernel_356\394869253.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   population_data = population_data.append({"Rank":rank, "Country":country, "Population":population, "Area":area, "Density":density}, ignore_index=True)
# C:\Users\abdul\AppData\Local\Temp\ipykernel_356\394869253.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   population_data = population_data.append({"Rank":rank, "Country":country, "Population":population, "Area":area, "Density":density}, ignore_index=True)
# C:\Users\abdul\AppData\Local\Temp\ipykernel_356\394869253.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   population_data = population_data.append({"Rank":rank, "Country":country, "Population":population, "Area":area, "Density":density}, ignore_index=True)
# C:\Users\abdul\AppData\Local\Temp\ipykernel_356\394869253.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   population_data = population_data.append({"Rank":rank, "Country":country, "Population":population, "Area":area, "Density":density}, ignore_index=True)
# C:\Users\abdul\AppData\Local\Temp\ipykernel_356\394869253.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   population_data = population_data.append({"Rank":rank, "Country":country, "Population":population, "Area":area, "Density":density}, ignore_index=True)
# C:\Users\abdul\AppData\Local\Temp\ipykernel_356\394869253.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   population_data = population_data.append({"Rank":rank, "Country":country, "Population":population, "Area":area, "Density":density}, ignore_index=True)
# C:\Users\abdul\AppData\Local\Temp\ipykernel_356\394869253.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   population_data = population_data.append({"Rank":rank, "Country":country, "Population":population, "Area":area, "Density":density}, ignore_index=True)
#   Rank           Country   Population     Area Density
# 0    1         Singapore    5,704,000      710   8,033
# 1    2        Bangladesh  172,790,000  143,998   1,200
# 2    3  \n Palestine\n\n    5,266,785    6,020     847
# 3    4           Lebanon    6,856,000   10,452     656
# 4    5            Taiwan   23,604,000   36,193     652
# 5    6       South Korea   51,781,000   99,538     520
# 6    7            Rwanda   12,374,000   26,338     470
# 7    8             Haiti   11,578,000   27,065     428
# 8    9       Netherlands   17,730,000   41,526     427
# 9   10            Israel    9,520,000   22,072     431

# %% [markdown]
# ## Scrape data from HTML tables into a DataFrame using BeautifulSoup and read_html

# %% [markdown]
# Using the same `url`, `data`, `soup`, and `tables` object as in the last section we can use the `read_html` function to create a DataFrame.
#
# Remember the table we need is located in `tables[table_index]`
#
# We can now use the `pandas` function `read_html` and give it the string version of the table as well as the `flavor` which is the parsing engine `bs4`.

# %%
#!pip install html5lib
#!pip install lxml
#!pip install beautifulSoup4

#import html5lib
#import lxml
#from bs4 import BeautifulSoup
#import pandas as pd

pd.read_html(str(tables[5]), flavor='bs4')
# Out:
# [   Rank      Country  Population  Area(km2)  Density(pop/km2)
#  0     1    Singapore     5704000        710              8033
#  1     2   Bangladesh   172790000     143998              1200
#  2     3    Palestine     5266785       6020               847
#  3     4      Lebanon     6856000      10452               656
#  4     5       Taiwan    23604000      36193               652
#  5     6  South Korea    51781000      99538               520
#  6     7       Rwanda    12374000      26338               470
#  7     8        Haiti    11578000      27065               428
#  8     9  Netherlands    17730000      41526               427
#  9    10       Israel     9520000      22072               431]

# %% [markdown]
# The function `read_html` always returns a list of DataFrames so we must pick the one we want out of the list.

# %%
population_data_read_html = pd.read_html(str(tables[5]), flavor='bs4')[0]

population_data_read_html
# Out:
#    Rank      Country  Population  Area(km2)  Density(pop/km2)
# 0     1    Singapore     5704000        710              8033
# 1     2   Bangladesh   172790000     143998              1200
# 2     3    Palestine     5266785       6020               847
# 3     4      Lebanon     6856000      10452               656
# 4     5       Taiwan    23604000      36193               652
# 5     6  South Korea    51781000      99538               520
# 6     7       Rwanda    12374000      26338               470
# 7     8        Haiti    11578000      27065               428
# 8     9  Netherlands    17730000      41526               427
# 9    10       Israel     9520000      22072               431

# %% [markdown]
# ## Scrape data from HTML tables into a DataFrame using read_html

# %% [markdown]
# We can also use the `read_html` function to directly get DataFrames from a `url`.

# %%
dataframe_list = pd.read_html(url, flavor='bs4')

# %% [markdown]
# We can see there are 25 DataFrames just like when we used `find_all` on the `soup` object.

# %%
len(dataframe_list)
# Out:
# 26

# %% [markdown]
# Finally we can pick the DataFrame we need out of the list.

# %%
dataframe_list[5]
# Out:
#    Rank      Country  Population  Area(km2)  Density(pop/km2)
# 0     1    Singapore     5704000        710              8033
# 1     2   Bangladesh   172790000     143998              1200
# 2     3    Palestine     5266785       6020               847
# 3     4      Lebanon     6856000      10452               656
# 4     5       Taiwan    23604000      36193               652
# 5     6  South Korea    51781000      99538               520
# 6     7       Rwanda    12374000      26338               470
# 7     8        Haiti    11578000      27065               428
# 8     9  Netherlands    17730000      41526               427
# 9    10       Israel     9520000      22072               431

# %% [markdown]
# We can also use the `match` parameter to select the specific table we want. If the table contains a string matching the text it will be read.

# %%
pd.read_html(url, match="10 most densely populated countries", flavor='bs4')[0]
# Out:
#    Rank      Country  Population  Area(km2)  Density(pop/km2)
# 0     1    Singapore     5704000        710              8033
# 1     2   Bangladesh   172790000     143998              1200
# 2     3    Palestine     5266785       6020               847
# 3     4      Lebanon     6856000      10452               656
# 4     5       Taiwan    23604000      36193               652
# 5     6  South Korea    51781000      99538               520
# 6     7       Rwanda    12374000      26338               470
# 7     8        Haiti    11578000      27065               428
# 8     9  Netherlands    17730000      41526               427
# 9    10       Israel     9520000      22072               431

# %%
# !mamba install bs4==4.10.0 -y
# !pip install lxml==4.6.4
# !mamba install html5lib==1.1 -y
# !pip install requests==2.26.0

import requests
from bs4 import BeautifulSoup
# Out:
# 'mamba' is not recognized as an internal or external command,
# operable program or batch file.
# Requirement already satisfied: lxml==4.6.4 in c:\users\abdul\anaconda3\lib\site-packages (4.6.4)
# 'mamba' is not recognized as an internal or external command,
# operable program or batch file.
# Requirement already satisfied: requests==2.26.0 in c:\users\abdul\anaconda3\lib\site-packages (2.26.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\abdul\anaconda3\lib\site-packages (from requests==2.26.0) (1.26.9)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\abdul\anaconda3\lib\site-packages (from requests==2.26.0) (3.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\abdul\anaconda3\lib\site-packages (from requests==2.26.0) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\abdul\anaconda3\lib\site-packages (from requests==2.26.0) (2022.5.18.1)

# %%
# %%html
# <!DOCTYPE xtml>
# <?xml version="1.0" encoding="UTF-8"?>
# <?xml-stylesheet type='text/xsl'?>
# <CATALOG>
# 	<CD>
# 	<TITLE>dill diya galla</TITLE>
# 	<ARTIST>Arijit singh</ARTIST>
# 	<COUNTRY>India</COUNTRY>
# 	<COMPANY>tseries</COMPANY>
# 	<PRICE>10.90</PRICE>
# 	<YEAR>2018</YEAR>
# 	</CD>
# 	<CD>
# 	<TITLE>Saiyara</TITLE>
# 	<ARTIST>Atif Aslam</ARTIST>
# 	<COUNTRY>Uk</COUNTRY>
# 	<COMPANY>Records</COMPANY>
# 	<PRICE>9.90</PRICE>
# 	<YEAR>2015</YEAR>
# 	</CD>
# 	<CD>
# 	<TITLE>Khairiyat</TITLE>
# 	<ARTIST>Sonu nigam</ARTIST>
# 	<COUNTRY>india</COUNTRY>
# 	<COMPANY>radio</COMPANY>
# 	<PRICE>9.90</PRICE>
# 	<YEAR>2019</YEAR>
# 	</CD>
# 	<CD>
# 	<TITLE>all is well</TITLE>
# 	<ARTIST>Amir Khan</ARTIST>
# 	<COUNTRY>pak</COUNTRY>
# 	<COMPANY>Virgin records</COMPANY>
# 	<PRICE>10.20</PRICE>
# 	<YEAR>2012</YEAR>
# 	</CD>
# 	<CD>
# 	<TITLE>rockstar</TITLE>
# 	<ARTIST>kk</ARTIST>
# 	<COUNTRY>india</COUNTRY>
# 	<COMPANY>Eros</COMPANY>
# 	<PRICE>9.90</PRICE>
# 	<YEAR>2014</YEAR>
# 	</CD>
# </CATALOG>
# </xml>
# Out:
# <!DOCTYPE xtml>
# <?xml version="1.0" encoding="UTF-8"?>
# <?xml-stylesheet type='text/xsl'?>
# <CATALOG>
# 	<CD>
# 	<TITLE>dill diya galla</TITLE>
# 	<ARTIST>Arijit singh</ARTIST>
# 	<COUNTRY>India</COUNTRY>
# 	<COMPANY>tseries</COMPANY>
# 	<PRICE>10.90</PRICE>
# 	<YEAR>2018</YEAR>
# 	</CD>
# 	<CD>
# 	<TITLE>Saiyara</TITLE>
# 	<ARTIST>Atif Aslam</ARTIST>
# 	<COUNTRY>Uk</COUNTRY>
# 	<COMPANY>Records</COMPANY>
# 	<PRICE>9.90</PRICE>
# 	<YEAR>2015</YEAR>
# 	</CD>
# 	<CD>
# 	<TITLE>Khairiyat</TITLE>
# 	<ARTIST>Sonu nigam</ARTIST>
# 	<COUNTRY>india</COUNTRY>
# 	<COMPANY>radio</COMPANY>
# 	<PRICE>9.90</PRICE>
# 	<YEAR>2019</YEAR>
# 	</CD>
# 	<CD>
# 	<TITLE>all is well</TITLE>
# 	<ARTIST>Amir Khan</ARTIST>
# 	<COUNTRY>pak</COUNTRY>
# 	<COMPANY>Virgin records</COMPANY>
# 	<PRICE>10.20</PRICE>
# 	<YEAR>2012</YEAR>
# 	</CD>
# 	<CD>
# 	<TITLE>rockstar</TITLE>
# 	<ARTIST>kk</ARTIST>
# 	<COUNTRY>india</COUNTRY>
# 	<COMPANY>Eros</COMPANY>
# 	<PRICE>9.90</PRICE>
# 	<YEAR>2014</YEAR>
# 	</CD>
# </CATALOG>
# </xml>

# %%
xml_page = "<!DOCTYPE xml><?xml-stylesheet type='text/xsl'?><CATALOG><CD><TITLE>dill diya galla</TITLE><ARTIST>Arijit singh</ARTIST><COUNTRY>India</COUNTRY><COMPANY>tseries</COMPANY><PRICE>10.90</PRICE><YEAR>2018</YEAR></CD><CD><TITLE>Saiyara</TITLE><ARTIST>Atif Aslam</ARTIST><COUNTRY>Uk</COUNTRY><COMPANY>Records</COMPANY><PRICE>9.90</PRICE><YEAR>2015</YEAR></CD><CD><TITLE>Khairiyat</TITLE><ARTIST>Sonu nigam</ARTIST><COUNTRY>india</COUNTRY><COMPANY>radio</COMPANY><PRICE>9.90</PRICE><YEAR>2019</YEAR></CD><CD><TITLE>all is well</TITLE><ARTIST>Amir Khan</ARTIST><COUNTRY>pak</COUNTRY><COMPANY>Virgin records</COMPANY><PRICE>10.20</PRICE><YEAR>2012</YEAR></CD><CD><TITLE>rockstar</TITLE><ARTIST>kk</ARTIST><COUNTRY>india</COUNTRY><COMPANY>Eros</COMPANY><PRICE>9.90</PRICE><YEAR>2014</YEAR></CD></CATALOG></xml>"

# %%
xml_page = requests.get("https://www.learningcontainer.com/sample-xml-file/").text

# Create BS4 object
soup_obj = BeautifulSoup(xml_page, "xml")

# pull any instance of <pre>
pre_tag = soup_obj.find_all('CD')

# clear data for all tags
for tags in pre_tag:
    names = tags.contents[0]
    full_link = tags.get('href')
    names
    full_link

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" dir="ltr" lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    World population - Wikipedia
#   </title>
#   <script>
#    document.documentElement.className="client-js";RLCONF={"wgBreakFrames":false,"wgSeparatorTransformTable":["",""],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","January","February","March","April","May","June","July","August","September","October","November","December"],"wgRequestId":"d9981f17-15d5-45ed-8d3a-486b6a8fa62c","wgCSPNonce":false,"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":false,"wgNamespaceNumber":0,"wgPageName":"World_population","wgTitle":"World population","wgCurRevisionId":1090171612,"wgRevisionId":1090171612,"wgArticleId":19017269,"wgIsArticle":true,"wgIsRedirect":false,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["Pages with non-numeric formatnum arguments","CS1 maint: url-status","Webarchive template wayback links","Articles with short description","Short description matches Wikidata","Wikipedia indefinitely semi-protected pages","Use dmy dates from October 2020",
# "Articles containing potentially dated statements from November 2021","All articles containing potentially dated statements","Wikipedia articles in need of updating from January 2022","All Wikipedia articles in need of updating","All articles with unsourced statements","Articles with unsourced statements from September 2014","Articles needing additional references from April 2020","All articles needing additional references","Articles with unsourced statements from May 2022","Commons category link is on Wikidata","Articles with GND identifiers","Pages using the Graph extension","World population","Cultural globalization","Human overpopulation"],"wgPageContentLanguage":"en","wgPageContentModel":"wikitext","wgRelevantPageName":"World_population","wgRelevantArticleId":19017269,"wgIsProbablyEditable":false,"wgRelevantPageIsProbablyEditable":false,"wgRestrictionEdit":["autoconfirmed"],"wgRestrictionMove":["autoconfirmed"],"wgFlaggedRevsParams":{"tags":{"status":{"levels":1}}},
# "wgVisualEditor":{"pageLanguageCode":"en","pageLanguageDir":"ltr","pageVariantFallbacks":"en"},"wgMFDisplayWikibaseDescriptions":{"search":true,"nearby":true,"watchlist":true,"tagline":false},"wgWMESchemaEditAttemptStepOversample":false,"wgWMEPageLength":100000,"wgNoticeProject":"wikipedia","wgMediaViewerOnClick":true,"wgMediaViewerEnabledByDefault":true,"wgPopupsFlags":10,"wgULSCurrentAutonym":"English","wgGraphSpecs":{"c53abf65ab34d88f888199ea617f77a6a67a2069":{"legends":[{"properties":{"title":{"fill":{"value":"#54595d"}},"labels":{"fill":{"value":"#54595d"}}},"stroke":"color","title":"","fill":"color"}],"scales":[{"type":"linear","name":"x","zero":false,"domain":{"data":"chart","field":"x"},"range":"width","nice":true},{"type":"linear","name":"y","domain":{"data":"chart","field":"y"},"zero":false,"range":"height","nice":true},{"domain":{"data":"chart","field":"series"},"type":"ordinal","name":"color","range":"category10"}],"version":2,"marks":[{"type":"line","properties":{"hover":{
# "stroke":{"value":"red"}},"update":{"stroke":{"scale":"color","field":"series"}},"enter":{"y":{"scale":"y","field":"y"},"x":{"scale":"x","field":"x"},"stroke":{"scale":"color","field":"series"},"strokeWidth":{"value":2.5}}},"from":{"data":"chart"}}],"height":150,"axes":[{"type":"x","title":"year","scale":"x","format":"d","properties":{"title":{"fill":{"value":"#54595d"}},"grid":{"stroke":{"value":"#54595d"}},"ticks":{"stroke":{"value":"#54595d"}},"axis":{"strokeWidth":{"value":2},"stroke":{"value":"#54595d"}},"labels":{"fill":{"value":"#54595d"}}},
# "population (billion)","x":2009},{"y":6.96,"series":"population (billion)","x":2010},{"y":7.04,"series":"population (billion)","x":2011},{"y":7.13,"series":"population (billion)","x":2012},{"y":7.21,"series":"population (billion)","x":2013},{"y":7.3,"series":"population (billion)","x":2014},{"y":7.38,"series":"population (billion)","x":2015},{"y":7.46,"series":"population (billion)","x":2016},{"y":7.55,"series":"population (billion)","x":2017},{"y":7.63,"series":"population (billion)","x":2018},{"y":7.71,"series":"population (billion)","x":2019},{"y":7.8,"series":"population (billion)","x":2020}]}],"width":550},"4bb4699e2d8b11cc124d4c245589da21a5ebc443":{"legends":[{"properties":{"title":{"fill":{"value":"#54595d"}},"labels":{"fill":{"value":"#54595d"}}},"stroke":"color","title":"","fill":"color"}],"scales":[{"type":"linear","name":"x","zero":false,"domain":{"data":"chart","field":"x"},"range":"width","nice":true},{"type":"linear","name":"y","domain":{"data":"chart","field":"y"},"zero"
# :false,"range":"height","nice":true},{"domain":{"data":"chart","field":"series"},"type":"ordinal","name":"color","range":"category10"}],"version":2,"marks":[{"type":"line","properties":{"hover":{"stroke":{"value":"red"}},"update":{"stroke":{"scale":"color","field":"series"}},"enter":{"y":{"scale":"y","field":"y"},"x":{"scale":"x","field":"x"},"stroke":{"scale":"color","field":"series"},"strokeWidth":{"value":2.5}}},"from":{"data":"chart"}}],"height":150,"axes":[{"type":"x","title":"years","scale":"x","format":"d","properties":{"title":{"fill":{"value":"#54595d"}},"grid":{"stroke":{"value":"#54595d"}},"ticks":{"stroke":{"value":"#54595d"}},"axis":{"strokeWidth":{"value":2},"stroke":{"value":"#54595d"}},"labels":{"fill":{"value":"#54595d"}}},"grid":true},{"type":"y","title":"‰","scale":"y","properties":{"title":{"fill":{"value":"#54595d"}},"grid":{"stroke":{"value":"#54595d"}},"ticks":{"stroke":{"value":"#54595d"}},"axis":{"strokeWidth":{"value":2},"stroke":{"value":"#54595d"}},
# "labels":{"fill":{"value":"#54595d"}}},"grid":true}],"data":[{"format":{"parse":{"y":"number","x":"integer"},"type":"json"},"name":"chart","values":[{"y":1.88,"series":"Annual growth (%)","x":1951},{"y":1.81,"series":"Annual growth (%)","x":1952},{"y":1.78,"series":"Annual growth (%)","x":1953},{"y":1.76,"series":"Annual growth (%)","x":1954},{"y":1.77,"series":"Annual growth (%)","x":1955},{"y":1.78,"series":"Annual growth (%)","x":1956},{"y":1.8,"series":"Annual growth (%)","x":1957},{"y":1.82,"series":"Annual growth (%)","x":1958},{"y":1.84,"series":"Annual growth (%)","x":1959},{"y":1.86,"series":"Annual growth (%)","x":1960},{"y":1.87,"series":"Annual growth (%)","x":1961},{"y":1.89,"series":"Annual growth (%)","x":1962},{"y":1.92,"series":"Annual growth (%)","x":1963},{"y":1.96,"series":"Annual growth (%)","x":1964},{"y":2,"series":"Annual growth (%)","x":1965},{"y":2.05,"series":"Annual growth (%)","x":1966},{"y":2.08,"series":"Annual growth (%)","x":1967},{"y":2.09,"series":
rel="canonical"/>
#   <link href="//meta.wikimedia.org" rel="dns-prefetch"/>
#   <link href="//login.wikimedia.org" rel="dns-prefetch"/>
#  </head>
#  <body class="mediawiki ltr sitedir-ltr mw-hide-empty-elt ns-0 ns-subject page-World_population rootpage-World_population skin-vector action-view skin-vector-legacy">
#   <div class="noprint" id="mw-page-base">
#   </div>
#   <div class="noprint" id="mw-head-base">
#   </div>
#   <div class="mw-body" id="content" role="main">
#    <a id="top">
#    </a>
#    <div id="siteNotice">
#     <!-- CentralNotice -->
#    </div>
#    <div class="mw-indicators">
#     <div class="mw-indicator" id="mw-indicator-pp-default">
#      <a href="/wiki/Wikipedia:Protection_policy#semi" title="This article is semi-protected.">
#       <img alt="Page semi-protected" data-file-height="512" data-file-width="512" decoding="async" height="20" src="//upload.wikimedia.org/wikipedia/en/thumb/1/1b/Semi-protection-shackle.svg/20px-Semi-protection-shackle.svg.png" srcset="//upload.wikimedia.org/wikipedia/en/thumb/1/1b/Semi-protection-shackle.svg/30px-Semi-protection-shackle.svg.png 1.5x, //upload.wikimedia.org/wikipedia/en/thumb/1/1b/Semi-protection-shackle.svg/40px-Semi-protection-shackle.svg.png 2x" width="20"/>
#      </a>
#     </div>
#    </div>
#    <h1 class="firstHeading mw-first-heading" id="firstHeading">
#     World population
#    </h1>
#    <div class="vector-body" id="bodyContent">
#     <div class="noprint" id="siteSub">
#      From Wikipedia, the free encyclopedia
#     </div>
#     <div id="contentSub">
#     </div>
#     <div id="contentSub2">
#     </div>
#     <div id="jump-to-nav">
#     </div>
#     <a class="mw-jump-link" href="#mw-head">
#      Jump to navigation
#     </a>
#     <a class="mw-jump-link" href="#searchInput">
#      Jump to search
#     </a>
#     <div class="mw-body-content mw-content-ltr" dir="ltr" id="mw-content-text" lang="en">
#      <div class="mw-parser-output">
#       <div class="shortdescription nomobile noexcerpt noprint searchaux" style="display:none">
#        Total number of living humans on Earth
#       </div>
#       <style data-mw-deduplicate="TemplateStyles:r1033289096">
#        .mw-parser-output .hatnote{font-style:italic}.mw-parser-output div.hatnote{padding-left:1.6em;margin-bottom:0.5em}.mw-parser-output .hatnote i{font-style:normal}.mw-parser-output .hatnote+link+.hatnote{margin-top:-0.5em}
#       </style>
#       <div class="hatnote navigation-not-searchable" role="note">
#        Not to be confused with
#        <a href="/wiki/Demographics_of_the_world" title="Demographics of the world">
#         Demographics of the world
#        </a>
#        .
#       </div>
#       <div class="thumb tright">
#        <div class="thumbinner" style="width:222px;">
#         <a class="image" href="/wiki/File:World-population-1750-2015-and-un-projection-until-2100.png">
#          <img alt="World population growth from 10,000 BCE to 2021" class="thumbimage" data-file-height="2400" data-file-width="3400" decoding="async" height="155" src="//upload.wikimedia.org/wikipedia/commons/thumb/8/85/World-population-1750-2015-and-un-projection-until-2100.png/220px-World-population-1750-2015-and-un-projection-until-2100.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/8/85/World-population-1750-2015-and-un-projection-until-2100.png/330px-World-population-1750-2015-and-un-projection-until-2100.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/8/85/World-population-1750-2015-and-un-projection-until-2100.png/440px-World-population-1750-2015-and-un-projection-until-2100.png 2x" width="220"/>
#         </a>
#         <div class="thumbcaption">
#          <div class="magnify">
#           <a class="internal" href="/wiki/File:World-population-1750-2015-and-un-projection-until-2100.png" title="Enlarge">
#           </a>
#          </div>
#          World population growth from 10,000 BCE to 2021.
#          <sup class="reference" id="cite_ref-1">
#           <a href="#cite_note-1">
#            [1]
#           </a>
#          </sup>
#         </div>
#        </div>
#       </div>
#       <p class="mw-empty-elt">
#       </p>
#       <div class="thumb tright">
#        <div class="thumbinner" style="width:222px;">
#         <a class="image" href="/wiki/File:World_Population_Prospects_2019.png">
#          <img alt="" class="thumbimage" data-file-height="731" data-file-width="975" decoding="async" height="165" src="//upload.wikimedia.org/wikipedia/commons/thumb/e/e5/World_Population_Prospects_2019.png/220px-World_Population_Prospects_2019.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/e/e5/World_Population_Prospects_2019.png/330px-World_Population_Prospects_2019.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/e/e5/World_Population_Prospects_2019.png/440px-World_Population_Prospects_2019.png 2x" width="220"/>
#         </a>
#         <div class="thumbcaption">
#          <div class="magnify">
#           <a class="internal" href="/wiki/File:World_Population_Prospects_2019.png" title="Enlarge">
#           </a>
#          </div>
#          High, medium, and low projections of the future human world population
#          <sup class="reference" id="cite_ref-:4_2-0">
#           <a href="#cite_note-:4-2">
#            [2]
#           </a>
#          </sup>
#         </div>
#        </div>
#       </div>
#       <p>
#        In
#        <a href="/wiki/Demography" title="Demography">
#         demographics
#        </a>
#        , the term
#        <b>
#         world population
#        </b>
#        is often used to refer to the total number of
#        <a href="/wiki/Human" title="Human">
#         humans
#        </a>
#        currently living, and was estimated to have exceeded 7.9 billion as of November 2021
#        <sup class="plainlinks noexcerpt noprint asof-tag update" style="display:none;">
#         <a class="external text" href="https://en.wikipedia.org/w/index.php?title=World_population&amp;action=edit">
#          [update]
#         </a>
#        </sup>
#        .
#        <sup class="reference" id="cite_ref-:6_3-0">
#         <a href="#cite_note-:6-3">
#          [3]
#         </a>
#        </sup>
#        It took over two million years of
#        <a href="/wiki/Prehistory" title="Prehistory">
#         human prehistory
#        </a>
#        and
#        <a href="/wiki/Human_history" title="Human history">
#         history
#        </a>
#        for the human population to reach one
#        <a href="/wiki/Billion" title="Billion">
#         billion
#        </a>
#        and only 207 years more to grow to 7 billion.
#        <sup class="reference" id="cite_ref-4">
#         <a href="#cite_note-4">
#          [4]
#         </a>
#        </sup>
#       </p>
#       <p>
#        The human population has experienced
#        <a href="/wiki/Population_growth" title="Population growth">
#         continuous growth
#        </a>
#        following the
#        <a href="/wiki/Great_Famine_of_1315%E2%80%931317" title="Great Famine of 1315–1317">
#         Great Famine of 1315–1317
#        </a>
#        and the end of the
#        <a href="/wiki/Black_Death" title="Black Death">
#         Black Death
#        </a>
#        in 1350, when it was near 370,000,000.
#        <sup class="reference" id="cite_ref-5">
#         <a href="#cite_note-5">
#          [5]
#         </a>
#        </sup>
#        The highest global
#        <a class="mw-redirect" href="/wiki/Population_growth_rates" title="Population growth rates">
#         population growth rates
#        </a>
#        , with increases of over 1.8% per year, occurred between 1955 and 1975 – peaking at 2.1% between 1965 and 1970.
#        <sup class="reference" id="cite_ref-:1_6-0">
#         <a href="#cite_note-:1-6">
#          [6]
#         </a>
#        </sup>
#        The growth rate declined to 1.1% between 2015 and 2020 and is projected to decline further in the course of the 21st century.
#        <sup class="reference" id="cite_ref-7">
#         <a href="#cite_note-7">
#          [7]
#         </a>
#        </sup>
#        <sup class="reference" id="cite_ref-:5_8-0">
#         <a href="#cite_note-:5-8">
#          [8]
#         </a>
#        </sup>
#        The global population is still increasing, but there is significant uncertainty about its long-term trajectory due to changing rates of fertility and mortality.
#        <sup class="reference" id="cite_ref-9">
#         <a href="#cite_note-9">
#          [9]
#         </a>
#        </sup>
#        The
#        <a href="/wiki/United_Nations_Department_of_Economic_and_Social_Affairs" title="United Nations Department of Economic and Social Affairs">
#         UN Department of Economics and Social Affairs
#        </a>
#        projects between 9 and 10 billion people by 2050, and gives an 80% confidence interval of 10–12 billion by the end of the 21st century,
#        <sup class="reference" id="cite_ref-:4_2-1">
#         <a href="#cite_note-:4-2">
#          [2]
#         </a>
#        </sup>
#        with a growth rate by then of zero.
#        <sup class="reference" id="cite_ref-:5_8-1">
#         <a href="#cite_note-:5-8">
#          [8]
#         </a>
#        </sup>
#        Other demographers predict that the human population will begin to decline in the second half of the 21st century.
#        <sup class="reference" id="cite_ref-10">
#         <a href="#cite_note-10">
#          [10]
#         </a>
#        </sup>
#       </p>
#       <p>
#        The total number of births globally is currently (2015-20) 140 million/year, is projected to peak during the period 2040-45 at 141 million/year and thereafter decline slowly to 126 million/year by 2100.
#        <sup class="reference" id="cite_ref-:2_11-0">
#         <a href="#cite_note-:2-11">
#          [11]
#         </a>
#        </sup>
#        The total number of deaths is currently 57 million/year and is projected to grow steadily to 121 million/year by 2100.
#        <sup class="reference" id="cite_ref-:3_12-0">
#         <a href="#cite_note-:3-12">
#          [12]
#         </a>
#        </sup>
#       </p>
#       <p>
#        The
#        <a class="mw-redirect" href="/wiki/Median_age" title="Median age">
#         median age
#        </a>
#        of human beings as of 2020 is 31 years.
#        <sup class="reference" id="cite_ref-:0_13-0">
#         <a href="#cite_note-:0-13">
#          [13]
#         </a>
#        </sup>
#       </p>
#       <div aria-labelledby="mw-toc-heading" class="toc" id="toc" role="navigation">
#        <input class="toctogglecheckbox" id="toctogglecheckbox" role="button" style="display:none" type="checkbox"/>
#        <div class="toctitle" dir="ltr" lang="en">
#         <h2 id="mw-toc-heading">
#          Contents
#         </h2>
#         <span class="toctogglespan">
#          <label class="toctogglelabel" for="toctogglecheckbox">
#          </label>
#         </span>
#        </div>
#        <ul>
#         <li class="toclevel-1 tocsection-1">
#          <a href="#Population_by_region">
#           <span class="tocnumber">
#            1
#           </span>
#           <span class="toctext">
#            Population by region
#           </span>
#          </a>
#         </li>
#         <li class="toclevel-1 tocsection-2">
#          <a href="#History">
#           <span class="tocnumber">
#            2
#           </span>
#           <span class="toctext">
#            History
#           </span>
#          </a>
#          <ul>
#           <li class="toclevel-2 tocsection-3">
#            <a href="#Ancient_and_post-classical_history">
#             <span class="tocnumber">
#              2.1
#             </span>
#             <span class="toctext">
#              Ancient and post-classical history
#             </span>
#            </a>
#           </li>
#           <li class="toclevel-2 tocsection-4">
#            <a href="#Modern_history">
#             <span class="tocnumber">
#              2.2
#             </span>
#             <span class="toctext">
#              Modern history
#             </span>
#            </a>
#           </li>
#           <li class="toclevel-2 tocsection-5">
#            <a href="#Milestones_by_the_billions">
#             <span class="tocnumber">
#              2.3
#             </span>
#             <span class="toctext">
#              Milestones by the billions
#             </span>
#            </a>
#           </li>
#          </ul>
#         </li>
#         <li class="toclevel-1 tocsection-6">
#          <a href="#Global_demographics">
#           <span class="tocnumber">
#            3
#           </span>
#           <span class="toctext">
#            Global demographics
#           </span>
#          </a>
#         </li>
#         <li class="toclevel-1 tocsection-7">
#          <a href="#Largest_populations_by_country">
#           <span class="tocnumber">
#            4
#           </span>
#           <span class="toctext">
#            Largest populations by country
#           </span>
#          </a>
#          <ul>
#           <li class="toclevel-2 tocsection-8">
#            <a href="#10_most_populous_countries">
#             <span class="tocnumber">
#              4.1
#             </span>
#             <span class="toctext">
#              10 most populous countries
#             </span>
#            </a>
#           </li>
#           <li class="toclevel-2 tocsection-9">
#            <a href="#Most_densely_populated_countries">
#             <span class="tocnumber">
#              4.2
#             </span>
#             <span class="toctext">
#              Most densely populated countries
#             </span>
#            </a>
#           </li>
#          </ul>
#         </li>
#         <li class="toclevel-1 tocsection-10">
#          <a href="#Fluctuation">
#           <span class="tocnumber">
#            5
#           </span>
#           <span class="toctext">
#            Fluctuation
#           </span>
#          </a>
#          <ul>
#           <li class="toclevel-2 tocsection-11">
#            <a href="#Annual_population_growth">
#             <span class="tocnumber">
#              5.1
#             </span>
#             <span class="toctext">
#              Annual population growth
#             </span>
#            </a>
#           </li>
#           <li class="toclevel-2 tocsection-12">
#            <a href="#Population_growth_by_region">
#             <span class="tocnumber">
#              5.2
#             </span>
#             <span class="toctext">
#              Population growth by region
#             </span>
#            </a>
#           </li>
#           <li class="toclevel-2 tocsection-13">
#            <a href="#Past_population">
#             <span class="tocnumber">
#              5.3
#             </span>
#             <span class="toctext">
#              Past population
#             </span>
#            </a>
#           </li>
#           <li class="toclevel-2 tocsection-14">
#            <a href="#Projections">
#             <span class="tocnumber">
#              5.4
#             </span>
#             <span class="toctext">
#              Projections
#             </span>
#            </a>
#           </li>
#          </ul>
#         </li>
#         <li class="toclevel-1 tocsection-15">
#          <a href="#Mathematical_approximations">
#           <span class="tocnumber">
#            6
#           </span>
#           <span class="toctext">
#            Mathematical approximations
#           </span>
#          </a>
#          <ul>
#           <li class="toclevel-2 tocsection-16">
#            <a href="#Years_for_world_population_to_double">
#             <span class="tocnumber">
#              6.1
#             </span>
#             <span class="toctext">
#              Years for world population to double
#             </span>
#            </a>
#           </li>
#          </ul>
#         </li>
#         <li class="toclevel-1 tocsection-17">
#          <a href="#Number_of_humans_who_have_ever_lived">
#           <span class="tocnumber">
#            7
#           </span>
#           <span class="toctext">
#            Number of humans who have ever lived
#           </span>
#          </a>
#         </li>
#         <li class="toclevel-1 tocsection-18">
#          <a href="#See_also">
#           <span class="tocnumber">
#            8
#           </span>
#           <span class="toctext">
#            See also
#           </span>
#          </a>
#         </li>
#         <li class="toclevel-1 tocsection-19">
#          <a href="#Explanatory_notes">
#           <span class="tocnumber">
#            9
#           </span>
#           <span class="toctext">
#            Explanatory notes
#           </span>
#          </a>
#         </li>
#         <li class="toclevel-1 tocsection-20">
#          <a href="#References">
#           <span class="tocnumber">
#            10
#           </span>
#           <span class="toctext">
#            References
#           </span>
#          </a>
#         </li>
#         <li class="toclevel-1 tocsection-21">
#          <a href="#Further_reading">
#           <span class="tocnumber">
#            11
#           </span>
#           <span class="toctext">
#            Further reading
#           </span>
#          </a>
#         </li>
#         <li class="toclevel-1 tocsection-22">
#          <a href="#External_links">
#           <span class="tocnumber">
#            12
#           </span>
#           <span class="toctext">
#            External links
#           </span>
#          </a>
#         </li>
#        </ul>
#       </div>
#       <h2>
#        <span class="mw-headline" id="Population_by_region">
#         Population by region
#        </span>
#       </h2>
#       <table class="wikitable floatright" style="font-size:90%">
#        <caption>
#         World population
#         <style data-mw-deduplicate="TemplateStyles:r886047488">
#          .mw-parser-output .nobold{font-weight:normal}
#         </style>
#         <span class="nobold">
#          (millions, UN estimates)
#          <sup class="reference" id="cite_ref-WPP2015total_14-0">
#           <a href="#cite_note-WPP2015total-14">
#            [14]
#           </a>
#          </sup>
#         </span>
#        </caption>
#        <tbody>
#         <tr>
#          <th>
#           #
#          </th>
#          <th>
#           Most populous countries
#          </th>
#          <th>
#           2000
#          </th>
#          <th>
#           2015
#          </th>
#          <th>
#           2030
#           <sup class="reference" id="cite_ref-note-2030_15-0">
#            <a href="#cite_note-note-2030-15">
#             [A]
#            </a>
#           </sup>
#          </th>
#         </tr>
#         <tr>
#          <td style="text-align:right;">
#           1
#          </td>
#          <td style="text-align:left;">
#           <span class="flagicon">
#            <a href="/wiki/China" title="China">
#             <img alt="China" class="thumbborder" data-file-height="600" data-file-width="900" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/commons/thumb/f/fa/Flag_of_the_People%27s_Republic_of_China.svg/23px-Flag_of_the_People%27s_Republic_of_China.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/f/fa/Flag_of_the_People%27s_Republic_of_China.svg/35px-Flag_of_the_People%27s_Republic_of_China.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/f/fa/Flag_of_the_People%27s_Republic_of_China.svg/45px-Flag_of_the_People%27s_Republic_of_China.svg.png 2x" width="23"/>
#            </a>
#           </span>
#           <a href="/wiki/Demographics_of_China" title="Demographics of China">
#            China
#           </a>
#           <sup class="reference" id="cite_ref-china-note_16-0">
#            <a href="#cite_note-china-note-16">
#             [B]
#            </a>
#           </sup>
#          </td>
#          <td style="text-align:right;">
#           1,270
#          </td>
#          <td style="text-align:right;">
#           1,376
#          </td>
#          <td style="text-align:right;">
#           1,416
#          </td>
#         </tr>
#         <tr>
#          <td style="text-align:right;">
#           2
#          </td>
#          <td style="text-align:left;">
#           <span class="flagicon">
#            <a href="/wiki/India" title="India">
#             <img alt="India" class="thumbborder" data-file-height="900" data-file-width="1350" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/en/thumb/4/41/Flag_of_India.svg/23px-Flag_of_India.svg.png" srcset="//upload.wikimedia.org/wikipedia/en/thumb/4/41/Flag_of_India.svg/35px-Flag_of_India.svg.png 1.5x, //upload.wikimedia.org/wikipedia/en/thumb/4/41/Flag_of_India.svg/45px-Flag_of_India.svg.png 2x" width="23"/>
#            </a>
#           </span>
#           <a href="/wiki/Demographics_of_India" title="Demographics of India">
#            India
#           </a>
#          </td>
#          <td style="text-align:right;">
#           1,053
#          </td>
#          <td style="text-align:right;">
#           1,311
#          </td>
#          <td style="text-align:right;">
#           1,528
#          </td>
#         </tr>
#         <tr>
#          <td style="text-align:right;">
#           3
#          </td>
#          <td style="text-align:left;">
#           <span class="flagicon">
#            <a href="/wiki/United_States" title="United States">
#             <img alt="United States" class="thumbborder" data-file-height="650" data-file-width="1235" decoding="async" height="12" src="//upload.wikimedia.org/wikipedia/en/thumb/a/a4/Flag_of_the_United_States.svg/23px-Flag_of_the_United_States.svg.png" srcset="//upload.wikimedia.org/wikipedia/en/thumb/a/a4/Flag_of_the_United_States.svg/35px-Flag_of_the_United_States.svg.png 1.5x, //upload.wikimedia.org/wikipedia/en/thumb/a/a4/Flag_of_the_United_States.svg/46px-Flag_of_the_United_States.svg.png 2x" width="23"/>
#            </a>
#           </span>
#           <a href="/wiki/Demographics_of_the_United_States" title="Demographics of the United States">
#            United States
#           </a>
#          </td>
#          <td style="text-align:right;">
#           283
#          </td>
#          <td style="text-align:right;">
#           322
#          </td>
#          <td style="text-align:right;">
#           356
#          </td>
#         </tr>
#         <tr>
#          <td style="text-align:right;">
#           4
#          </td>
#          <td style="text-align:left;">
#           <span class="flagicon">
#            <a href="/wiki/Indonesia" title="Indonesia">
#             <img alt="Indonesia" class="thumbborder" data-file-height="600" data-file-width="900" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/commons/thumb/9/9f/Flag_of_Indonesia.svg/23px-Flag_of_Indonesia.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/9/9f/Flag_of_Indonesia.svg/35px-Flag_of_Indonesia.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/9/9f/Flag_of_Indonesia.svg/45px-Flag_of_Indonesia.svg.png 2x" width="23"/>
#            </a>
#           </span>
#           <a href="/wiki/Demographics_of_Indonesia" title="Demographics of Indonesia">
#            Indonesia
#           </a>
#          </td>
#          <td style="text-align:right;">
#           212
#          </td>
#          <td style="text-align:right;">
#           258
#          </td>
#          <td style="text-align:right;">
#           295
#          </td>
#         </tr>
#         <tr>
#          <td style="text-align:right;">
#           5
#          </td>
#          <td style="text-align:left;">
#           <span class="flagicon">
#            <a href="/wiki/Pakistan" title="Pakistan">
#             <img alt="Pakistan" class="thumbborder" data-file-height="600" data-file-width="900" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/commons/thumb/3/32/Flag_of_Pakistan.svg/23px-Flag_of_Pakistan.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/3/32/Flag_of_Pakistan.svg/35px-Flag_of_Pakistan.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/3/32/Flag_of_Pakistan.svg/45px-Flag_of_Pakistan.svg.png 2x" width="23"/>
#            </a>
#           </span>
#           <a href="/wiki/Demographics_of_Pakistan" title="Demographics of Pakistan">
#            Pakistan
#           </a>
#          </td>
#          <td style="text-align:right;">
#           136
#          </td>
#          <td style="text-align:right;">
#           208
#          </td>
#          <td style="text-align:right;">
#           245
#          </td>
#         </tr>
#         <tr>
#          <td style="text-align:right;">
#           6
#          </td>
#          <td style="text-align:left;">
#           <span class="flagicon">
#            <a href="/wiki/Brazil" title="Brazil">
#             <img alt="Brazil" class="thumbborder" data-file-height="504" data-file-width="720" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/en/thumb/0/05/Flag_of_Brazil.svg/22px-Flag_of_Brazil.svg.png" srcset="//upload.wikimedia.org/wikipedia/en/thumb/0/05/Flag_of_Brazil.svg/33px-Flag_of_Brazil.svg.png 1.5x, //upload.wikimedia.org/wikipedia/en/thumb/0/05/Flag_of_Brazil.svg/43px-Flag_of_Brazil.svg.png 2x" width="22"/>
#            </a>
#           </span>
#           <a href="/wiki/Demographics_of_Brazil" title="Demographics of Brazil">
#            Brazil
#           </a>
#          </td>
#          <td style="text-align:right;">
#           176
#          </td>
#          <td style="text-align:right;">
#           206
#          </td>
#          <td style="text-align:right;">
#           228
#          </td>
#         </tr>
#         <tr>
#          <td style="text-align:right;">
#           7
#          </td>
#          <td style="text-align:left;">
#           <span class="flagicon">
#            <a href="/wiki/Nigeria" title="Nigeria">
#             <img alt="Nigeria" class="thumbborder" data-file-height="600" data-file-width="1200" decoding="async" height="12" src="//upload.wikimedia.org/wikipedia/commons/thumb/7/79/Flag_of_Nigeria.svg/23px-Flag_of_Nigeria.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/7/79/Flag_of_Nigeria.svg/35px-Flag_of_Nigeria.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/7/79/Flag_of_Nigeria.svg/46px-Flag_of_Nigeria.svg.png 2x" width="23"/>
#            </a>
#           </span>
#           <a href="/wiki/Demographics_of_Nigeria" title="Demographics of Nigeria">
#            Nigeria
#           </a>
#          </td>
#          <td style="text-align:right;">
#           123
#          </td>
#          <td style="text-align:right;">
#           182
#          </td>
#          <td style="text-align:right;">
#           263
#          </td>
#         </tr>
#         <tr>
#          <td style="text-align:right;">
#           8
#          </td>
#          <td style="text-align:left;">
#           <span class="flagicon">
#            <a href="/wiki/Bangladesh" title="Bangladesh">
#             <img alt="Bangladesh" class="thumbborder" data-file-height="600" data-file-width="1000" decoding="async" height="14" src="//upload.wikimedia.org/wikipedia/commons/thumb/f/f9/Flag_of_Bangladesh.svg/23px-Flag_of_Bangladesh.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/f/f9/Flag_of_Bangladesh.svg/35px-Flag_of_Bangladesh.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/f/f9/Flag_of_Bangladesh.svg/46px-Flag_of_Bangladesh.svg.png 2x" width="23"/>
#            </a>
#           </span>
#           <a href="/wiki/Demographics_of_Bangladesh" title="Demographics of Bangladesh">
#            Bangladesh
#           </a>
#          </td>
#          <td style="text-align:right;">
#           131
#          </td>
#          <td style="text-align:right;">
#           161
#          </td>
#          <td style="text-align:right;">
#           186
#          </td>
#         </tr>
#         <tr>
#          <td style="text-align:right;">
#           9
#          </td>
#          <td style="text-align:left;">
#           <span class="flagicon">
#            <a href="/wiki/Russia" title="Russia">
#             <img alt="Russia" class="thumbborder" data-file-height="600" data-file-width="900" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/en/thumb/f/f3/Flag_of_Russia.svg/23px-Flag_of_Russia.svg.png" srcset="//upload.wikimedia.org/wikipedia/en/thumb/f/f3/Flag_of_Russia.svg/35px-Flag_of_Russia.svg.png 1.5x, //upload.wikimedia.org/wikipedia/en/thumb/f/f3/Flag_of_Russia.svg/45px-Flag_of_Russia.svg.png 2x" width="23"/>
#            </a>
#           </span>
#           <a href="/wiki/Demographics_of_Russia" title="Demographics of Russia">
#            Russia
#           </a>
#          </td>
#          <td style="text-align:right;">
#           146
#          </td>
#          <td style="text-align:right;">
#           146
#          </td>
#          <td style="text-align:right;">
#           149
#          </td>
#         </tr>
#         <tr>
#          <td style="text-align:right;">
#           10
#          </td>
#          <td style="text-align:left;">
#           <span class="flagicon">
#            <a href="/wiki/Mexico" title="Mexico">
#             <img alt="Mexico" class="thumbborder" data-file-height="560" data-file-width="980" decoding="async" height="13" src="//upload.wikimedia.org/wikipedia/commons/thumb/f/fc/Flag_of_Mexico.svg/23px-Flag_of_Mexico.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/f/fc/Flag_of_Mexico.svg/35px-Flag_of_Mexico.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/f/fc/Flag_of_Mexico.svg/46px-Flag_of_Mexico.svg.png 2x" width="23"/>
#            </a>
#           </span>
#           <a href="/wiki/Demographics_of_Mexico" title="Demographics of Mexico">
#            Mexico
#           </a>
#          </td>
#          <td style="text-align:right;">
#           103
#          </td>
#          <td style="text-align:right;">
#           127
#          </td>
#          <td style="text-align:right;">
#           148
#          </td>
#         </tr>
#         <tr>
#          <td>
#          </td>
#          <td style="text-align:left;">
#           <b>
#            World total
#           </b>
#          </td>
#          <td style="text-align:right;">
#           6,127
#          </td>
#          <td style="text-align:right;">
#           7,349
#          </td>
#          <td style="text-align:right;">
#           8,501
#          </td>
#         </tr>
#         <tr>
#          <td colspan="5" style="text-align:left;">
#           Notes:
#           <style data-mw-deduplicate="TemplateStyles:r1011085734">
#            .mw-parser-output .reflist{font-size:90%;margin-bottom:0.5em;list-style-type:decimal}.mw-parser-output .reflist .references{font-size:100%;margin-bottom:0;list-style-type:inherit}.mw-parser-output .reflist-columns-2{column-width:30em}.mw-parser-output .reflist-columns-3{column-width:25em}.mw-parser-output .reflist-columns{margin-top:0.3em}.mw-parser-output .reflist-columns ol{margin-top:0}.mw-parser-output .reflist-columns li{page-break-inside:avoid;break-inside:avoid-column}.mw-parser-output .reflist-upper-alpha{list-style-type:upper-alpha}.mw-parser-output .reflist-upper-roman{list-style-type:upper-roman}.mw-parser-output .reflist-lower-alpha{list-style-type:lower-alpha}.mw-parser-output .reflist-lower-greek{list-style-type:lower-greek}.mw-parser-output .reflist-lower-roman{list-style-type:lower-roman}
#           </style>
#           <div class="reflist reflist-upper-alpha">
#            <div class="mw-references-wrap">
#             <ol class="references">
#              <li id="cite_note-note-2030-15">
#               <span class="mw-cite-backlink">
#                <b>
#                 <a href="#cite_ref-note-2030_15-0">
#                  ^
#                 </a>
#                </b>
#               </span>
#               <span class="reference-text">
#                2030 = Medium variant.
#               </span>
#              </li>
#              <li id="cite_note-china-note-16">
#               <span class="mw-cite-backlink">
#                <b>
#                 <a href="#cite_ref-china-note_16-0">
#                  ^
# ...
#          <span>
#           پښتو
#          </span>
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-pl mw-list-item">
#         <a class="interlanguage-link-target" href="https://pl.wikipedia.org/wiki/Ludno%C5%9B%C4%87_%C5%9Bwiata" hreflang="pl" lang="pl" title="Ludność świata – Polish">
#          <span>
#           Polski
#          </span>
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-pt mw-list-item">
#         <a class="interlanguage-link-target" href="https://pt.wikipedia.org/wiki/Popula%C3%A7%C3%A3o_mundial" hreflang="pt" lang="pt" title="População mundial – Portuguese">
#          <span>
#           Português
#          </span>
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-ro mw-list-item">
#         <a class="interlanguage-link-target" href="https://ro.wikipedia.org/wiki/Popula%C8%9Bia_P%C4%83m%C3%A2ntului" hreflang="ro" lang="ro" title="Populația Pământului – Romanian">
#          <span>
#           Română
#          </span>
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-rm mw-list-item">
#         <a class="interlanguage-link-target" href="https://rm.wikipedia.org/wiki/Populaziun_mundiala" hreflang="rm" lang="rm" title="Populaziun mundiala – Romansh">
#          <span>
#           Rumantsch
#          </span>
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-ru mw-list-item">
#         <a class="interlanguage-link-target" href="https://ru.wikipedia.org/wiki/%D0%9D%D0%B0%D1%81%D0%B5%D0%BB%D0%B5%D0%BD%D0%B8%D0%B5_%D0%97%D0%B5%D0%BC%D0%BB%D0%B8" hreflang="ru" lang="ru" title="Население Земли – Russian">
#          <span>
#           Русский
#          </span>
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-sco mw-list-item">
#         <a class="interlanguage-link-target" href="https://sco.wikipedia.org/wiki/Warld_population" hreflang="sco" lang="sco" title="Warld population – Scots">
#          <span>
#           Scots
#          </span>
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-sq mw-list-item">
#         <a class="interlanguage-link-target" href="https://sq.wikipedia.org/wiki/Popullsia_n%C3%AB_Bot%C3%AB" hreflang="sq" lang="sq" title="Popullsia në Botë – Albanian">
#          <span>
#           Shqip
#          </span>
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-si mw-list-item">
#         <a class="interlanguage-link-target" href="https://si.wikipedia.org/wiki/%E0%B6%BD%E0%B7%9D%E0%B6%9A_%E0%B6%A2%E0%B6%B1%E0%B6%9C%E0%B7%84%E0%B6%B1%E0%B6%BA" hreflang="si" lang="si" title="ලෝක ජනගහනය – Sinhala">
#          <span>
#           සිංහල
#          </span>
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-simple mw-list-item">
#         <a class="interlanguage-link-target" href="https://simple.wikipedia.org/wiki/World_population" hreflang="en-simple" lang="en-simple" title="World population – Simple English">
#          <span>
#           Simple English
#          </span>
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-szl mw-list-item">
#         <a class="interlanguage-link-target" href="https://szl.wikipedia.org/wiki/Wjelo%C5%9B%C4%87_lud%C5%BAi" hreflang="szl" lang="szl" title="Wjelość ludźi – Silesian">
#          <span>
#           Ślůnski
#          </span>
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-so mw-list-item">
#         <a class="interlanguage-link-target" href="https://so.wikipedia.org/wiki/Bulshada_aduunka" hreflang="so" lang="so" title="Bulshada aduunka – Somali">
#          <span>
#           Soomaaliga
#          </span>
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-ckb mw-list-item">
#         <a class="interlanguage-link-target" href="https://ckb.wikipedia.org/wiki
"limit":2097152},"expansiondepth":{"value":20,"limit":100},"expensivefunctioncount":{"value":36,"limit":500},"unstrip-depth":{"value":1,"limit":20},"unstrip-size":{"value":476077,"limit":5000000},"entityaccesscount":{"value":1,"limit":400},"timingprofile":["100.00% 2646.662      1 -total"," 34.20%  905.229      3 Template:Reflist"," 16.36%  432.888     90 Template:Cite_web"," 10.70%  283.121     10 Template:Flag+link","  5.60%  148.232      7 Template:Navbox","  3.44%   91.159      1 Template:Navboxes","  3.38%   89.431      5 Template:Poptoday_1","  3.33%   88.176     16 Template:Flagicon","  3.28%   86.735     10 Template:N+p","  3.06%   80.890      1 Template:Short_description"]},"scribunto":{"limitreport-timeusage":{"value":"1.305","limit":"10.000"},"limitreport-memusage":{"value":16329632,"limit":52428800},"limitreport-logs":"table#1 {\n}\n","limitreport-profile":[["?","200","14.3"],["Scribunto_LuaSandboxCallback::callParserFunction","160","11.4"],["Scribunto_LuaSandboxCallback::expandTemplate","120","8.6"],["recursiveClone \u003CmwInit.lua:41\u003E","100","7.1"],["Scribunto_LuaSandboxCallback::getExpandedArgument","80","5.7"],["Scribunto_LuaSandboxCallback::gsub","80","5.7"],["Scribunto_LuaSandboxCallback::getAllExpandedArguments","60","4.3"],["Scribunto_LuaSandboxCallback::match","60","4.3"],["\u003Cmw.title.lua:50\u003E","40","2.9"],["Scribunto_LuaSandboxCallback::plain","40","2.9"],["[others]","460","32.9"]]},"cachereport":{"origin":"mw1402","timestamp":"20220527214504","ttl":1814400,"transientcontent":false}}});});
#   </script>
#   <script type="application/ld+json">
#    {"@context":"https:\/\/schema.org","@type":"Article","name":"World population","url":"https:\/\/en.wikipedia.org\/wiki\/World_population","sameAs":"http:\/\/www.wikidata.org\/entity\/Q11188","mainEntity":"http:\/\/www.wikidata.org\/entity\/Q11188","author":{"@type":"Organization","name":"Contributors to Wikimedia projects"},"publisher":{"@type":"Organization","name":"Wikimedia Foundation, Inc.","logo":{"@type":"ImageObject","url":"https:\/\/www.wikimedia.org\/static\/images\/wmf-hor-googpub.png"}},"datePublished":"2004-03-13T23:02:21Z","dateModified":"2022-05-27T21:45:01Z","image":"https:\/\/upload.wikimedia.org\/wikipedia\/commons\/8\/85\/World-population-1750-2015-and-un-projection-until-2100.png","headline":"total number of living humans on Earth"}
#   </script>
#   <script type="application/ld+json">
#    {"@context":"https:\/\/schema.org","@type":"Article","name":"World population","url":"https:\/\/en.wikipedia.org\/wiki\/World_population","sameAs":"http:\/\/www.wikidata.org\/entity\/Q11188","mainEntity":"http:\/\/www.wikidata.org\/entity\/Q11188","author":{"@type":"Organization","name":"Contributors to Wikimedia projects"},"publisher":{"@type":"Organization","name":"Wikimedia Foundation, Inc.","logo":{"@type":"ImageObject","url":"https:\/\/www.wikimedia.org\/static\/images\/wmf-hor-googpub.png"}},"datePublished":"2004-03-13T23:02:21Z","dateModified":"2022-05-27T21:45:01Z","image":"https:\/\/upload.wikimedia.org\/wikipedia\/commons\/8\/85\/World-population-1750-2015-and-un-projection-until-2100.png","headline":"total number of living humans on Earth"}
#   </script>
#   <script>
#    (RLQ=window.RLQ||[]).push(function(){mw.config.set({"wgBackendResponseTime":140,"wgHostname":"mw1435"});});
#   </script>
#  </body>
# </html>

# %%
# access title tag
tag_obj = soup.title
print("Tag object: ", tag_obj, "Type of the Tag: ", type(tag_obj))
# Out:
# Tag object:  <title>World population - Wikipedia</title> Type of the Tag:  <class 'bs4.element.Tag'>

# %%
# access h3 tag
tag_obj = soup.h3
tag_obj
# Out:
# <h3><span class="mw-headline" id="Ancient_and_post-classical_history">Ancient and post-classical history</span></h3>

# %%
# access div tag
tag_div = soup.div
tag_div
# Out:
# <div class="noprint" id="mw-page-base"></div>

# %%
# access the parent tag of div
tag_parent = tag_div.parent
tag_parent
# Out:
# <body class="mediawiki ltr sitedir-ltr mw-hide-empty-elt ns-0 ns-subject page-World_population rootpage-World_population skin-vector action-view skin-vector-legacy"><div class="noprint" id="mw-page-base"></div>
# <div class="noprint" id="mw-head-base"></div>
# <div class="mw-body" id="content" role="main">
# <a id="top"></a>
# <div id="siteNotice"><!-- CentralNotice --></div>
# <div class="mw-indicators">
# <div class="mw-indicator" id="mw-indicator-pp-default"><a href="/wiki/Wikipedia:Protection_policy#semi" title="This article is semi-protected."><img alt="Page semi-protected" data-file-height="512" data-file-width="512" decoding="async" height="20" src="//upload.wikimedia.org/wikipedia/en/thumb/1/1b/Semi-protection-shackle.svg/20px-Semi-protection-shackle.svg.png" srcset="//upload.wikimedia.org/wikipedia/en/thumb/1/1b/Semi-protection-shackle.svg/30px-Semi-protection-shackle.svg.png 1.5x, //upload.wikimedia.org/wikipedia/en/thumb/1/1b/Semi-protection-shackle.svg/40px-Semi-protection-shackle.svg.png 2x" width="20"/></a></div>
# </div>
# <h1 class="firstHeading mw-first-heading" id="firstHeading">World population</h1>
# <div class="vector-body" id="bodyContent">
# <div class="noprint" id="siteSub">From Wikipedia, the free encyclopedia</div>
# <div id="contentSub"></div>
# <div id="contentSub2"></div>
# <div id="jump-to-nav"></div>
# <a class="mw-jump-link" href="#mw-head">Jump to navigation</a>
# <a class="mw-jump-link" href="#searchInput">Jump to search</a>
# <div class="mw-body-content mw-content-ltr" dir="ltr" id="mw-content-text" lang="en"><div class="mw-parser-output"><div class="shortdescription nomobile noexcerpt noprint searchaux" style="display:none">Total number of living humans on Earth</div>
# <style data-mw-deduplicate="TemplateStyles:r1033289096">.mw-parser-output .hatnote{font-style:italic}.mw-parser-output div.hatnote{padding-left:1.6em;margin-bottom:0.5em}.mw-parser-output .hatnote i{font-style:normal}.mw-parser-output .hatnote+link+.hatnote{margin-top:-0.5em}</style><div class="hatnote navigation-not-searchable" role="note">Not to be confused with <a href="/wiki/Demographics_of_the_world" title="Demographics of the world">Demographics of the world</a>.</div><div class="thumb tright"><div class="thumbinner" style="width:222px;"><a class="image" href="/wiki/File:World-population-1750-2015-and-un-projection-until-2100.png"><img alt="World population growth from 10,000 BCE to 2021" class="thumbimage" data-file-height="2400" data-file-width="3400" decoding="async" height="155" src="//upload.wikimedia.org/wikipedia/commons/thumb/8/85/World-population-1750-2015-and-un-projection-until-2100.png/220px-World-population-1750-2015-and-un-projection-until-2100.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/8/85/World-population-1750-2015-and-un-projection-until-2100.png/330px-World-population-1750-2015-and-un-projection-until-2100.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/8/85/World-population-1750-2015-and-un-projection-until-2100.png/440px-World-population-1750-2015-and-un-projection-until-2100.png 2x" width="220"/></a> <div class="thumbcaption"><div class="magnify"><a class="internal" href="/wiki/File:World-population-1750-2015-and-un-projection-until-2100.png" title="Enlarge"></a></div>World population growth from 10,000 BCE to 2021.<sup class="reference" id="cite_ref-1"><a href="#cite_note-1">[1]</a></sup></div></div></div>
# <p class="mw-empty-elt">
# </p>
# <div class="thumb tright"><div class="thumbinner" style="width:222px;"><a class="image" href="/wiki/File:World_Population_Prospects_2019.png"><img alt="" class="thumbimage" data-file-height="731" data-file-width="975" decoding="async" height="165" src="//upload.wikimedia.org/wikipedia/commons/thumb/e/e5/World_Population_Prospects_2019.png/220px-World_Population_Prospects_2019.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/e/e5/World_Population_Prospects_2019.png/330px-World_Population_Prospects_2019.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/e/e5/World_Population_Prospects_2019.png/440px-World_Population_Prospects_2019.png 2x" width="220"/></a> <div class="thumbcaption"><div class="magnify"><a class="internal" href="/wiki/File:World_Population_Prospects_2019.png" title="Enlarge"></a></div>High, medium, and low projections of the future human world population<sup class="reference" id="cite_ref-:4_2-0"><a href="#cite_note-:4-2">[2]</a></sup></div></div></div>
# <p>In <a href="/wiki/Demography" title="Demography">demographics</a>, the term <b>world population</b> is often used to refer to the total number of <a href="/wiki/Human" title="Human">humans</a> currently living, and was estimated to have exceeded 7.9 billion as of November 2021<sup class="plainlinks noexcerpt noprint asof-tag update" style="display:none;"><a class="external text" href="https://en.wikipedia.org/w/index.php?title=World_population&amp;action=edit">[update]</a></sup>.<sup class="reference" id="cite_ref-:6_3-0"><a href="#cite_note-:6-3">[3]</a></sup> It took over two million years of <a href="/wiki/Prehistory" title="Prehistory">human prehistory</a> and <a href="/wiki/Human_history" title="Human history">history</a> for the human population to reach one <a href="/wiki/Billion" title="Billion">billion</a> and only 207 years more to grow to 7 billion.<sup class="reference" id="cite_ref-4"><a href="#cite_note-4">[4]</a></sup>
# </p><p>The human population has experienced <a href="/wiki/Population_growth" title="Population growth">continuous growth</a> following the <a href="/wiki/Great_Famine_of_1315%E2%80%931317" title="Great Famine of 1315–1317">Great Famine of 1315–1317</a> and the end of the <a href="/wiki/Black_Death" title="Black Death">Black Death</a> in 1350, when it was near 370,000,000.<sup class="reference" id="cite_ref-5"><a href="#cite_note-5">[5]</a></sup> The highest global <a class="mw-redirect" href="/wiki/Population_growth_rates" title="Population growth rates">population growth rates</a>, with increases of over 1.8% per year, occurred between 1955 and 1975 – peaking at 2.1% between 1965 and 1970.<sup class="reference" id="cite_ref-:1_6-0"><a href="#cite_note-:1-6">[6]</a></sup> The growth rate declined to 1.1% between 2015 and 2020 and is projected to decline further in the course of the 21st century.<sup class="reference" id="cite_ref-7"><a href="#cite_note-7">[7]</a></sup><sup class="reference" id="cite_ref-:5_8-0"><a href="#cite_note-:5-8">[8]</a></sup> The global population is still increasing, but there is significant uncertainty about its long-term trajectory due to changing rates of fertility and mortality.<sup class="reference" id="cite_ref-9"><a href="#cite_note-9">[9]</a></sup> The <a href="/wiki/United_Nations_Department_of_Economic_and_Social_Affairs" title="United Nations Department of Economic and Social Affairs">UN Department of Economics and Social Affairs</a> projects between 9 and 10 billion people by 2050, and gives an 80% confidence interval of 10–12 billion by the end of the 21st century,<sup class="reference" id="cite_ref-:4_2-1"><a href="#cite_note-:4-2">[2]</a></sup> with a growth rate by then of zero.<sup class="reference" id="cite_ref-:5_8-1"><a href="#cite_note-:5-8">[8]</a></sup> Other demographers predict that the human population will begin to decline in the second half of the 21st century.<sup class="reference" id="cite_ref-10"><a href="#cite_note-10">[10]</a></sup>
# </p><p>The total number of births globally is currently (2015-20) 140 million/year, is projected to peak during the period 2040-45 at 141 million/year and thereafter decline slowly to 126 million/year by 2100.<sup class="reference" id="cite_ref-:2_11-0"><a href="#cite_note-:2-11">[11]</a></sup> The total number of deaths is currently 57 million/year and is projected to grow steadily to 121 million/year by 2100.<sup class="reference" id="cite_ref-:3_12-0"><a href="#cite_note-:3-12">[12]</a></sup>
# </p><p>The <a class="mw-redirect" href="/wiki/Median_age" title="Median age">median age</a> of human beings as of 2020 is 31 years.<sup class="reference" id="cite_ref-:0_13-0"><a href="#cite_note-:0-13">[13]</a></sup>
# </p>
# <div aria-labelledby="mw-toc-heading" class="toc" id="toc" role="navigation"><input class="toctogglecheckbox" id="toctogglecheckbox" role="button" style="display:none" type="checkbox"/><div class="toctitle" dir="ltr" lang="en"><h2 id="mw-toc-heading">Contents</h2><span class="toctogglespan"><label class="toctogglelabel" for="toctogglecheckbox"></label></span></div>
# <ul>
# <li class="toclevel-1 tocsection-1"><a href="#Population_by_region"><span class="tocnumber">1</span> <span class="toctext">Population by region</span></a></li>
# <li class="toclevel-1 tocsection-2"><a href="#History"><span class="tocnumber">2</span> <span class="toctext">History</span></a>
# <ul>
# <li class="toclevel-2 tocsection-3"><a href="#Ancient_and_post-classical_history"><span class="tocnumber">2.1</span> <span class="toctext">Ancient and post-classical history</span></a></li>
# <li class="toclevel-2 tocsection-4"><a href="#Modern_history"><span class="tocnumber">2.2</span> <span class="toctext">Modern history</span></a></li>
# <li class="toclevel-2 tocsection-5"><a href="#Milestones_by_the_billions"><span class="tocnumber">2.3</span> <span class="toctext">Milestones by the billions</span></a></li>
# </ul>
# </li>
# <li class="toclevel-1 tocsection-6"><a href="#Global_demographics"><span class="tocnumber">3</span> <span class="toctext">Global demographics</span></a></li>
# <li class="toclevel-1 tocsection-7"><a href="#Largest_populations_by_country"><span class="tocnumber">4</span> <span class="toctext">Largest populations by country</span></a>
# <ul>
# <li class="toclevel-2 tocsection-8"><a href="#10_most_populous_countries"><span class="tocnumber">4.1</span> <span class="toctext">10 most populous countries</span></a></li>
# <li class="toclevel-2 tocsection-9"><a href="#Most_densely_populated_countries"><span class="tocnumber">4.2</span> <span class="toctext">Most densely populated countries</span></a></li>
# </ul>
# </li>
# <li class="toclevel-1 tocsection-10"><a href="#Fluctuation"><span class="tocnumber">5</span> <span class="toctext">Fluctuation</span></a>
# <ul>
# <li class="toclevel-2 tocsection-11"><a href="#Annual_population_growth"><span class="tocnumber">5.1</span> <span class="toctext">Annual population growth</span></a></li>
# <li class="toclevel-2 tocsection-12"><a href="#Population_growth_by_region"><span class="tocnumber">5.2</span> <span class="toctext">Population growth by region</span></a></li>
# <li class="toclevel-2 tocsection-13"><a href="#Past_population"><span class="tocnumber">5.3</span> <span class="toctext">Past population</span></a></li>
# <li class="toclevel-2 tocsection-14"><a href="#Projections"><span class="tocnumber">5.4</span> <span class="toctext">Projections</span></a></li>
# </ul>
# </li>
# <li class="toclevel-1 tocsection-15"><a href="#Mathematical_approximations"><span class="tocnumber">6</span> <span class="toctext">Mathematical approximations</span></a>
# <ul>
# <li class="toclevel-2 tocsection-16"><a href="#Years_for_world_population_to_double"><span class="tocnumber">6.1</span> <span class="toctext">Years for world population to double</span></a></li>
# </ul>
# </li>
# <li class="toclevel-1 tocsection-17"><a href="#Number_of_humans_who_have_ever_lived"><span class="tocnumber">7</span> <span class="toctext">Number of humans who have ever lived</span></a></li>
# <li class="toclevel-1 tocsection-18"><a href="#See_also"><span class="tocnumber">8</span> <span class="toctext">See also</span></a></li>
# <li class="toclevel-1 tocsection-19"><a href="#Explanatory_notes"><span class="tocnumber">9</span> <span class="toctext">Explanatory notes</span></a></li>
# <li class="toclevel-1 tocsection-20"><a href="#References"><span class="tocnumber">10</span> <span class="toctext">References</span></a></li>
# <li class="toclevel-1 tocsection-21"><a href="#Further_reading"><span class="tocnumber">11</span> <span class="toctext">Further reading</span></a></li>
# <li class="toclevel-1 tocsection-22"><a href="#External_links"><span class="tocnumber">12</span> <span class="toctext">External links</span></a></li>
# </ul>
# </div>
# <h2><span class="mw-headline" id="Population_by_region">Population by region</span></h2>
# <table class="wikitable floatright" style="font-size:90%">
# <caption>World population <style data-mw-deduplicate="TemplateStyles:r886047488">.mw-parser-output .nobold{font-weight:normal}</style><span class="nobold">(millions, UN estimates)<sup class="reference" id="cite_ref-WPP2015total_14-0"><a href="#cite_note-WPP2015total-14">[14]</a></sup></span>
# </caption>
# <tbody><tr>
# <th>#
# </th>
# <th>Most populous countries
# </th>
# <th>2000
# </th>
# <th>2015
# </th>
# <th>2030<sup class="reference" id="cite_ref-note-2030_15-0"><a href="#cite_note-note-2030-15">[A]</a></sup>
# </th></tr>
# <tr>
# <td style="text-align:right;">1</td>
# <td style="text-align:left;"><span class="flagicon"><a href="/wiki/China" title="China"><img alt="China" class="thumbborder" data-file-height="600" data-file-width="900" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/commons/thumb/f/fa/Flag_of_the_People%27s_Republic_of_China.svg/23px-Flag_of_the_People%27s_Republic_of_China.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/f/fa/Flag_of_the_People%27s_Republic_of_China.svg/35px-Flag_of_the_People%27s_Republic_of_China.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/f/fa/Flag_of_the_People%27s_Republic_of_China.svg/45px-Flag_of_the_People%27s_Republic_of_China.svg.png 2x" width="23"/></a></span> <a href="/wiki/Demographics_of
w-parser-output .reflist{font-size:90%;margin-bottom:0.5em;list-style-type:decimal}.mw-parser-output .reflist .references{font-size:100%;margin-bottom:0;list-style-type:inherit}.mw-parser-output .reflist-columns-2{column-width:30em}.mw-parser-output .reflist-columns-3{column-width:25em}.mw-parser-output .reflist-columns{margin-top:0.3em}.mw-parser-output .reflist-columns ol{margin-top:0}.mw-parser-output .reflist-columns li{page-break-inside:avoid;break-inside:avoid-column}.mw-parser-output .reflist-upper-alpha{list-style-type:upper-alpha}.mw-parser-output .reflist-upper-roman{list-style-type:upper-roman}.mw-parser-output .reflist-lower-alpha{list-style-type:lower-alpha}.mw-parser-output .reflist-lower-greek{list-style-type:lower-greek}.mw-parser-output .reflist-lower-roman{list-style-type:lower-roman}</style><div class="reflist reflist-upper-alpha">
# <div class="mw-references-wrap"><ol class="references">
# <li id="cite_note-note-2030-15"><span class="mw-cite-backlink"><b><a href="#cite_ref-note-2030_15-0">^</a></b></span> <span class="reference-text">2030 = Medium variant.</span>
# </li>
# <li id="cite_note-china-note-16"><span class="mw-cite-backlink"><b><a href="#cite_ref-china-note_16-0">^</a></b></span> <span class="reference-text">China excludes <a href="/wiki/Hong_Kong" title="Hong Kong">Hong Kong</a> and <a href="/wiki/Macau" title="Macau">Macau</a>.</span>
# </li>
# </ol></div></div>
# </td></tr></tbody></table>
# <p>Six of the Earth's seven <a href="/wiki/Continent" title="Continent">continents</a> are permanently inhabited on a large scale. Asia is the most populous continent, with its 4.64 billion inhabitants accounting for 60% of the world population. The world's two most populated countries, China and India, together constitute about 36% of the world's population. Africa is the second most populated continent, with around 1.34 billion people, or 17% of the world's population. Europe's 747 million people make up 10% of the world's population as of 2020, while the <a class="mw-redirect" href="/wiki/Latin_American" title="Latin American">Latin American</a> and <a href="/wiki/Caribbean" title="Caribbean">Caribbean</a> regions are home to around 653 million (8%). Northern America, primarily consisting of the United States and Canada, has a population of around 368 million (5%), and <a href="/wiki/Oceania" title="Oceania">Oceania</a>, the least populated region, has about 42 million inhabitants (0.5%).<sup class="reference" id="cite_ref-17"><a href="#cite_note-17">[15]</a></sup> <a href="/wiki/Antarctica" title="Antarctica">Antarctica</a> only has a very small, fluctuating population of about 1200 people based mainly in polar <a href="/wiki/Research_stations_in_Antarctica" title="Research stations in Antarctica">science stations</a>.<sup class="reference" id="cite_ref-AntarcticCIA_18-0"><a href="#cite_note-AntarcticCIA-18">[16]</a></sup>
# </p>
# <table class="wikitable sortable">
# <caption>Population by region (2020 estimates)
# </caption>
# <tbody><tr>
# <th>Region
# </th>
# <th>Density<br/><small>(inhabitants/km<sup>2</sup>)</small>
# </th>
# <th>Population<br/><small>(millions)</small>
# </th>
# <th>Most populous country
# </th>
# <th>Most populous city (metropolitan area)
# </th></tr>
# <tr>
# <td>Asia
# </td>
# <td style="text-align:right">104.1
# </td>
# <td style="text-align:right">4,641
# </td>
# <td>1,411,778,000<sup class="reference" id="cite_ref-19"><a href="#cite_note-19">[note 1]</a></sup> – <span class="flagicon"><img alt="" class="thumbborder" data-file-height="600" data-file-width="900" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/commons/thumb/f/fa/Flag_of_the_People%27s_Republic_of_China.svg/23px-Flag_of_the_People%27s_Republic_of_China.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/f/fa/Flag_of_the_People%27s_Republic_of_China.svg/35px-Flag_of_the_People%27s_Republic_of_China.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/f/fa/Flag_of_the_People%27s_Republic_of_China.svg/45px-Flag_of_the_People%27s_Republic_of_China.svg.png 2x" width="23"/> </span><a href="/wiki/China" title="China">China</a>
# </td>
# <td>37,400,000/13,515,000 – <span class="flagicon"><a href="/wiki/Japan" title="Japan"><img alt="Japan" class="thumbborder" data-file-height="600" data-file-width="900" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/en/thumb/9/9e/Flag_of_Japan.svg/23px-Flag_of_Japan.svg.png" srcset="//upload.wikimedia.org/wikipedia/en/thumb/9/9e/Flag_of_Japan.svg/35px-Flag_of_Japan.svg.png 1.5x, //upload.wikimedia.org/wikipedia/en/thumb/9/9e/Flag_of_Japan.svg/45px-Flag_of_Japan.svg.png 2x" width="23"/></a></span> <a href="/wiki/Greater_Tokyo_Area" title="Greater Tokyo Area">Greater Tokyo Area</a>/<a href="/wiki/Tokyo" title="Tokyo">Tokyo Metropolis</a>
# </td></tr>
# <tr>
# <td>Africa
# </td>
# <td style="text-align:right">44.4
# </td>
# <td style="text-align:right">1,340
# </td>
# <td><span style="visibility:hidden;color:transparent;">0</span>211,401,000 – <span class="flagicon"><img alt="" class="thumbborder" data-file-height="600" data-file-width="1200" decoding="async" height="12" src="//upload.wikimedia.org/wikipedia/commons/thumb/7/79/Flag_of_Nigeria.svg/23px-Flag_of_Nigeria.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/7/79/Flag_of_Nigeria.svg/35px-Flag_of_Nigeria.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/7/79/Flag_of_Nigeria.svg/46px-Flag_of_Nigeria.svg.png 2x" width="23"/> </span><a href="/wiki/Nigeria" title="Nigeria">Nigeria</a>
# </td>
# <td>20,076,000/9,500,000 – <span class="flagicon"><a href="/wiki/Egypt" title="Egypt"><img alt="Egypt" class="thumbborder" data-file-height="600" data-file-width="900" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/commons/thumb/f/fe/Flag_of_Egypt.svg/23px-Flag_of_Egypt.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/f/fe/Flag_of_Egypt.svg/35px-Flag_of_Egypt.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/f/fe/Flag_of_Egypt.svg/45px-Flag_of_Egypt.svg.png 2x" width="23"
></h2>
# <div class="thumb tright"><div class="thumbinner" style="width:222px;"><a class="image" href="/wiki/File:Illustration_of_contemporary_and_past_human_populations_Our_World_in_Data.png"><img alt="" class="thumbimage" data-file-height="7747" data-file-width="5201" decoding="async" height="328" src="//upload.wikimedia.org/wikipedia/commons/thumb/d/d2/Illustration_of_contemporary_and_past_human_populations_Our_World_in_Data.png/220px-Illustration_of_contemporary_and_past_human_populations_Our_World_in_Data.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/d/d2/Illustration_of_contemporary_and_past_human_populations_Our_World_in_Data.png/330px-Illustration_of_contemporary_and_past_human_populations_Our_World_in_Data.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/d/d2/Illustration_of_contemporary_and_past_human_populations_Our_World_in_Data.png/440px-Illustration_of_contemporary_and_past_human_populations_Our_World_in_Data.png 2x" width="220"/></a> <div class="thumbcaption"><div class="magnify"><a class="internal" href="/wiki/File:Illustration_of_contemporary_and_past_human_populations_Our_World_in_Data.png" title="Enlarge"></a></div>Visual comparison of the world population in past and present</div></div></div>
# <link href="mw-data:TemplateStyles:r1033289096" rel="mw-deduplicated-inline-style"/><div class="hatnote navigation-not-searchable" role="note">Further information: <a href="/wiki/Estimates_of_historical_world_population" title="Estimates of historical world population">Estimates of historical world population</a> and <a href="/wiki/Human_history" title="Human history">Human history</a></div>
# <p>Estimates of world population by their nature are an aspect of <a href="/wiki/Modernity" title="Modernity">modernity</a>, possible only since the <a href="/wiki/Age_of_Discovery" title="Age of Discovery">Age of Discovery</a>. Early estimates for the population of the world<sup class="reference" id="cite_ref-23"><a href="#cite_note-23">[18]</a></sup> date to the 17th century: <a href="/wiki/William_Petty" title="William Petty">William Petty</a> in 1682 estimated world population at 320 million (modern estimates ranging close to twice this number); by the late 18th century, estimates ranged close to one billion (consistent with modern estimates).<sup class="reference" id="cite_ref-24"><a href="#cite_note-24">[19]</a></sup> More refined estimates, broken down by continents, were published in the first half of the 19th century, at 600 million to 1 billion in the early 1800s and at 800 million to 1 billion in the 1840s.<sup class="reference" id="cite_ref-25"><a href="#cite_note-25">[20]</a></sup>
# </p><p>It is difficult for estimates to be better than rough approximations, as even modern population estimates are fraught with uncertainties on the order of 3% to 5%.<sup class="reference" id="cite_ref-Kapitza2_26-0"><a href="#cite_note-Kapitza2-26">[21]</a></sup>
# </p>
# <h3><span class="mw-headline" id="Ancient_and_post-classical_history">Ancient and post-classical history</span></h3>
# <link href="mw-data:TemplateStyles:r1033289096" rel="mw-deduplicated-inline-style"/><div class="hatnote navigation-not-searchable" role="note">Main articles: <a href="/wiki/Classical_demography" title="Classical demography">Classical demography</a> and <a href="/wiki/Medieval_demography" title="Medieval demography">Medieval demography</a></div>
# <p>Estimates of the population of the world at the time agriculture emerged in around 10,000 BC have ranged between 1 million and 15 million.<sup class="reference" id="cite_ref-27"><a href="#cite_note-27">[22]</a></sup><sup class="reference" id="cite_ref-28"><a href="#cite_note-28">[23]</a></sup> Even earlier, genetic evidence suggests humans may have gone through a population bottleneck of between 1,000 and 10,000 people about 70,000 BC, according to the <a class="mw-redirect" href="/wiki/Lake_Toba_genetic_bottleneck" title="Lake Toba genetic bottleneck">Toba catastrophe theory</a>. By contrast, it is estimated that around 50–60 million people lived in the combined eastern and western <a href="/wiki/Roman_Empire" title="Roman Empire">Roman Empire</a> in the 4th century AD.<sup class="reference" id="cite_ref-29"><a href="#cite_note-29">[24]</a></sup>
# </p><p>The <a href="/wiki/Plague_of_Justinian" title="Plague of Justinian">Plague of Justinian</a>, which first emerged during the reign of the <a href="/wiki/Roman_emperor" title="Roman emperor">Roman emperor</a> <a class="mw-redirect" href="/wiki/Justinian" title="Justinian">Justinian</a>, caused Europe's population to drop by around 50% between the 6th and 8th centuries AD.<sup class="reference" id="cite_ref-30"><a href="#cite_note-30">[25]</a></sup> The population of Europe was more than 70 million in 1340.<sup class="reference" id="cite_ref-31"><a href="#cite_note-31">[26]</a></sup> From 1340 to 1400, the world's population fell from an estimated 443 million to 350-375 million,<sup class="reference" id="cite_ref-32"><a href="#cite_note-32">[27]</a></sup> with the <a href="/wiki/Indian_subcontinent" title="Indian subcontinent">Indian subcontinent</a> suffering the greatest loss and Europe suffering the <a href="/wiki/Black_Death" title="Black Death">Black Death</a> <a href="/wiki/Pandemic" title="Pandemic">pandemic</a>;<sup class="reference" id="cite_ref-Essai_sur_l'évolution_du_nombre_des_hommes_33-0"><a href="#cite_note-Essai_sur_l'évolution_du_nombre_des_hommes-33">[28]</a></sup> it took 200 years for European population figures to recover.<sup class="reference" id="cite_ref-34"><a href="#cite_note-34">[29]</a></sup> The population of China decreased from 123 million in 1200 to 65 million in 1393,<sup class="reference" id="cite_ref-35"><a href="#cite_note-35">[30]</a></sup> presumably from a combination of <a href="/wiki/Mongol_Empire" title="Mongol Empire">Mongol</a> invasions, famine, and plague.<sup class="reference" id="cite_ref-36"><a href="#cite_note-36">[31]</a></sup>
# </p><p>Starting in AD 2, the <a href="/wiki/Han_dynasty" title="Han dynasty">Han dynasty</a> of <a class="mw-redirect" href="/wiki/Ancient_China" title="Ancient China">ancient China</a> kept consistent family registers in order to properly assess the poll taxes and labor service duties of each household.<sup class="reference" id="cite_ref-nishijima_1986_pp595-96_37-0"><a href="#cite_note-nishijima_1986_pp595-96-37">[32]</a></sup> In that year, the population of <a class="mw-redirect" href="/wiki/Western_Han" title="Western Han">Western Han</a> was recorded as 57,671,400 individuals in 12,366,470 households, decreasing to 47,566,772 individuals in 9,348,227 households by AD 146, towards the <a href="/wiki/End_of_the_Han_dynasty" title="End of the Han dynasty">End of the Han dynasty</a>.<sup class="reference" id="cite_ref-nishijima_1986_pp595-96_37-1"><a href="#cite_note-nishijima_1986_pp595-96-37">[32]</a></sup> From 200 to 400, the world population fell from an estimated 257 million to 206 million, with China suffering the greatest loss.<sup class="reference" id="cite_ref-Essai_sur_l'évolution_du_nombre_des_hommes_33-1"><a href="#cite_note-Essai_sur_l'évolution_du_nombre_des_hommes-33">[28]</a></sup> At the founding of the <a href="/wiki/Ming_dynasty" title="Ming dynasty">Ming dynasty</a> in 1368, China's population was reported to be close to 60 million; toward the end of the dynasty in 1644, it may have approached 150 million.<sup class="reference" id="cite_ref-38"><a href="#cite_note-38">[33]</a></sup> England's population reached an estimated 5.6 million in 1650, up from an estimated 2.6 million in 1500.<sup class="reference" id="cite_ref-39"><a href="#cite_note-39">[34]</a></sup> New crops that were brought to Asia and Europe from the Americas by Portuguese and Spanish colonists in the 16th century are believed to have contributed to population growth.<sup class="reference" id="cite_ref-40"><a href="#cite_note-40">[35]</a></sup><sup class="reference" id="cite_ref-41"><a href="#cite_note-41">[36]</a></sup><sup class="reference" id="cite_ref-42"><a href="#cite_note-42">[37]</a></sup> Since their introduction to Africa by Portuguese traders in the 16th century,<sup class="reference" id="cite_ref-43"><a href="#cite_note-43">[38]</a></sup> <a href="/wiki/Maize" title="Maize">maize</a> and <a href="/wiki/Cassava" title="Cassava">cassava</a> have similarly replaced traditional African crops as the most important <a href="/wiki/Staple_food" title="Staple food">staple food</a> crops grown on the continent.<sup class="reference" id="cite_ref-44"><a href="#cite_note-44">[39]</a></sup>
# </p><p>The <a href="/wiki/Pre-Columbian_era" title="Pre-Columbian era">pre-Columbian</a> population of the Americas is uncertain; historian David Henige called it "the most unanswerable question in the world."<sup class="reference" id="cite_ref-45"><a href="#cite_note-45">[40]</a></sup> By the end of the 20th century, scholarly consensus favored an estimate of roughly 55 million people, but numbers from various sources have ranged from 10 million to 100 million.<sup class="reference" id="cite_ref-46"><a href="#cite_note-46">[41]</a></sup> Encounters between European explorers and populations in the rest of the world often introduced local <a href="/wiki/List_of_epidemics" title="List of epidemics">epidemics</a> of extraordinary virulence.<sup class="reference" id="cite_ref-47"><a href="#cite_note-47">[42]</a></sup> According to the most extreme scholarly claims, as many as 90% of the <a class="mw-redirect" href="/wiki/Population_history_of_indigenous_peoples_of_the_Americas" title="Population history of indigenous peoples of the Americas">Native American population</a> of the <a href="/wiki/New_World" title="New World">New World</a> died of <a href="/wiki/Old_World" title="Old World">Old World</a> diseases such as <a href="/wiki/Smallpox" title="Smallpox">smallpox</a>, <a href="/wiki/Measles" title="Measles">measles</a>, and <a href="/wiki/Influenza" title="Influenza">influenza</a>.<sup class="reference" id="cite_ref-48"><a href="#cite_note-48">[43]</a></sup> Over the centuries, the Europeans had developed high degrees of immunity to these diseases, while the indigenous peoples had no such immunity.<sup class="reference" id="cite_ref-49"><a href="#cite_note-49">[44]</a></sup>
# </p>
# <h3><span class="mw-headline" id="Modern_history">Modern history</span></h3>
# <div class="thumb tright"><div class="thumbinner" style="width
Czech"><span>Čeština</span></a></li><li class="interlanguage-link interwiki-da mw-list-item"><a class="interlanguage-link-target" href="https://da.wikipedia.org/wiki/Verdens_befolkning" hreflang="da" lang="da" title="Verdens befolkning – Danish"><span>Dansk</span></a></li><li class="interlanguage-link interwiki-de mw-list-item"><a class="interlanguage-link-target" href="https://de.wikipedia.org/wiki/Weltbev%C3%B6lkerung" hreflang="de" lang="de" title="Weltbevölkerung – German"><span>Deutsch</span></a></li><li class="interlanguage-link interwiki-et mw-list-item"><a class="interlanguage-link-target" href="https://et.wikipedia.org/wiki/Maailma_rahvaarv" hreflang="et" lang="et" title="Maailma rahvaarv – Estonian"><span>Eesti</span></a></li><li class="interlanguage-link interwiki-el mw-list-item"><a class="interlanguage-link-target" href="https://el.wikipedia.org/wiki/%CE%A0%CE%B1%CE%B3%CE%BA%CF%8C%CF%83%CE%BC%CE%B9%CE%BF%CF%82_%CF%80%CE%BB%CE%B7%CE%B8%CF%85%CF%83%CE%BC%CF%8C%CF%82" hreflang="el" lang="el" title="Παγκόσμιος πληθυσμός – Greek"><span>Ελληνικά</span></a></li><li class="interlanguage-link interwiki-es mw-li ...
# <div class="after-portlet after-portlet-lang"><span class="wb-langlinks-edit wb-langlinks-link"><a class="wbc-editpage" href="https://www.wikidata.org/wiki/Special:EntityPage/Q11188#sitelinks-wikipedia" title="Edit interlanguage links">Edit links</a></span></div>
# </div>
# </nav>
# </div>
# </div>
# <footer class="mw-footer" id="footer" role="contentinfo">
# <ul id="footer-info">
# <li id="footer-info-lastmod"> This page was last edited on 27 May 2022, at 21:45<span class="anonymous-show"> (UTC)</span>.</li>
# <li id="footer-info-copyright">Text is available under the <a href="//en.wikipedia.org/wiki/Wikipedia:Text_of_Creative_Commons_Attribution-ShareAlike_3.0_Unported_License" rel="license">Creative Commons Attribution-ShareAlike License 3.0</a><a href="//creativecommons.org/licenses/by-sa/3.0/" rel="license" style="display:none;"></a>;
# additional terms may apply.  By using this site, you agree to the <a href="//foundation.wikimedia.org/wiki/Terms_of_Use">Terms of Use</a> and <a href="//foundation.wikimedia.org/wiki/Privacy_policy">Privacy Policy</a>. Wikipedia® is a registered trademark of the <a href="//www.wikimediafoundation.org/">Wikimedia Foundation, Inc.</a>, a non-profit organization.</li>
# </ul>
# <ul id="footer-places">
# <li id="footer-places-privacy"><a class="extiw" href="https://foundation.wikimedia.org/wiki/Privacy_policy" title="wmf:Privacy policy">Privacy policy</a></li>
# <li id="footer-places-about"><a href="/wiki/Wikipedia:About" title="Wikipedia:About">About Wikipedia</a></li>
# <li id="footer-places-disclaimer"><a href="/wiki/Wikipedia:General_disclaimer" title="Wikipedia:General disclaimer">Disclaimers</a></li>
# <li id="footer-places-contact"><a href="//en.wikipedia.org/wiki/Wikipedia:Contact_us">Contact Wikipedia</a></li>
# <li id="footer-places-mobileview"><a class="noprint stopMobileRedirectToggle" href="//en.m.wikipedia.org/w/index.php?title=World_population&amp;mobileaction=toggle_view_mobile">Mobile view</a></li>
# <li id="footer-places-developers"><a href="https://www.mediawiki.org/wiki/Special:MyLanguage/How_to_contribute">Developers</a></li>
# <li id="footer-places-statslink"><a href="https://stats.wikimedia.org/#/en.wikipedia.org">Statistics</a></li>
# <li id="footer-places-cookiestatement"><a href="https://foundation.wikimedia.org/wiki/Cookie_statement">Cookie statement</a></li>
# </ul>
# <ul class="noprint" id="footer-icons">
# <li id="footer-copyrightico"><a href="https://wikimediafoundation.org/"><img alt="Wikimedia Foundation" height="31" loading="lazy" src="/static/images/footer/wikimedia-button.png" srcset="/static/images/footer/wikimedia-button-1.5x.png 1.5x, /static/images/footer/wikimedia-button-2x.png 2x" width="88"/></a></li>
# <li id="footer-poweredbyico"><a href="https://www.mediawiki.org/"><img alt="Powered by MediaWiki" height="31" loading="lazy" src="/static/images/footer/poweredby_mediawiki_88x31.png" srcset="/static/images/footer/poweredby_mediawiki_132x47.png 1.5x, /static/images/footer/poweredby_mediawiki_176x62.png 2x" width="88"/></a></li>
# </ul>
# </footer>
# <script>(RLQ=window.RLQ||[]).push(function(){mw.config.set({"wgPageParseReport":{"limitreport":{"cputime":"2.838","walltime":"3.241","ppvisitednodes":{"value":20428,"limit":1000000},"postexpandincludesize":{"value":510587,"limit":2097152},"templateargumentsize":{"value":73671,"limit":2097152},"expansiondepth":{"value":20,"limit":100},"expensivefunctioncount":{"value":36,"limit":500},"unstrip-depth":{"value":1,"limit":20},"unstrip-size":{"value":476077,"limit":5000000},"entityaccesscount":{"value":1,"limit":400},"timingprofile":["100.00% 2646.662      1 -total"," 34.20%  905.229      3 Template:Reflist"," 16.36%  432.888     90 Template:Cite_web"," 10.70%  283.121     10 Template:Flag+link","  5.60%  148.232      7 Template:Navbox","  3.44%   91.159      1 Template:Navboxes","  3.38%   89.431      5 Template:Poptoday_1","  3.33%   88.176     16 Template:Flagicon","  3.28%   86.735     10 Template:N+p","  3.06%   80.890      1 Template:Short_description"]},"scribunto":{"limitreport-timeusage":{"value":"1.305","limit":"10.000"},"limitreport-memusage":{"value":16329632,"limit":52428800},"limitreport-logs":"table#1 {\n}\n","limitreport-profile":[["?","200","14.3"],["Scribunto_LuaSandboxCallback::callParserFunction","160","11.4"],["Scribunto_LuaSandboxCallback::expandTemplate","120","8.6"],["recursiveClone \u003CmwInit.lua:41\u003E","100","7.1"],["Scribunto_LuaSandboxCallback::getExpandedArgument","80","5.7"],["Scribunto_LuaSandboxCallback::gsub","80","5.7"],["Scribunto_LuaSandboxCallback::getAllExpandedArguments","60","4.3"],["Scribunto_LuaSandboxCallback::match","60","4.3"],["\u003Cmw.title.lua:50\u003E","40","2.9"],["Scribunto_LuaSandboxCallback::plain","40","2.9"],["[others]","460","32.9"]]},"cachereport":{"origin":"mw1402","timestamp":"20220527214504","ttl":1814400,"transientcontent":false}}});});</script>
# <script type="application/ld+json">{"@context":"https:\/\/schema.org","@type":"Article","name":"World population","url":"https:\/\/en.wikipedia.org\/wiki\/World_population","sameAs":"http:\/\/www.wikidata.org\/entity\/Q11188","mainEntity":"http:\/\/www.wikidata.org\/entity\/Q11188","author":{"@type":"Organization","name":"Contributors to Wikimedia projects"},"publisher":{"@type":"Organization","name":"Wikimedia Foundation, Inc.","logo":{"@type":"ImageObject","url":"https:\/\/www.wikimedia.org\/static\/images\/wmf-hor-googpub.png"}},"datePublished":"2004-03-13T23:02:21Z","dateModified":"2022-05-27T21:45:01Z","image":"https:\/\/upload.wikimedia.org\/wikipedia\/commons\/8\/85\/World-population-1750-2015-and-un-projection-until-2100.png","headline":"total number of living humans on Earth"}</script><script type="application/ld+json">{"@context":"https:\/\/schema.org","@type":"Article","name":"World population","url":"https:\/\/en.wikipedia.org\/wiki\/World_population","sameAs":"http:\/\/www.wikidata.org\/entity\/Q11188","mainEntity":"http:\/\/www.wikidata.org\/entity\/Q11188","author":{"@type":"Organization","name":"Contributors to Wikimedia projects"},"publisher":{"@type":"Organization","name":"Wikimedia Foundation, Inc.","logo":{"@type":"ImageObject","url":"https:\/\/www.wikimedia.org\/static\/images\/wmf-hor-googpub.png"}},"datePublished":"2004-03-13T23:02:21Z","dateModified":"2022-05-27T21:45:01Z","image":"https:\/\/upload.wikimedia.org\/wikipedia\/commons\/8\/85\/World-population-1750-2015-and-un-projection-until-2100.png","headline":"total number of living humans on Earth"}</script>
# <script>(RLQ=window.RLQ||[]).push(function(){mw.config.set({"wgBackendResponseTime":140,"wgHostname":"mw1435"});});</script>
# </body>

# %%
# access the child tag <b> of parent tag 
tag_child = tag_parent.b
tag_child
# Out:
# <b>world population</b>

# %%
# access the parent siblig tags

#sibiling_1 = tag_parent.next_sibling


# access the child sibling tag
#sibiling_1 = tag_child.next_sibling

#sibiling_1 = tag_obj.next_sibling
sibiling_1 = tag_div.next_sibling
sibiling_1
# Out:
# '\n'

# %%
# html attributes

#tag_div['id']
#tag_div.attrs
#tag_parent.attrs

#tag_div.get('id')
tag_parent.get('class')
# Out:
# ['mediawiki',
#  'ltr',
#  'sitedir-ltr',
#  'mw-hide-empty-elt',
#  'ns-0',
#  'ns-subject',
#  'page-World_population',
#  'rootpage-World_population',
#  'skin-vector',
#  'action-view',
#  'skin-vector-legacy']

# %%
# to get the string of the tag navigable tag
tag_string=tag_child.string
print("String of the Tag: ", tag_string, "Type of the content: ", type(tag_string))
# Out:
# String of the Tag:  world population Type of the content:  <class 'bs4.element.NavigableString'>

# %%
# search find_all()

page_url = "https://www.learningcontainer.com/sample-xml-file/"

xml_data = requests.get(page_url).text
soup_obj2 = BeautifulSoup(xml_data, "xml")
#tag_obj.title
pre_tag = soup_obj2.find_all(name=["pre"])
#tag_obj
pre_tag
# Out:
# []

# %%
pre_tag = soup_obj2.find("div", class_="e")
pre_tag

# %%
# scraping the content of any web 

page_url = "https://www.learningcontainer.com/sample-xml-file/"
data = requests.get(page_url).text
data
# Out:
# '<!DOCTYPE html><html lang="en-US"><head><meta charset="UTF-8" />\n<script data-ezscrex=\'false\' data-cfasync=\'false\' data-pagespeed-no-defer>var __ez=__ez||{};__ez.stms=Date.now();__ez.evt={};__ez.script={};__ez.ck=__ez.ck||{};__ez.template={};__ez.template.isOrig=true;__ez.queue=(function(){var count=0,incr=0,items=[],timeDelayFired=false,hpItems=[],lpItems=[],allowLoad=true;var obj={func:function(name,funcName,parameters,isBlock,blockedBy,deleteWhenComplete,proceedIfError){var self=this;this.name=name;this.funcName=funcName;this.parameters=parameters===null?null:(parameters instanceof Array)?parameters:[parameters];this.isBlock=isBlock;this.blockedBy=blockedBy;this.deleteWhenComplete=deleteWhenComplete;this.isError=false;this.isComplete=false;this.isInitialized=false;this.proceedIfError=proceedIfError;this.isTimeDelay=false;this.process=function(){log("... func = "+name);self.isInitialized=true;self.isComplete=true;log("... func.apply: "+name);var funcs=self.funcName.split(\'.\');var func=null;if(funcs.length>3){}else if(funcs.length===3){func=window[funcs[0]][funcs[1]][funcs[2]];}else if(funcs.length===2){func=window[funcs[0]][funcs[1]];}else{func=window[self.funcName];}\nif(typeof func!==\'undefined\'&&func!==null){func.apply(null,this.parameters);}\nif(self.deleteWhenComplete===true)delete items[name];if(self.isBlock===true){log("----- F\'D: "+self.name);processAll();}}},file:function(name,path,isBlock,blockedBy,async,defer,proceedIfError){var self=this;this.name=name;this.path=path;this.async=async;this.defer=defer;this.isBlock=isBlock;this.blockedBy=blockedBy;this.isInitialized=false;this.isError=false;this.isComplete=false;this.proceedIfError=proceedIfError;this.isTimeDelay=false;this.process=function(){self.isInitialized=true;log("... file = "+name);var scr=document.createElement(\'script\');scr.src=path;if(async===true)scr.async=true;else if(defer===true)scr.defer=true;scr.onerror=function(){log("----- ERR\'D: "+self.name);self.isError=true;if(self.isBlock===true){processAll();}};scr.onreadystatechange=scr.onload=function(){var state=scr.readyState;log("----- F\'D: "+self.name);if((!state||/loaded|complete/.test(state))){self.isComplete=true;if(self.isBlock===true){processAll();}}};document.getElementsByTagName(\'head\')[0].appendChild(scr);}},fileLoaded:function(name,isComplete){this.name=name;this.path="";this.async=false;this.defer=false;this.isBlock=false;this.blockedBy=[];this.isInitialized=true;this.isError=false;this.isComplete=isComplete;this.proceedIfError=false;this.isTimeDelay=false;this.process=function(){};}};function init(){window.addEventListener("load",function(){setTimeout(function(){timeDelayFired=true;log(\'TDELAY -----\');processAll();},5000);},false);}\nfunction addFile(name,path,isBlock,blockedBy,async,defer,proceedIfError,priority){var item=new obj.file(name,path,isBlock,blockedBy,async,defer,proceedIfError);if(priority===true){hpItems[name]=item}else{lpItems[name]=item}\nitems[name]=item;checkIfBlocked(item);}\nfunction setallowLoad(settobool){allowLoad=settobool}\nfunction addFunc(name,func,parameters,isBlock,blockedBy,autoInc,deleteWhenComplete,proceedIfError,priority){if(autoInc===true)name=name+"_"+incr++;var item=new obj.func(name,func,parameters,isBlock,blockedBy,deleteWhenComplete,proceedIfError);if(priority===true){hpItems[name]=item}else{lpItems[name]=item}\nitems[name]=item;checkIfBlocked(item);}\nfunction addTimeDelayFile(name,path){var item=new obj.file(name,path,false,[],false,false,true);item.isTimeDelay=true;log(name+\' ... \'+\' FILE! TDELAY\');lpItems[name]=item;items[name]=item;checkIfBlocked(item);}\nfunction addTimeDelayFunc(name,func,parameters){var item=new obj.func(name,func,parameters,false,[],true,true);item.isTimeDelay=true;log(name+\' ... \'+\' FUNCTION! TDELAY\');lpItems[name]=item;items[name]=item;checkIfBlocked(item);}\nfunction checkIfBlocked(item){if(isBlocked(item)===true||allowLoad==false)return;item.process();}\nfunction isBlocked(item){if(item.isTimeDela ...

# %%
soup2 = BeautifulSoup(data,"html.parser")
pre_tag = soup2.find("div", class_="e")
#pre_tag
pre_tag = pre_tag.string
pre_tag

# %%
for link in soup.find_all('a',href=True):  # in html anchor/link is represented by the tag <a>

    print(link.get('href'))
# Out:
# /wiki/Wikipedia:Protection_policy#semi
# #mw-head
# #searchInput
# /wiki/Demographics_of_the_world
# /wiki/File:World-population-1750-2015-and-un-projection-until-2100.png
# /wiki/File:World-population-1750-2015-and-un-projection-until-2100.png
# #cite_note-1
# /wiki/File:World_Population_Prospects_2019.png
# /wiki/File:World_Population_Prospects_2019.png
# #cite_note-:4-2
# /wiki/Demography
# /wiki/Human
# https://en.wikipedia.org/w/index.php?title=World_population&action=edit
# #cite_note-:6-3
# /wiki/Prehistory
# /wiki/Human_history
# /wiki/Billion
# #cite_note-4
# /wiki/Population_growth
# /wiki/Great_Famine_of_1315%E2%80%931317
# /wiki/Black_Death
# #cite_note-5
# /wiki/Population_growth_rates
# #cite_note-:1-6
# #cite_note-7
# #cite_note-:5-8
# #cite_note-9
# /wiki/United_Nations_Department_of_Economic_and_Social_Affairs
# #cite_note-:4-2
# #cite_note-:5-8
# #cite_note-10
# #cite_note-:2-11
# #cite_note-:3-12
# /wiki/Median_age
# #cite_note-:0-13
# #Population_by_region
# #History
# #Ancient_and_post-classical_history
# #Modern_history
# #Milestones_by_the_billions
# #Global_demographics
# #Largest_populations_by_country
# #10_most_populous_countries
# #Most_densely_populated_countries
# #Fluctuation
# #Annual_population_growth
# #Population_growth_by_region
# #Past_population
# #Projections
# #Mathematical_approximations
# #Years_for_world_population_to_double
# #Number_of_humans_who_have_ever_lived
# #See_also
# #Explanatory_notes
# #References
# #Further_reading
# #External_links
# #cite_note-WPP2015total-14
# #cite_note-note-2030-15
# /wiki/China
# /wiki/Demographics_of_China
# #cite_note-china-note-16
# /wiki/India
# /wiki/Demographics_of_India
# /wiki/United_States
# /wiki/Demographics_of_the_United_States
# /wiki/Indonesia
# /wiki/Demographics_of_Indonesia
# /wiki/Pakistan
# /wiki/Demographics_of_Pakistan
# /wiki/Brazil
# /wiki/Demographics_of_Brazil
# /wiki/Nigeria
# /wiki/Demographics_of_Nigeria
# /wiki/Bangladesh
# /wiki/Demographics_of_Bangladesh
# /wiki/Russia
# /wiki/Demographics_of_Russia
# /wiki/Mexico
# /wiki/Demographics_of_Mexico
# #cite_ref-note-2030_15-0
# #cite_ref-china-note_16-0
# /wiki/Hong_Kong
# /wiki/Macau
# /wiki/Continent
# /wiki/Latin_American
# /wiki/Caribbean
# /wiki/Oceania
# #cite_note-17
# /wiki/Antarctica
# /wiki/Research_stations_in_Antarctica
# #cite_note-AntarcticCIA-18
# #cite_note-19
# /wiki/China
# /wiki/Japan
# /wiki/Greater_Tokyo_Area
# /wiki/Tokyo
# /wiki/Nigeria
# /wiki/Egypt
# /wiki/Greater_Cairo
# /wiki/Cairo
# /wiki/Russia
# /wiki/European_Russia
# /wiki/Russia
# /wiki/Moscow_metropolitan_area
# /wiki/Moscow
# /wiki/Latin_America
# /wiki/Brazil
# /wiki/Brazil
# /wiki/Greater_S%C3%A3o_Paulo
# /wiki/S%C3%A3o_Paulo
# /wiki/Northern_America
# #cite_note-20
# /wiki/United_States
# #cite_note-CityPopulation.de-21
# /wiki/United_States
# /wiki/New_York_metropolitan_area
# /wiki/New_York_City
# /wiki/Oceania
# /wiki/Australia
# /wiki/Australia
# /wiki/Sydney
# /wiki/Antarctica
# #cite_note-AntarcticCIA-18
# #cite_note-22
# /wiki/McMurdo_Station
# /wiki/File:Illustration_of_contemporary_and_past_human_populations_Our_World_in_Data.png
# /wiki/File:Illustration_of_contemporary_and_past_human_populations_Our_World_in_Data.png
# /wiki/Estimates_of_historical_world_population
# /wiki/Human_history
# /wiki/Modernity
# /wiki/Age_of_Discovery
# #cite_note-23
# /wiki/William_Petty
# #cite_note-24
# #cite_note-25
# #cite_note-Kapitza2-26
# /wiki/Classical_demography
# /wiki/Medieval_demography
# #cite_note-27
# #cite_note-28
# /wiki/Lake_Toba_genetic_bottleneck
# /wiki/Roman_Empire
# #cite_note-29
# /wiki/Plague_of_Justinian
# /wiki/Roman_emperor
# /wiki/Justinian
# #cite_note-30
# #cite_note-31
# #cite_note-32
# /wiki/Indian_subcontinent
# /wiki/Black_Death
# /wiki/Pandemic
# #cite_note-Essai_sur_l'évolution_du_nombre_des_hommes-33
# #cite_note-34
# #cite_note-35
# /wiki/Mongol_Empire
# #cite_note-36
# /wiki/Han_dynasty
# /wiki/Ancient_China
# #cite_note-nishijima_1986_pp595-96-37
# /wiki/Western_Han
# /wiki/End_of_the_Han_dynasty
# #cite_note-nishijima_1986_pp595-96-37
# #cite_note-Essai_sur_l'évolution_du_nombre_des_hommes-33
# /wiki/Ming_dynasty
# #cite_note-38
# #cite_note-39
# #cite_note-40
# #cite_note-41
# #cite_note-42
# #cite_note-43
# /wiki/Maize
# /wiki/Cassava
# /wiki/Staple_food
# #cite_note-44
# /wiki/Pre-Columbian_era
# #cite_note-45
# #cite_note-46
# /wiki/List_of_epidemics
# #cite_note-47
# /wiki/Population_history_of_indigenous_peoples_of_the_Americas
# /wiki/New_World
# /wiki/Old_World
# /wiki/Smallpox
# /wiki/Measles
# /wiki/Influenza
# #cite_note-48
# #cite_note-49
# /wiki/File:2006megacities.svg
# /wiki/File:2006megacities.svg
# #cite_note-50
# #cite_note-51
# /wiki/British_Agricultural_Revolution
# /wiki/Industrial_Revolution
# /wiki/Life_expectancy
# #cite_note-52
# /wiki/Infant_mortality
# #cite_note-Buer-53
# #cite_note-54
# #cite_note-55
# #cite_note-56
# /wiki/Western_world
# /wiki/Vaccination
# /wiki/Sanitation
# #cite_note-57
# #cite_note-58
# #cite_note-59
# #cite_note-60
# /wiki/Russian_Empire
# /wiki/Soviet_Union
# /wiki/Famine
# #cite_note-61
# #cite_note-62
# #cite_note-63
# #cite_note-64
# /wiki/Developing_world
# #cite_note-65
# /wiki/Indian_subcontinent
# #cite_note-66
# #cite_note-67
# /wiki/Java
# /wiki/Indonesia
# #cite_note-68
# #cite_note-69
# #cite_note-70
# #cite_note-71
# /wiki/World_population_milestones
# #cite_note-:6-3
# #cite_note-72
# #cite_note-USCBcite-73
# #cite_note-UN7bn-74
# #cite_note-Guardian7-75
# #cite_note-UPI7bn-76
# #cite_note-77
# #cite_note-WorldPopProspects-78
# /wiki/Fertility
# /wiki/Mortality_rate
# #cite_note-WorldPopProspects-78
# #cite_note-LongRangeProjections2003KeyFindings-79
# #cite_note-Fertility2010-80
# /wiki/Day_of_7_Billion
# #cite_note-81
# /wiki/Demographics_of_the_world
# /wiki/File:Expectancy_of_life.svg
# /wiki/File:Expectancy_of_life.svg
# #cite_note-WHOStats2016-82
# /wiki/Human_sex_ratio
# /wiki/Gender_mortality_differentials
# #cite_note-IndexWorldDemogr.-83
# #cite_note-84
# #cite_note-IndexWorldDemogr.-83
# #cite_note-:0-13
# #cite_note-85
# /wiki/World_Health_Organization
# /wiki/List_of_countries_by_life_expectancy
# #cite_note-86
# /wiki/Fertility_rate
# #cite_note-87
# #cite_note-88
# /wiki/International_Monetary_Fund
# /wiki/Gross_world_product
# #cite_note-89
# /wiki/Extreme_poverty
# #cite_note-90
# /wiki/Undernourished
# #cite_note-91
# /wiki/Literacy_rate
# #cite_note-92
# #cite_note-93
# /wiki/Han_Chinese
# #cite_note-94
# /wiki/English_language
# /wiki/Mandarin_Chinese
# /wiki/Hindi
# /wiki/Spanish_language
# /wiki/French_language
# #cite_note-95
# /wiki/Christianity
# /wiki/Islam
# /wiki/Irreligion
# /wiki/Hinduism
# #cite_note-Pew-96
# /wiki/List_of_countries_and_dependencies_by_population
# /wiki/File:World_Population.svg
# /wiki/File:World_Population.svg
# /wiki/File:Countries_population_graph.jpeg
# /wiki/File:Countries_population_graph.jpeg
# /wiki/Wikipedia:Manual_of_Style/Dates_and_numbers#Chronological_items
# /wiki/Demographics_of_China
# #cite_note-97
# /wiki/Demographics_of_India
# #cite_note-98
# /wiki/Demographics_of_United_States
# #cite_note-99
# /wiki/Demographics_of_Indonesia
# #cite_note-100
# /wiki/Demographics_of_Pakistan
# #cite_note-unpop-101
# /wiki/Demographics_of_Brazil
# #cite_note-102
# /wiki/Demographics_of_Nigeria
# #cite_note-unpop-101
# /wiki/Demographics_of_Bangladesh
# #cite_note-103
# /wiki/Demographics_of_Russia
# #cite_note-104
# /wiki/Demographics_of_Mexico
# #cite_note-105
# /wiki/List_of_countries_and_dependencies_by_population_density
# /wiki/File:World_population_density_1994.png
# /wiki/File:World_population_density_1994.png
# /wiki/Singapore
# /wiki/Bangladesh
# /wiki/State_of_Palestine
# /wiki/Lebanon
# /wiki/Taiwan
# /wiki/South_Korea
# /wiki/Rwanda
# /wiki/Haiti
# /wiki/Netherlands
# /wiki/Israel
# /wiki/India
# /wiki/Pakistan
# /wiki/Bangladesh
# /wiki/Japan
# #cite_note-BigDecline-106
# /wiki/Philippines
# /wiki/Vietnam
# /wiki/United_Kingdom
# /wiki/South_Korea
# /wiki/Taiwan
# /wiki/Sri_Lanka
# /wiki/Population_growth
# /wiki/Projections_of_population_growth
# /wiki/Population_dynamics
# /wiki/File:World_population_(UN).svg
# /wiki/File:World_population_(UN).svg
# /wiki/Continent
# /wiki/Logarithmic_scale
# /wiki/Mortality_rate
# /wiki/History_of_medicine#Modern_medicine
# /wiki/Green_Revolution
# #cite_note-107
# #cite_note-108
# #cite_note-109
# #cite_note-110
# /wiki/Population_growth
# /wiki/Sub-Saharan_Africa
# #cite_note-111
# /wiki/File:Total_Fertility_Rate_Map_by_Country.svg
# /wiki/File:Total_Fertility_Rate_Map_by_Country.svg
# /wiki/Population_Reference_Bureau
# /wiki/Negative_population_growth
# /wiki/Net_(economics)
# /wiki/Sub-replacement_fertility
# #cite_note-BigDecline-106
# /wiki/Demographic_transition
# #cite_note-112
# #cite_note-113
# #cite_note-114
# /wiki/University_of_Washington
# #cite_note-115
# /wiki/File:Population_curve.svg
# /wiki/10th_millennium_BC
# /wiki/File:World_population_growth_(lin-log_scale).png
# /wiki/Logarithmic_scale
# /wiki/File:World_population_history.svg
# #cite_note-116
# /wiki/Population_growth
# /wiki/Total_fertility_rate
# /wiki/Birth_rate
# #cite_note-UN-117
# #cite_note-118
# #cite_note-autogenerated1-119
# #cite_note-Vallin-120
# #cite_note-un2004-121
# #cite_note-122
# #cite_note-Americas-123
# #cite_note-Americas-123
# #cite_note-Vallin-120
# #cite_note-un2004-121
# #cite_note-Americas-123
# #cite_note-Americas-123
# /wiki/Estimates_of_historical_world_population
# #cite_note-124
# #cite_note-WPP2015total-14
# #cite_note-Americas-123
# #cite_note-Americas-123
# #cite_note-125
# #cite_note-HistoricalEstimates-126
# /wiki/Wikipedia:Citation_needed
# #cite_note-CensusPopulation-127
# #cite_ref-Americas_123-0
# #cite_ref-Americas_123-1
# #cite_ref-Americas_123-2
# #cite_ref-Americas_123-3
# #cite_ref-Americas_123-4
# #cite_ref-Americas_123-5
# /wiki/Bermuda
# /wiki/St._Pierre_and_Miquelon
# /wiki/Caribbean
# /wiki/Projections_of_population_growth
# /wiki/File:Question_book-new.svg
# /wiki/Wikipedia:Verifiability
# https://en.wikipedia.org/w/index.php?title=World_population&action=edit
# /wiki/Help:Referencing_for_beginners
# /wiki/Help:Maintenance_template_removal
# #cite_note-UN-117
# #cite_note-129
# /wiki/Wikipedia:Citation_needed
# /wiki/Birth_rate
# /wiki/Mortality_rate
# /wiki/Demographic_transition#Stages
# /wiki/Wikipedia:Citation_needed
# /wiki/Infectious_disease#Mortality_from_infectious_diseases
# /wiki/List_of_wars
# /wiki/Life_extension
# /wiki/Public_health
# /wiki/Birth_rate
# /wiki/Mortality_rate
# #cite_note-130
# #cite_note-131
# #cite_note-:2-11
# #cite_note-:3-12
# #cite_note-132
# #cite_note-133
# /wiki/United_Nations_Population_Division
# #cite_note-LongRangeProjections2003KeyFindings-79
# #cite_note-134
# #cite_note-135
# #cite_note-136
# #cite_note-137
# /wiki/German_Foundation_for_World_Population
# #cite_note-138
# /wiki/Institute_for_Health_Metrics_and_Evaluation
# #cite_note-139
# /wiki/Human_impact_on_the_environment
# #cite_note-StokstadAAAS-140
# #cite_note-141
# #cite_note-TIMEenvir-142
# #cite_note-Zehner-143
# #cite_note-UN19-144
# #cite_note-145
# #cite_note-UN19-144
# /wiki/Sebastian_von_Hoerner
# /wiki/Hyperbolic_growth
# #cite_note-146
# /wiki/Carrying_capacity
# #cite_note-147
# /wiki/Demographic_transition
# /wiki/Sergey_Kapitsa
# #cite_note-Kapitza-148
# /wiki/World_population_estimates
# /wiki/2nd_millennium
# #cite_note-149
# /wiki/File:Population-doubling.svg
# /wiki/File:Population-doubling.svg
# /wiki/Prehistoric_demography
# /wiki/1E11
# #cite_note-Kapitza2-26
# #cite_note-150
# /wiki/Population_Reference_Bureau
# #cite_note-151
# #cite_note-Curtin2007-152
# #cite_note-Haub1995-153
# #cite_note-Haub2011-154
# #cite_note-Haub1995-153
# /wiki/Census_in_Egypt
# /wiki/Achaemenid_Empire
# #cite_note-155
# /wiki/Infant_mortality
# /wiki/Life_expectancy_at_birth
# #cite_note-Haub1995-153
# /wiki/Life_expectancy#Variation_over_time
# /wiki/File:The_Earth_seen_from_Apollo_17.jpg
# /wiki/Portal:World
# /wiki/Demographics_of_the_world
# /wiki/Anthropocene
# /wiki/Birth_control
# /wiki/Coastal_development_hazards#Coastal_population_growth_and_development_on_coasts
# /wiki/Demographic_transition
# /wiki/Population_decline
# /wiki/Doomsday_argument
# /wiki/Family_planning
# /wiki/Food_security
# /wiki/Human_overpopulation
# /wiki/Megacity
# /wiki/Natalism
# /wiki/One-child_policy
# /wiki/Population_growth
# /wiki/Population_dynamics
# /wiki/Two-child_policy
# /wiki/List_of_countries_and_dependencies_by_population
# /wiki/List_of_largest_cities
# /wiki/List_of_population_concern_organizations
# /wiki/List_of_sovereign_states_and_dependencies_by_total_fertility_rate
# /wiki/List_of_countries_by_past_and_projected_future_population
# /wiki/List_of_countries_by_population_in_1900
# /wiki/List_of_countries_and_dependencies_by_population_density
# /wiki/List_of_countries_by_population_growth_rate
# /wiki/Lists_of_organisms_by_population
# /wiki/List_of_religious_populations
# /wiki/Census#History_of_censuses
# /wiki/Historical_demography
# #cite_ref-19
# /wiki/Hong_Kong
# /wiki/Macau
# #cite_ref-20
# /wiki/Mexico
# /wiki/Central_America
# /wiki/Caribbean
# #cite_ref-22
# /wiki/Antarctic_Treaty_System
# /wiki/Territorial_claims_in_Antarctica
# /wiki/Ross_Dependency
# #cite_ref-1
# https://ourworldindata.org/grapher/world-population-1750-2015-and-un-projection-until-2100
# #cite_ref-:4_2-0
# #cite_ref-:4_2-1
# https://population.un.org/wpp/Graphs/Probabilistic/POP/TOT/900
# #cite_ref-:6_3-0
# #cite_ref-:6_3-1
# https://www.worldometers.info/world-population/
# /wiki/Template:Cite_web
# /wiki/Category:CS1_maint:_url-status
# #cite_ref-4
# https://www.pbs.org/newshour/bb/world-july-dec11-population1_10-27/
# https://web.archive.org/web/20170924090953/http://www.pbs.org/newshour/bb/world-july-dec11-population1_10-27/
# #cite_ref-5
# #cite_ref-:1_6-0
# https://web.archive.org/web/20160919061238/https://esa.un.org/unpd/wpp/DataQuery/
# https://esa.un.org/unpd/wpp/DataQuery/
# #cite_ref-7
# https://population.un.org/wpp/Download/Standard/Population/
# #cite_ref-:5_8-0
# #cite_ref-:5_8-1
# https://population.un.org/wpp/Download/Standard/Population/
# #cite_ref-9
# https://ourworldindata.org/world-population-growth
# https://web.archive.org/web/20161013144559/https://ourworldindata.org/world-population-growth/
# #cite_ref-10
# https://ghostarchive.org/archive/20211228/https://www.nytimes.com/2021/05/22/world/global-population-shrinking.html
# /wiki/ISSN_(identifier)
# //www.worldcat.org/issn/0362-4331
# https://www.nytimes.com/2021/05/22/world/global-population-shrinking.html
# #cite_ref-:2_11-0
# #cite_ref-:2_11-1
# https://population.un.org/wpp/Download/Standard/Fertility/
# #cite_ref-:3_12-0
# #cite_ref-:3_12-1
# https://population.un.org/wpp/Download/Standard/Mortality/
# #cite_ref-:0_13-0
# #cite_ref-:0_13-1
# https://www.cia.gov/the-world-factbook/countries/world/
# #cite_ref-WPP2015total_14-0
# #cite_ref-WPP2015total_14-1
# https://web.archive.org/web/20151222125602/http://esa.un.org/unpd/wpp/DVD/Files/1_Indicators%20(Standard)/EXCEL_FILES/1_Population/WPP2015_POP_F01_1_TOTAL_POPULATION_BOTH_SEXES.XLS
# http://esa.un.org/unpd/wpp/DVD/Files/1_Indicators%20(Standard)/EXCEL_FILES/1_Population/WPP2015_POP_F01_1_TOTAL_POPULATION_BOTH_SEXES.XLS
# https://web.archive.org/web/20151225073428/http://esa.un.org/unpd/wpp/Download/Standard/Population/
# #cite_ref-17
# https://www.worldometers.info/world-population/population-by-region/
# #cite_ref-AntarcticCIA_18-0
# #cite_ref-AntarcticCIA_18-1
# https://www.cia.gov/the-world-factbook/countries/antarctica/
# #cite_ref-CityPopulation.de_21-0
# http://citypopulation.de/en/usa/combmetro/
# #cite_ref-23
# /wiki/English_compound
# #cite_ref-24
# https://books.google.com/books?id=0S0AAAAAYAAJ&pg=PA167#v=onepage&q&f=false
# #cite_ref-25
# https://books.google.com/books?id=ue5eAAAAcAAJ&pg=PA356
# https://web.archive.org/web/20190606203312/https://books.google.com/books?id=ue5eAAAAcAAJ&pg=PA356
# /wiki/Wayback_Machine
# https://books.google.com/books?id=ZzA3AAAAMAAJ&pg=PA10
# https://web.archive.org/web/20190606203315/https://books.google.com/books?id=ZzA3AAAAMAAJ&pg=PA10
# /wiki/Wayback_Machine
# https://archive.org/details/60340180R.nlm.nih.gov/page/n28
# #cite_ref-Kapitza2_26-0
# #cite_ref-Kapitza2_26-1
# #cite_ref-27
# https://books.google.com/books?id=cXuCjDbxC1YC&pg=PA26
# /wiki/ISBN_(identifier)
# /wiki/Special:BookSources/978-2-7605-1588-8
# #cite_ref-28
# /wiki/ISBN_(identifier)
# /wiki/Special:BookSources/0-8221-0166-1
# #cite_ref-29
# https://web.archive.org/web/20160507061006/http://www.tulane.edu/~august/H303/handouts/Population.htm
# http://www.tulane.edu/~august/H303/handouts/Population.htm
# #cite_ref-30
# http://science.nationalgeographic.com/science/health-and-human-body/human-diseases/plague-article.html
# https://www.webcitation.org/6HfrvlPBO?url=http://science.nationalgeographic.com/science/health-and-human-body/human-diseases/plague-article.html
# #cite_ref-31
# http://www.britannica.com/EBchecked/topic/195896/history-of-Europe/276190/Demographic-and-agricultural-growth#ref=ref994290
# https://web.archive.org/web/20121220154316/http://www.britannica.com/EBchecked/topic/195896/history-of-Europe/276190/Demographic-and-agricultural-growth#ref=ref994290
# #cite_ref-32
# https://www.census.gov/population/international/data/worldpop/table_history.php
# https://web.archive.org/web/20120709092946/https://www.census.gov/population/international/data/worldpop/table_history.php
# #cite_ref-Essai_sur_l'évolution_du_nombre_des_hommes_33-0
# #cite_ref-Essai_sur_l'évolution_du_nombre_des_hommes_33-1
# https://www.jstor.org/stable/1531855?seq=4#metadata_info_tab_contents
# #cite_ref-34
# https://web.archive.org/web/20080725005418/http://www.time.com/time/europe/magazine/2000/0717/peter.html
# http://www.time.com/time/world/article/0,8599,2050585,00.html
# #cite_ref-35
# https://books.google.com/books?id=cHcjnkrMweYC&pg=PA285
# /wiki/ISBN_(identifier)
# /wiki/Special:BookSources/978-0-691-09291-1
# #cite_ref-36
# https://books.google.com/books?id=nmgNXoiAiU4C&pg=RA2-PA34
# /wiki/ISBN_(identifier)
# /wiki/Special:BookSources/978-0-12-765660-1
# #cite_ref-nishijima_1986_pp595-96_37-0
# #cite_ref-nishijima_1986_pp595-96_37-1
# #cite_ref-38
# http://afe.easia.columbia.edu/special/china_1750_demographic.htm
# /wiki/Columbia_University
# https://web.archive.org/web/20110708082757/http://afe.easia.columbia.edu/special/china_1750_demographic.htm
# #cite_ref-39
# http://www.britannica.com/EBchecked/topic/195896/history-of-Europe/58335/Demographics#ref=ref310375
# https://web.archive.org/web/20160205063346/http://www.un.org/esa/population/publications/sixbillion/sixbilpart1.pdf
# https://www.un.org/esa/population/publications/sixbillion/sixbilpart1.pdf
# #cite_ref-USCBcite_73-0
# https://www.census.gov/population/popclockworld.html
# https://web.archive.org/web/20111118011415/http://www.census.gov/population/popclockworld.html
# #cite_ref-UN7bn_74-0
# https://www.bbc.co.uk/news/world-15459643
# https://web.archive.org/web/20111026202531/http://www.bbc.co.uk/news/world-15459643
# #cite_ref-Guardian7_75-0
# https://www.theguardian.com/world/2011/oct/31/seven-billionth-baby-born-philippines?intcmp=122
# https://web.archive.org/web/20130930143837/http://www.theguardian.com/world/2011/oct/31/seven-billionth-baby-born-philippines?intcmp=122
# #cite_ref-UPI7bn_76-0
# http://www.upi.com/Top_News/US/2011/10/31/7-billion-people-is-a-serious-challenge/UPI-73301320046200/
# https://web.archive.org/web/20111103213419/http://www.upi.com/Top_News/US/2011/10/31/7-billion-people-is-a-serious-challenge/UPI-73301320046200/
# #cite_ref-77
# https://population.un.org/wpp/Download/Standard/Population/
# #cite_ref-WorldPopProspects_78-0
# #cite_ref-WorldPopProspects_78-1
# https://www.un.org/esa/population/publications/wpp2000/chapter5.pdf
# https://www.un.org/esa/population/publications/wpp2002/English.pdf
# https://www.un.org/esa/population/publications/longrange2/WorldPop2300final.pdf
# https://web.archive.org/web/20180919132323/http://www.un.org/esa/population/publications/longrange2/WorldPop2300final.pdf
# https://www.census.gov/ipc/www/idb/worldpopgraph.php
# /wiki/United_States_Census_Bureau
# https://web.archive.org/web/20131005014003/http://www.census.gov/ipc/www/idb/worldpopgraph.php
# http://www.prb.org/pdf09/09wpds_eng.pdf
# /wiki/Population_Reference_Bureau
# https://web.archive.org/web/20100422034436/http://www.prb.org/pdf09/09wpds_eng.pdf
# #cite_ref-LongRangeProjections2003KeyFindings_79-0
# #cite_ref-LongRangeProjections2003KeyFindings_79-1
# https://www.un.org/esa/population/publications/longrange/longrangeKeyFind.pdf
# /wiki/Template:Cite_book
# /wiki/Category:CS1_maint:_url-status
# #cite_ref-Fertility2010_80-0
# https://web.archive.org/web/20120607191518/http://esa.un.org/unpd/wpp/Excel-Data/DB01_Period_Indicators/WPP2010_DB1_F01_TOTAL_FERTILITY.XLS
# http://esa.un.org/unpd/wpp/Excel-Data/DB01_Period_Indicators/WPP2010_DB1_F01_TOTAL_FERTILITY.XLS
# #cite_ref-81
# https://web.archive.org/web/20150224215308/http://esa.un.org/unpd/wpp/Other-Information/faq.htm
# http://esa.un.org/unpd/wpp/Other-Information/faq.htm
# #cite_ref-WHOStats2016_82-0
# https://www.who.int/gho/publications/world_health_statistics/2016/EN_WHS2016_AnnexB.pdf
# https://web.archive.org/web/20180517033759/http://www.who.int/gho/publications/world_health_statistics/2016/EN_WHS2016_AnnexB.pdf
# #cite_ref-IndexWorldDemogr._83-0
# #cite_ref-IndexWorldDemogr._83-1
# http://www.indexmundi.com/world/demographics_profile.html
# https://web.archive.org/web/20111130063938/http://www.indexmundi.com/world/demographics_profile.html
# #cite_ref-84
# http://www.unfpa.org/gender/docs/studies/summaries/reg_exe_summary.pdf
# https://web.archive.org/web/20120604165426/http://www.unfpa.org/gender/docs/studies/summaries/reg_exe_summary.pdf
# #cite_ref-85
# https://www.un.org/esa/population/cpd/cpd2012/Agenda%20item%204/UN%20system%20statements/ECA_Item4.pdf
# https://web.archive.org/web/20131110111359/http://www.un.org/esa/population/cpd/cpd2012/Agenda%20item%204/UN%20system%20statements/ECA_Item4.pdf
# #cite_ref-86
# https://apps.who.int/gho/data/node.main.688
# /wiki/Template:Cite_web
# /wiki/Category:CS1_maint:_url-status
# #cite_ref-87
# https://ourworldindata.org/grapher/children-per-woman-UN
# #cite_ref-88
# https://www.bbc.co.uk/news/health-18462985
# https://web.archive.org/web/20130204103058/http://www.bbc.co.uk/news/health-18462985
# #cite_ref-89
# https://www.imf.org/external/datamapper/datasets/WEO
# /wiki/Template:Cite_web
# /wiki/Category:CS1_maint:_url-status
# #cite_ref-90
# https://data.worldbank.org/indicator/SI.POV.DDAY
# #cite_ref-91
# http://www.fao.org/docrep/016/i3027e/i3027e02.pdf
# https://web.archive.org/web/20140611064129/http://www.fao.org/docrep/016/i3027e/i3027e02.pdf
# /wiki/Wayback_Machine
# #cite_ref-92
# https://data.worldbank.org/indicator/SE.ADT.LITR.ZS
# #cite_ref-93
# https://www.statista.com/statistics/617136/digital-population-worldwide/
# #cite_ref-94
# https://blogs.wsj.com/chinarealtime/2011/03/04/worlds-most-typical-person-han-chinese-man/
# https://web.archive.org/web/20190606203315/https://blogs.wsj.com/chinarealtime/2011/03/04/worlds-most-typical-person-han-chinese-man/
# /wiki/Wayback_Machine
# #cite_ref-95
# https://www.visualcapitalist.com/100-most-spoken-languages/
# #cite_ref-Pew_96-0
# https://www.pewforum.org/2015/04/02/religious-projection-table/2010/number/all/
# #cite_ref-97
# http://data.stats.gov.cn/english/
# https://web.archive.org/web/20180614044850/http://data.stats.gov.cn/english/
# #cite_ref-98
# https://data.gov.in/
# https://web.archive.org/web/20160619153514/https://data.gov.in/
# #cite_ref-99
# https://www.census.gov/popclock/
# https://web.archive.org/web/20151117025617/http://www.census.gov/popclock/
# #cite_ref-100
# https://www.bps.go.id/
# https://web.archive.org/web/20180717152402/https://www.bps.go.id/
# #cite_ref-unpop_101-0
# #cite_ref-unpop_101-1
# https://population.un.org/wpp/Download/Files/1_Indicators%20(Standard)/EXCEL_FILES/1_Population/WPP2019_POP_F01_1_TOTAL_POPULATION_BOTH_SEXES.xlsx
# #cite_ref-102
# https://www.ibge.gov.br/apps/populacao/projecao/index.html
# https://web.archive.org/web/20200204104203/https://www.ibge.gov.br/apps/populacao/projecao/index.html
# #cite_ref-103
# https://web.archive.org/web/20110904045106/http://www.bbs.gov.bd/Home.aspx
# http://www.bbs.gov.bd/Home.aspx
# #cite_ref-104
# https://www.gks.ru/
# https://web.archive.org/web/20200104204802/https://www.gks.ru/
# #cite_ref-105
# http://www.conapo.gob.mx/work/models/CONAPO/Mapa_Ind_Dem18/index_2.html
# https://web.archive.org/web/20190103091405/http://www.conapo.gob.mx/work/models/CONAPO/Mapa_Ind_Dem18/index_2.html
# #cite_ref-BigDecline_106-0
# #cite_ref-BigDecline_106-1
# https://www.telegraph.co.uk/news/worldnews/asia/japan/9999591/Japans-population-suffers-biggest-fall-in-history.html
# https://web.archive.org/web/20130521221053/http://www.telegraph.co.uk/news/worldnews/asia/japan/9999591/Japans-population-suffers-biggest-fall-in-history.html
# #cite_ref-107
# http://news.bbc.co.uk/2/hi/in_depth/6496585.stm
# https://web.archive.org/web/20110728055441/http://news.bbc.co.uk/2/hi/in_depth/6496585.stm
# #cite_ref-108
# https://web.archive.org/web/20080422210924/http://www.energybulletin.net/19525.html
# http://www.energybulletin.net/19525.html
# #cite_ref-109
# https://www.un.org/esa/population/publications/longrange2/WorldPop2300final.pdf
# https://web.archive.org/web/20180919132323/http://www.un.org/esa/population/publications/longrange2/WorldPop2300final.pdf
# #cite_ref-110
# https://www.census.gov/ipc/www/worldpop.html
# https://web.archive.org/web/20100823141629/http://www.census.gov/ipc/www/worldpop.html
# #cite_ref-111
# https://archive.org/details/littlegreenhandb00ronn
# /wiki/ISBN_(identifier)
# /wiki/Special:BookSources/978-0-312-42581-4
# #cite_ref-112
# https://www.un.org/esa/population/publications/wpp2006/WPP2006_Highlights_rev.pdf
# https://web.archive.org/web/20181012171547/http://www.un.org/esa/population/publications/wpp2006/WPP2006_Highlights_rev.pdf
# #cite_ref-113
# https://web.archive.org/web/20100819143228/http://esa.un.org/UNPP/
# http://esa.un.org/unpp/
# #cite_ref-114
# #cite_ref-115
# http://www.washington.edu/news/2014/09/18/world-population-to-keep-growing-this-century-hit-11-billion-by-2100/
# https://web.archive.org/web/20161204155734/http://www.washington.edu/news/2014/09/18/world-population-to-keep-growing-this-century-hit-11-billion-by-2100/
# /wiki/Wayback_Machine
# #cite_ref-116
# https://www.worldometers.info/world-population/world-population-by-year/
# #cite_ref-UN_117-0
# #cite_ref-UN_117-1
# https://www.un.org/esa/population/publications/wpp2008/wpp2008_highlights.pdf
# /wiki/Population_Division_of_the_Department_of_Economic_and_Social_Affairs_of_the_United_Nations_Secretariat
# https://web.archive.org/web/20130319095657/http://www.un.org/esa/population/publications/wpp2008/wpp2008_highlights.pdf
# #cite_ref-118
# https://www.un.org/esa/population/publications/sixbillion/sixbillion.htm
# https://web.archive.org/web/20130709223435/http://www.un.org/esa/population/publications/sixbillion/sixbillion.htm
# #cite_ref-autogenerated1_119-0
# https://web.archive.org/web/20110724101452/http://www.globalchange.umich.edu/globalchange2/current/lectures/human_pop/human_pop.html
# /wiki/University_of_Michigan
# http://www.globalchange.umich.edu/globalchange2/current/lectures/human_pop/human_pop.html
# #cite_ref-Vallin_120-0
# #cite_ref-Vallin_120-1
# /wiki/ISBN_(identifier)
# /wiki/Special:BookSources/978-0-12-765660-1
# #cite_ref-un2004_121-0
# #cite_ref-un2004_121-1
# https://web.archive.org/web/20160205063346/http://www.un.org/esa/population/publications/sixbillion/sixbilpart1.pdf
# https://www.un.org/esa/population/publications/sixbillion/sixbilpart1.pdf
# #cite_ref-122
# https://web.archive.org/web/20140320035709/http://esa.un.org/unpd/wpp/unpp/panel_population.htm
# http://esa.un.org/unpd/wpp/Publications/Files/Key_Findings_WPP_2015.pdf
# #cite_ref-124
# https://www.un.org/esa/population/publications/sixbillion/sixbillion.htm
# https://web.archive.org/web/20160305042434/http://www.un.org/esa/population/publications/sixbillion/sixbillion.htm
# https://web.archive.org/web/20160101220025/http://www.un.org/esa/population/publications/sixbillion/sixbilpart1.pdf
# #cite_ref-125
# /wiki/Toba_catastrophe_theory
# https://www.bbc.co.uk/news/science-environment-22355515
# https://web.archive.org/web/20150107140627/http://www.bbc.co.uk/news/science-environment-22355515
# #cite_ref-HistoricalEstimates_126-0
# https://www.census.gov/data/tables/time-series/demo/international-programs/historical-est-worldpop.html
# https://web.archive.org/web/20190502001420/https://www.census.gov/data/tables/time-series/demo/international-programs/historical-est-worldpop.html
# /wiki/Wayback_Machine
# /wiki/Michael_Kremer
# /wiki/Doi_(identifier)
# https://doi.org/10.2307%2F2118405
# /wiki/JSTOR_(identifier)
# //www.jstor.org/stable/2118405
# #cite_ref-CensusPopulation_127-0
# https://www.census.gov/population/international/data/worldpop/table_population.php
# https://web.archive.org/web/20170521041303/https://www.census.gov/population/international/data/worldpop/table_population.php
# /wiki/Wayback_Machine
# #cite_ref-129
# https://www.census.gov/ipc/www/popwnote.html
# https://web.archive.org/web/20131002103104/http://www.census.gov/ipc/www/popwnote.html
# #cite_ref-130
# https://population.un.org/wpp/Download/Standard/Population/
# #cite_ref-131
# https://population.un.org/wpp/Download/Standard/Mortality/
# #cite_ref-132
# https://web.archive.org/web/20140701185837/http://esa.un.org/wpp/unpp/panel_population.htm
# http://esa.un.org/wpp/unpp/panel_population.htm
# #cite_ref-133
# https://www.un.org/apps/news/story.asp?NewsID=45165
# https://web.archive.org/web/20130823185917/http://www.un.org/apps/news/story.asp?NewsID=45165
# #cite_ref-134
# https://www.sciencedaily.com/releases/2013/04/130404072923.htm
# https://web.archive.org/web/20200102113023/https://www.sciencedaily.com/releases/2013/04/130404072923.htm
# #cite_ref-135
# https://www.theguardian.com/environment/2014/sep/18/world-population-new-study-11bn-2100
# https://web.archive.org/web/20140920203432/http://www.theguardian.com/environment/2014/sep/18/world-population-new-study-11bn-2100
# #cite_ref-136
# //www.ncbi.nlm.nih.gov/pmc/articles/PMC4230924
# /wiki/Bibcode_(identifier)
# https://ui.adsabs.harvard.edu/abs/2014Sci...346..234G
# /wiki/Doi_(identifier)
# https://doi.org/10.1126%2Fscience.1257469
# /wiki/ISSN_(identifier)
# //www.worldcat.org/issn/1095-9203
# /wiki/PMC_(identifier)
# //www.ncbi.nlm.nih.gov/pmc/articles/PMC4230924
# /wiki/PMID_(identifier)
# //pubmed.ncbi.nlm.nih.gov/25301627
# #cite_ref-137
# https://population.un.org/wpp/Publications/Files/WPP2019_10KeyFindings.pdf
# https://web.archive.org/web/20190703142439/https://population.un.org/wpp/Publications/Files/WPP2019_10KeyFindings.pdf
# #cite_ref-138
# https://www.dw.com/en/worlds-population-to-hit-775-billion-in-2019/a-51758905
# /wiki/Deutsche_Welle
# #cite_ref-139
# https://www.theguardian.com/world/2020/jul/15/world-population-in-2100-could-be-2-billion-below-un-forecasts-study-suggests
# #cite_ref-StokstadAAAS_140-0
# https://www.sciencemag.org/news/2019/05/landmark-analysis-documents-alarming-global-decline-nature
# /wiki/Science_(journal)
# /wiki/American_Association_for_the_Advancement_of_Science
# #cite_ref-141
# https://books.google.com/books?id=GZ4Pvk0LVQMC
# /wiki/ISBN_(identifier)
# /wiki/Special:BookSources/978-1849770477
# #cite_ref-TIMEenvir_142-0
# https://web.archive.org/web/20130218180534/http://www.time.com/time/specials/packages/article/0,28804,2097720_2097782_2097814,00.html
# http://www.time.com/time/specials/packages/article/0,28804,2097720_2097782_2097814,00.html
# #cite_ref-Zehner_143-0
# http://greenillusions.org
# https://web.archive.org/web/20191129202344/http://www.greenillusions.org/
# #cite_ref-UN19_144-0
# #cite_ref-UN19_144-1
# https://population.un.org/wpp/Download/Files/1_Indicators%20(Standard)/EXCEL_FILES/1_Population/WPP2019_POP_F01_1_TOTAL_POPULATION_BOTH_SEXES.xlsx
# /wiki/Population_Division_of_the_Department_of_Economic_and_Social_Affairs_of_the_United_Nations_Secretariat
# #cite_ref-145
# https://www.census.gov/population/international/data/worldpop/table_population.php
# https://web.archive.org/web/20170521041303/https://www.census.gov/population/international/data/worldpop/table_population.php
# #cite_ref-146
# /wiki/Bibcode_(identifier)
# https://ui.adsabs.harvard.edu/abs/1975JBIS...28..691V
# #cite_ref-147
# http://urss.ru/cgi-bin/db.pl?cp=&page=Book&id=37484&lang=en&blang=en&list=14
# https://web.archive.org/web/20120210055935/http://urss.ru/cgi-bin/db.pl?cp=&lang=en&blang=en&list=14&page=Book&id=37484
# /wiki/Wayback_Machine
# /wiki/Andrey_Korotayev
# https://arxiv.org/abs/1206.0496
# https://web.archive.org/web/20190217142233/https://arxiv.org/abs/1206.0496
# /wiki/Wayback_Machine
# #cite_ref-Kapitza_148-0
# https://web.archive.org/web/20090511041230/http://srs.dl.ac.uk/SPEAKERS/KAPITZA/Uspekhi_96.html
# /wiki/Bibcode_(identifier)
# https://ui.adsabs.harvard.edu/abs/1996PhyU...39...57K
# /wiki/Doi_(identifier)
# https://doi.org/10.1070%2Fpu1996v039n01abeh000127
# http://srs.dl.ac.uk/SPEAKERS/KAPITZA/Uspekhi_96.html
# #cite_ref-149
# http://pure.iiasa.ac.at/5299/1/RR-97-10.pdf
# /wiki/Bibcode_(identifier)
# https://ui.adsabs.harvard.edu/abs/1997Natur.387..803L
# /wiki/Doi_(identifier)
# https://doi.org/10.1038%2F42935
# /wiki/PMID_(identifier)
# //pubmed.ncbi.nlm.nih.gov/9194559
# /wiki/S2CID_(identifier)
# https://api.semanticscholar.org/CorpusID:4306159
# #cite_ref-150
# #cite_ref-151
# https://www.prb.org/articles/how-many-people-have-ever-lived-on-earth/
# #cite_ref-Curtin2007_152-0
# http://www.sciam.com/article.cfm?id=fact-or-fiction-living-outnumber-dead
# /wiki/Bibcode_(identifier)
# https://ui.adsabs.harvard.edu/abs/2007SciAm.297c.126C
# /wiki/Doi_(identifier)
# https://doi.org/10.1038%2Fscientificamerican0907-126
# /wiki/PMID_(identifier)
# //pubmed.ncbi.nlm.nih.gov/17784634
# #cite_ref-Haub1995_153-0
# #cite_ref-Haub1995_153-1
# #cite_ref-Haub1995_153-2
# http://www.prb.org/pdf/PT_novdec02.pdf
# /wiki/Population_Reference_Bureau
# https://web.archive.org/web/20110812104745/http://www.prb.org/pdf/PT_novdec02.pdf
# #cite_ref-Haub2011_154-0
# https://web.archive.org/web/20130424014209/http://www.prb.org/Articles/2002/HowManyPeopleHaveEverLivedonEarth.aspx
# /wiki/Population_Reference_Bureau
# http://www.prb.org/Articles/2002/HowManyPeopleHaveEverLivedonEarth.aspx
# #cite_ref-155
# /wiki/ISBN_(identifier)
# /wiki/Special:BookSources/978-0-393-31495-3
# https://web.archive.org/web/20150816232627/http://esa.un.org/unpd/wpp/index.htm
# /wiki/United_Nations_Population_Division
# https://web.archive.org/web/20150816232627/http://esa.un.org/unpd/wpp/index.htm
# /wiki/United_Nations_Population_Division
# https://web.archive.org/web/20150816232627/http://esa.un.org/unpd/wpp/index.htm
# http://demographia.ru/eng/articles/index.html?idR=67&idArt=1815
# https://www.cia.gov/the-world-factbook/countries/world/
# /wiki/The_World_Factbook
# /wiki/Central_Intelligence_Agency
# https://www.pbs.org/wgbh/nova/transcripts/3108_worldbal.html
# https://berkeley.academia.edu/OzzieZehner/Papers/911571/The_Environmental_Politics_of_Population_and_Overpopulation/
# /wiki/University_of_California,_Berkeley
# https://www.economist.com/news/international/21579817-lot-more-people-faces-future
# https://www.bbc.co.uk/news/science-environment-23253917
# /wiki/BBC_News
# https://ourworldindata.org/world-population-growth/
# /wiki/OurWorldInData
# http://sacredlands.org/food_and_population.htm
# /wiki/Duke_University
# /wiki/David_Pimentel
# /wiki/Cornell_University
# https://commons.wikimedia.org/wiki/Category:World_population_statistics
# http://www.unfpa.org/press/six-billion-growing-population-and-sustainable-development-will-population-issues-undermine
# https://web.archive.org/web/20130718121104/http://7billionactions.org/
# http://www.prb.org/
# http://www.berlin-institut.org/index.php?id=48
# http://www.hivegroup.com/gallery/worldpop/
# http://www.win.tue.nl/~speckman/Cartograms/WorldCarto.html
# https://www.census.gov/popclock/
# /wiki/Template:Population
# /wiki/Template_talk:Population
# https://en.wikipedia.org/w/index.php?title=Template:Population&action=edit
# /wiki/Biocapacity
# /wiki/Demographics_of_the_world
# /wiki/Human_overpopulation
# /wiki/Malthusianism
# /wiki/Human_population_planning
# /wiki/Compulsory_sterilization
# /wiki/Family_planning
# /wiki/One-child_policy
# /wiki/Two-child_policy
# /wiki/Optimum_population
# /wiki/Population
# /wiki/Population_ethics
# /wiki/Population_growth
# /wiki/Population_momentum
# /wiki/Sustainable_development
# /wiki/Sustainable_population
# /wiki/Reproductive_rights
# /wiki/Zero_population_growth
# /wiki/Population_biology
# /wiki/Population_decline
# /wiki/Population_density
# /wiki/Physiological_density
# /wiki/Population_dynamics
# /wiki/Population_model
# /wiki/Population_pyramid
# /wiki/Projections_of_population_growth
# /wiki/Population_ecology
# /wiki/Earth%27s_energy_budget
# /wiki/I_%3D_PAT
# /wiki/Kaya_identity
# /wiki/Malthusian_growth_model
# /wiki/Overshoot_(population)
# /wiki/World3
# /wiki/A_Modest_Proposal
# /wiki/Observations_Concerning_the_Increase_of_Mankind,_Peopling_of_Countries,_etc.
# /wiki/An_Essay_on_the_Principle_of_Population
# /wiki/How_Much_Land_Does_a_Man_Need%3F
# /wiki/Operating_Manual_for_Spaceship_Earth
# /wiki/Population_Control:_Real_Costs,_Illusory_Benefits
# /wiki/The_Limits_to_Growth
# /wiki/The_Population_Bomb
# /wiki/The_Skeptical_Environmentalist
# /wiki/The_Ultimate_Resource
# /wiki/Fatal_Misconception
# /wiki/Population_and_Environment
# /wiki/Population_and_Development_Review
# /wiki/Population_and_housing_censuses_by_country
# /wiki/List_of_metropolitan_areas_by_population
# /wiki/World_population_milestones
# /wiki/7_Billion_Actions
# /wiki/International_Conference_on_Population_and_Development
# /wiki/Population_Action_International
# /wiki/Population_Connection
# /wiki/Population_Matters
# /wiki/Population_Research_Institute
# /wiki/United_Nations_Population_Fund
# /wiki/Voluntary_Human_Extinction_Movement
# /wiki/World_Population_Day
# /wiki/World_Population_Foundation
# /wiki/Deep_ecology
# /wiki/Fertility_and_intelligence
# /wiki/Green_Revolution
# /wiki/Human_impact_on_the_environment
# /wiki/Human_migration
# https://commons.wikimedia.org/wiki/Category:Human_overpopulation
# /wiki/Category:Human_overpopulation
# /wiki/Category:Human_activities_with_impact_on_the_environment
# /wiki/Category:Human_migration
# /wiki/Template:Anthropogenic_effects_on_the_environment
# /wiki/Template_talk:Anthropogenic_effects_on_the_environment
# https://en.wikipedia.org/w/index.php?title=Template:Anthropogenic_effects_on_the_environment&action=edit
# /wiki/Anthropogenic_effects_on_the_environment
# /wiki/Anthropocene
# /wiki/Environmental_issues
# /wiki/List_of_environmental_issues
# /wiki/Human_impact_on_the_environment
# /wiki/Human_impact_on_marine_life
# /wiki/List_of_global_issues
# /wiki/Environmental_impact_assessment
# /wiki/Planetary_boundaries
# /wiki/Environmental_impact_of_agriculture
# /wiki/Environmental_impact_of_cannabis_cultivation
# /wiki/Environmental_effects_of_irrigation
# /wiki/Environmental_impact_of_meat_production
# /wiki/Environmental_impact_of_cocoa_production
# /wiki/Social_and_environmental_impact_of_palm_oil
# /wiki/Environmental_impact_of_the_energy_industry
# /wiki/Indirect_land_use_change_impacts_of_biofuels
# /wiki/Environmental_impact_of_biodiesel
# /wiki/Environmental_impact_of_the_coal_industry
# /wiki/Environmental_impact_of_nuclear_power
# /wiki/Environmental_impact_of_the_oil_shale_industry
# /wiki/Environmental_impact_of_the_petroleum_industry
# /wiki/Environmental_impact_of_reservoirs
# /wiki/Genetic_pollution
# /wiki/Environmental_crime
# /wiki/Industrialisation
# /wiki/Land_use#Environment
# /wiki/Manufacturing
# /wiki/Environmental_impact_of_cleaning_agents
# /wiki/Environmental_impact_of_concrete
# /wiki/Plastic#Environmental_effects
# /wiki/Impact_of_nanotechnology
# /wiki/Environmental_impact_of_paint
# /wiki/Environmental_impact_of_paper
# /wiki/Environmental_impact_of_pesticides
# /wiki/Environmental_impact_of_pharmaceuticals_and_personal_care_products
# /wiki/Human_impacts_on_marine_life
# /wiki/Environmental_impact_of_fishing
# /wiki/Fishing_down_the_food_web
# /wiki/Marine_pollution
# /wiki/Overfishing
# /wiki/Environmental_impact_of_mining
# /wiki/Overconsumption
# /wiki/Overdrafting
# /wiki/Overexploitation
# /wiki/Overgrazing
# /wiki/Particulates
# /wiki/Pollution
# /wiki/Quarry
# /wiki/Environmental_impact_of_reservoirs
# /wiki/Impacts_of_tourism
# /wiki/Environmental_impact_of_transport
# /wiki/Environmental_impact_of_aviation
# /wiki/Environmental_impact_of_roads
# /wiki/Environmental_impact_of_shipping
# /wiki/Urbanization
# /wiki/Urban_sprawl
# /wiki/Environmental_impact_of_war
# /wiki/Biodiversity_threats
# /wiki/Biodiversity_loss
# /wiki/Decline_in_amphibian_populations
# /wiki/Decline_in_insect_populations
# /wiki/Climate_change
# /wiki/Runaway_climate_change
# /wiki/Environmental_issues_with_coral_reefs
# /wiki/Deforestation
# /wiki/Defaunation
# /wiki/Desertification
# /wiki/Ecocide
# /wiki/Erosion
# /wiki/Environmental_degradation
# /wiki/Freshwater_cycle
# /wiki/Habitat_destruction
# /wiki/Holocene_extinction
# /wiki/Human_impact_on_the_nitrogen_cycle
# /wiki/Land_degradation
# /wiki/Land_consumption
# /wiki/Land_surface_effects_on_climate
# /wiki/Green_belt
# /wiki/Phosphorus_cycle#Human_influences
# /wiki/Ocean_acidification#Possible_impacts
# /wiki/Ozone_depletion
# /wiki/Resource_depletion
# /wiki/Water_degradation
# /wiki/Water_scarcity
# /wiki/Alternative_fuel_vehicle
# /wiki/Birth_control
# /wiki/Cleaner_production
# /wiki/Climate_change_mitigation
# /wiki/Climate_engineering
# /wiki/Community_resilience
# /wiki/Eco-economic_decoupling
# /wiki/Ecological_engineering
# /wiki/Environmental_engineering
# /wiki/Environmental_mitigation
# /wiki/Industrial_ecology
# /wiki/Mitigation_banking
# /wiki/Organic_farming
# /wiki/Recycling
# /wiki/Reforestation
# /wiki/Urban_reforestation
# /wiki/Restoration_ecology
# /wiki/Sustainable_consumption
# /wiki/Waste_minimisation
# https://commons.wikimedia.org/wiki/Category:Environmental_impact
# /wiki/Category:Environmental_impact_by_source
# /wiki/Category:Environmental_impact_by_country
# /wiki/Category:Environmental_impact_assessment
# /wiki/Category:Environmental_mitigation
# /wiki/Template:Lists_of_countries_by_population_statistics
# /wiki/Template_talk:Lists_of_countries_by_population_statistics
# https://en.wikipedia.org/w/index.php?title=Template:Lists_of_countries_by_population_statistics&action=edit
# /wiki/Lists_of_countries_and_territories
# /wiki/Demographic_statistics
# /wiki/List_of_countries_and_dependencies_by_population
# /wiki/Demographics_of_the_world
# /wiki/List_of_continents_and_continental_subregions_by_population
# /wiki/List_of_African_countries_by_population
# /wiki/Demographics_of_Antarctica
# /wiki/List_of_Asian_countries_by_population
# /wiki/List_of_European_countries_by_population
# /wiki/List_of_North_American_countries_by_population
# /wiki/List_of_Caribbean_countries_by_population
# /wiki/List_of_Oceanian_countries_by_population
# /wiki/List_of_South_American_countries_by_population
# /wiki/List_of_countries_in_the_Americas_by_population
# /wiki/List_of_Arab_countries_by_population
# /wiki/List_of_member_states_of_the_Commonwealth_of_Nations_by_population
# /wiki/List_of_Eurasian_countries_by_population
# ...
# /wiki/List_of_countries_by_urban_population
# /wiki/Urbanization_by_country
# /wiki/Health
# /wiki/List_of_countries_by_antidepressant_consumption
# /wiki/Stockpiling_antiviral_medications_for_pandemic_influenza
# /wiki/List_of_countries_by_HIV/AIDS_adult_prevalence_rate
# /wiki/List_of_countries_by_infant_and_under-five_mortality_rates
# /wiki/List_of_countries_by_maternal_mortality_ratio
# /wiki/List_of_countries_by_life_expectancy
# /wiki/List_of_countries_by_obesity_rate
# /wiki/List_of_countries_by_past_life_expectancy
# /wiki/List_of_countries_by_percentage_of_population_suffering_from_undernourishment
# /wiki/List_of_OECD_health_expenditure_by_country_by_type_of_financing
# /wiki/List_of_countries_by_suicide_rate
# /wiki/List_of_countries_by_total_health_expenditure_per_capita
# /wiki/List_of_countries_by_body_mass_index
# /wiki/Bloomberg_Innovation_Index
# /wiki/Education_Index
# /wiki/International_Innovation_Index
# /wiki/List_of_countries_by_literacy_rate
# /wiki/Programme_for_International_Student_Assessment
# /wiki/Programme_for_the_International_Assessment_of_Adult_Competencies
# /wiki/Progress_in_International_Reading_Literacy_Study
# /wiki/List_of_countries_by_student_skills
# /wiki/List_of_countries_by_tertiary_education_attainment
# /wiki/Trends_in_International_Mathematics_and_Science_Study
# /wiki/World_Intellectual_Property_Indicators
# /wiki/Demographic_economics
# /wiki/List_of_countries_by_share_of_population_with_access_to_financial_services
# /wiki/List_of_development_aid_country_donors
# /wiki/List_of_countries_by_Official_Development_Assistance_received
# /wiki/List_of_countries_by_employment_rate
# /wiki/List_of_countries_by_irrigated_land_area
# /wiki/Human_Development_Index
# /wiki/List_of_countries_by_Human_Development_Index
# /wiki/List_of_countries_by_inequality-adjusted_HDI
# /wiki/List_of_countries_by_planetary_pressures%E2%80%93adjusted_HDI
# /wiki/Human_Poverty_Index
# /wiki/List_of_countries_by_imports
# /wiki/List_of_countries_by_income_equality
# /wiki/List_of_countries_by_labour_force
# /wiki/List_of_countries_by_share_of_income_of_the_richest_one_percent
# /wiki/List_of_countries_by_the_number_of_millionaires
# /wiki/List_of_countries_by_the_number_of_billionaires
# /wiki/List_of_countries_by_percentage_of_population_living_in_poverty
# /wiki/List_of_countries_by_public_sector
# /wiki/List_of_countries_by_unemployment_rate
# /wiki/List_of_international_rankings
# /wiki/Lists_by_country
# /wiki/Template:Biological_organisation
# /wiki/Template_talk:Biological_organisation
# https://en.wikipedia.org/w/index.php?title=Template:Biological_organisation&action=edit
# /wiki/Biological_organisation
# /wiki/Biosphere
# /wiki/Biome
# /wiki/Ecosystem
# /wiki/Biocenosis
# /wiki/Population
# /wiki/Organism
# /wiki/Biological_system
# /wiki/Organ_(anatomy)
# /wiki/Tissue_(biology)
# /wiki/Cell_(biology)
# /wiki/Organelle
# /wiki/Macromolecular_assembly
# /wiki/Macromolecule
# /wiki/Biomolecule
# /wiki/Template:Globalization
# /wiki/Template_talk:Globalization
# https://en.wikipedia.org/w/index.php?title=Template:Globalization&action=edit
# /wiki/Globalization
# /wiki/List_of_globalization-related_journals
# /wiki/Outline_of_globalization
# /wiki/Global_studies
# /wiki/Alter-globalization
# /wiki/Anti-globalization_movement
# /wiki/Cultural_globalization
# /wiki/Deglobalization
# /wiki/Democratic_globalization
# /wiki/Economic_globalization
# /wiki/Environmental_globalization
# /wiki/Global_financial_system
# /wiki/Global_citizenship
# /wiki/Global_citizenship_education
# /wiki/Global_governance
# /wiki/Global_politics
# /wiki/Global_health
# /wiki/Globality
# /wiki/History_of_globalization
# /wiki/Archaic_globalization
# /wiki/Proto-globalization
# /wiki/Military_globalization
# /wiki/Political_globalization
# /wiki/Trade_globalization
# /wiki/Global_workforce
# /wiki/Climate_change
# /wiki/Climate_justice
# /wiki/Globalization_and_disease
# /wiki/COVID-19_pandemic
# /wiki/Global_digital_divide
# /wiki/Global_labor_arbitrage
# /wiki/Tax_haven
# /wiki/Offshore_financial_centre
# /wiki/Tax_inversion
# /wiki/Water_security
# /wiki/Human_capital_flight
# /wiki/Reverse_brain_drain
# /wiki/Care_drain
# /wiki/Development_aid
# /wiki/Economic_inequality
# /wiki/Endangered_language
# /wiki/Fair_trade
# /wiki/Forced_displacement
# /wiki/Human_rights
# /wiki/Illicit_financial_flows
# /wiki/Imperialism
# /wiki/Academic_imperialism
# /wiki/Cultural_imperialism
# /wiki/Linguistic_imperialism
# /wiki/Media_imperialism
# /wiki/Scientific_imperialism
# /wiki/Social_imperialism
# /wiki/Invasive_species
# /wiki/Investor-state_dispute_settlement
# /wiki/McDonaldization
# /wiki/New_international_division_of_labour
# /wiki/North%E2%80%93South_divide_in_the_World
# /wiki/Offshoring
# /wiki/Race_to_the_bottom
# /wiki/Pollution_haven_hypothesis
# /wiki/Transnational_organized_crime
# /wiki/Westernization
# /wiki/World_war
# /wiki/Capital_accumulation
# /wiki/Dependency_theory
# /wiki/Development_theory
# /wiki/Earth_system_science
# /wiki/Fiscal_localism
# /wiki/Modernization_theory
# /wiki/Ecological_modernization
# /wiki/History_of_modernisation_theory
# /wiki/Primitive_accumulation_of_capital
# /wiki/Social_change
# /wiki/World_history
# /wiki/World-systems_theory
# /wiki/David_Autor
# /wiki/Richard_Baldwin_(economist)
# /wiki/Ravi_Batra
# /wiki/Jagdish_Bhagwati
# /wiki/Robert_Brenner
# /wiki/Jayati_Ghosh
# /wiki/Michael_Hudson_(economist)
# /wiki/Branko_Milanovi%C4%87
# /wiki/Kevin_O%27Rourke
# /wiki/Thomas_Piketty
# /wiki/Dani_Rodrik
# /wiki/Jeffrey_Sachs
# /wiki/Amartya_Sen
# /wiki/Joseph_Stiglitz
# /wiki/Samir_Amin
# /wiki/Giovanni_Arrighi
# /wiki/Robert_W._Cox
# /wiki/Andre_Gunder_Frank
# /wiki/Stephen_Gill_(political_scientist)
# /wiki/Peter_Gowan
# /wiki/David_Harvey
# /wiki/Ronen_Palan
# /wiki/Susan_Strange
# /wiki/Robert_Wade_(scholar)
# /wiki/Arjun_Appadurai
# /wiki/Daniele_Archibugi
# /wiki/Kwame_Anthony_Appiah
# /wiki/Ulrich_Beck
# /wiki/Walden_Bello
# /wiki/Jean_Baudrillard
# /wiki/Zygmunt_Bauman
# /wiki/Manuel_Castells
# /wiki/Christopher_Chase-Dunn
# /wiki/Alfred_W._Crosby
# /wiki/Nancy_Fraser
# /wiki/Susan_George_(political_scientist)
# /wiki/Anthony_Giddens
# /wiki/Michael_Hardt
# /wiki/David_Held
# /wiki/Paul_Hirst
# /wiki/L._H._M._Ling
# /wiki/Antonio_Negri
# /wiki/George_Ritzer
# /wiki/Saskia_Sassen
# /wiki/John_Urry_(sociologist)
# /wiki/Immanuel_Wallerstein
# /wiki/Noam_Chomsky
# /wiki/Thomas_Friedman
# /wiki/Naomi_Klein
# /wiki/John_Ralston_Saul
# /wiki/Vandana_Shiva
# /wiki/Category:Globalization
# /wiki/File:Emblem-money.svg
# /wiki/Portal:Business
# /wiki/Help:Authority_control
# https://www.wikidata.org/wiki/Q11188#identifiers
# https://d-nb.info/gnd/4125901-4
# https://en.wikipedia.org/w/index.php?title=World_population&oldid=1090171612
# /wiki/Help:Category
# /wiki/Category:World_population
# /wiki/Category:Cultural_globalization
# /wiki/Category:Human_overpopulation
# /wiki/Category:Pages_with_non-numeric_formatnum_arguments
# /wiki/Category:CS1_maint:_url-status
# /wiki/Category:Webarchive_template_wayback_links
# /wiki/Category:Articles_with_short_description
# /wiki/Category:Short_description_matches_Wikidata
# /wiki/Category:Wikipedia_indefinitely_semi-protected_pages
# /wiki/Category:Use_dmy_dates_from_October_2020
# /wiki/Category:Articles_containing_potentially_dated_statements_from_November_2021
# /wiki/Category:All_articles_containing_potentially_dated_statements
# /wiki/Category:Wikipedia_articles_in_need_of_updating_from_January_2022
# /wiki/Category:All_Wikipedia_articles_in_need_of_updating
# /wiki/Category:All_articles_with_unsourced_statements
# /wiki/Category:Articles_with_unsourced_statements_from_September_2014
# /wiki/Category:Articles_needing_additional_references_from_April_2020
# /wiki/Category:All_articles_needing_additional_references
# /wiki/Category:Articles_with_unsourced_statements_from_May_2022
# /wiki/Category:Commons_category_link_is_on_Wikidata
# /wiki/Category:Articles_with_GND_identifiers
# /wiki/Category:Pages_using_the_Graph_extension
# /wiki/Special:MyTalk
# /wiki/Special:MyContributions
# /w/index.php?title=Special:CreateAccount&returnto=World+population
# /w/index.php?title=Special:UserLogin&returnto=World+population
# /wiki/World_population
# /wiki/Talk:World_population
# /wiki/World_population
# /w/index.php?title=World_population&action=edit
# /w/index.php?title=World_population&action=history
# /wiki/Main_Page
# /wiki/Main_Page
# /wiki/Wikipedia:Contents
# /wiki/Portal:Current_events
# /wiki/Special:Random
# /wiki/Wikipedia:About
# //en.wikipedia.org/wiki/Wikipedia:Contact_us
# https://donate.wikimedia.org/wiki/Special:FundraiserRedirector?utm_source=donate&utm_medium=sidebar&utm_campaign=C13_en.wikipedia.org&uselang=en
# /wiki/Help:Contents
# /wiki/Help:Introduction
# /wiki/Wikipedia:Community_portal
# /wiki/Special:RecentChanges
# /wiki/Wikipedia:File_Upload_Wizard
# /wiki/Special:WhatLinksHere/World_population
# /wiki/Special:RecentChangesLinked/World_population
# /wiki/Wikipedia:File_Upload_Wizard
# /wiki/Special:SpecialPages
# /w/index.php?title=World_population&oldid=1090171612
# /w/index.php?title=World_population&action=info
# /w/index.php?title=Special:CiteThisPage&page=World_population&id=1090171612&wpFormIdentifier=titleform
# https://www.wikidata.org/wiki/Special:EntityPage/Q11188
# /w/index.php?title=Special:DownloadAsPdf&page=World_population&action=show-download-screen
# /w/index.php?title=World_population&printable=yes
# https://commons.wikimedia.org/wiki/Category:World_population_statistics
# https://am.wikipedia.org/wiki/%E1%8B%A8%E1%8B%93%E1%88%88%E1%88%9D_%E1%8B%A8%E1%88%85%E1%8B%9D%E1%89%A5_%E1%89%A5%E1%8B%9B%E1%89%B5
# https://ar.wikipedia.org/wiki/%D8%AA%D8%B9%D8%AF%D8%A7%D8%AF_%D8%A7%D9%84%D8%B3%D9%83%D8%A7%D9%86_%D9%81%D9%8A_%D8%A7%D9%84%D8%B9%D8%A7%D9%84%D9%85
# https://ast.wikipedia.org/wiki/Poblaci%C3%B3n_mundial
# https://az.wikipedia.org/wiki/D%C3%BCnya_%C9%99halisi
# https://be.wikipedia.org/wiki/%D0%9D%D0%B0%D1%81%D0%B5%D0%BB%
# https://so.wikipedia.org/wiki/Bulshada_aduunka
# https://ckb.wikipedia.org/wiki/%D8%AF%D8%A7%D9%86%DB%8C%D8%B4%D8%AA%D9%88%D9%88%D8%A7%D9%86%DB%8C_%D8%AC%DB%8C%DA%BE%D8%A7%D9%86
# https://sr.wikipedia.org/wiki/%D0%A1%D0%B2%D0%B5%D1%82%D1%81%D0%BA%D0%B0_%D0%BF%D0%BE%D0%BF%D1%83%D0%BB%D0%B0%D1%86%D0%B8%D1%98%D0%B0
# https://sh.wikipedia.org/wiki/Svjetsko_stanovni%C5%A1tvo
# https://fi.wikipedia.org/wiki/Maailman_v%C3%A4kiluku
# https://sv.wikipedia.org/wiki/V%C3%A4rldens_befolkning
# https://ta.wikipedia.org/wiki/%E0%AE%89%E0%AE%B2%E0%AE%95_%E0%AE%AE%E0%AE%95%E0%AF%8D%E0%AE%95%E0%AE%B3%E0%AF%8D_%E0%AE%A4%E0%AF%8A%E0%AE%95%E0%AF%88
# https://th.wikipedia.org/wiki/%E0%B8%9B%E0%B8%A3%E0%B8%B0%E0%B8%8A%E0%B8%B2%E0%B8%81%E0%B8%A3%E0%B9%82%E0%B8%A5%E0%B8%81
# https://tg.wikipedia.org/wiki/%D0%90%D2%B3%D0%BE%D0%BB%D0%B8%D0%B8_%D0%97%D0%B0%D0%BC%D0%B8%D0%BD
# https://tr.wikipedia.org/wiki/D%C3%BCnya_n%C3%BCfusu
# https://uk.wikipedia.org/wiki/%D0%9D%D0%B0%D1%81%D0%B5%D0%BB%D0%B5%D0%BD%D0%BD%D1%8F_%D0%97%D0%B5%D0%BC%D0%BB%D1%96
# https://ur.wikipedia.org/wiki/%D8%B9%D8%A7%D9%84%D9%85%DB%8C_%D8%A2%D8%A8%D8%A7%D8%AF%DB%8C
# https://vi.wikipedia.org/wiki/D%C3%A2n_s%E1%BB%91_th%E1%BA%BF_gi%E1%BB%9Bi
# https://wuu.wikipedia.org/wiki/%E4%B8%96%E7%95%8C%E4%BA%BA%E5%8F%A3
# https://zh-yue.wikipedia.org/wiki/%E4%B8%96%E7%95%8C%E4%BA%BA%E5%8F%A3
# https://zh.wikipedia.org/wiki/%E4%B8%96%E7%95%8C%E4%BA%BA%E5%8F%A3
# https://www.wikidata.org/wiki/Special:EntityPage/Q11188#sitelinks-wikipedia
# //en.wikipedia.org/wiki/Wikipedia:Text_of_Creative_Commons_Attribution-ShareAlike_3.0_Unported_License
# //creativecommons.org/licenses/by-sa/3.0/
# //foundation.wikimedia.org/wiki/Terms_of_Use
# //foundation.wikimedia.org/wiki/Privacy_policy
# //www.wikimediafoundation.org/
# https://foundation.wikimedia.org/wiki/Privacy_policy
# /wiki/Wikipedia:About
# /wiki/Wikipedia:General_disclaimer
# //en.wikipedia.org/wiki/Wikipedia:Contact_us
# //en.m.wikipedia.org/w/index.php?title=World_population&mobileaction=toggle_view_mobile
# https://www.mediawiki.org/wiki/Special:MyLanguage/How_to_contribute
# https://stats.wikimedia.org/#/en.wikipedia.org
# https://foundation.wikimedia.org/wiki/Cookie_statement
# https://wikimediafoundation.org/
# https://www.mediawiki.org/

# %%
for link in soup.find_all('img'):# in html image is represented by the tag <img>
    print(link)
    print(link.get('src'))
# Out:
# <img alt="Page semi-protected" data-file-height="512" data-file-width="512" decoding="async" height="20" src="//upload.wikimedia.org/wikipedia/en/thumb/1/1b/Semi-protection-shackle.svg/20px-Semi-protection-shackle.svg.png" srcset="//upload.wikimedia.org/wikipedia/en/thumb/1/1b/Semi-protection-shackle.svg/30px-Semi-protection-shackle.svg.png 1.5x, //upload.wikimedia.org/wikipedia/en/thumb/1/1b/Semi-protection-shackle.svg/40px-Semi-protection-shackle.svg.png 2x" width="20"/>
# //upload.wikimedia.org/wikipedia/en/thumb/1/1b/Semi-protection-shackle.svg/20px-Semi-protection-shackle.svg.png
# <img alt="World population growth from 10,000 BCE to 2021" class="thumbimage" data-file-height="2400" data-file-width="3400" decoding="async" height="155" src="//upload.wikimedia.org/wikipedia/commons/thumb/8/85/World-population-1750-2015-and-un-projection-until-2100.png/220px-World-population-1750-2015-and-un-projection-until-2100.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/8/85/World-population-1750-2015-and-un-projection-until-2100.png/330px-World-population-1750-2015-and-un-projection-until-2100.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/8/85/World-population-1750-2015-and-un-projection-until-2100.png/440px-World-population-1750-2015-and-un-projection-until-2100.png 2x" width="220"/>
# //upload.wikimedia.org/wikipedia/commons/thumb/8/85/World-population-1750-2015-and-un-projection-until-2100.png/220px-World-population-1750-2015-and-un-projection-until-2100.png
# <img alt="" class="thumbimage" data-file-height="731" data-file-width="975" decoding="async" height="165" src="//upload.wikimedia.org/wikipedia/commons/thumb/e/e5/World_Population_Prospects_2019.png/220px-World_Population_Prospects_2019.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/e/e5/World_Population_Prospects_2019.png/330px-World_Population_Prospects_2019.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/e/e5/World_Population_Prospects_2019.png/440px-World_Population_Prospects_2019.png 2x" width="220"/>
# //upload.wikimedia.org/wikipedia/commons/thumb
data-file-height="399" data-file-width="512" decoding="async" height="39" src="//upload.wikimedia.org/wikipedia/en/thumb/9/99/Question_book-new.svg/50px-Question_book-new.svg.png" srcset="//upload.wikimedia.org/wikipedia/en/thumb/9/99/Question_book-new.svg/75px-Question_book-new.svg.png 1.5x, //upload.wikimedia.org/wikipedia/en/thumb/9/99/Question_book-new.svg/100px-Question_book-new.svg.png 2x" width="50"/>
# //upload.wikimedia.org/wikipedia/en/thumb/9/99/Question_book-new.svg/50px-Question_book-new.svg.png
# <img alt="{\displaystyle N={\frac {C}{\tau }}\operatorname {arccot} {\frac {T_{0}-T}{\tau }},}" aria-hidden="true" class="mwe-math-fallback-image-inline" src="https://wikimedia.org/api/rest_v1/media/math/render/svg/5343454561d001d6d023b1aa36f88b54febb1349" style="vertical-align: -1.838ex; width:23.116ex; height:5.343ex;"/>
# https://wikimedia.org/api/rest_v1/media/math/render/svg/5343454561d001d6d023b1aa36f88b54febb1349
# <img alt="\tau " aria-hidden="true" class="mwe-math-fallback-image-inline" src="https://wikimedia.org/api/rest_v1/media/math/render/svg/38a7dcde9730ef0853809fefc18d88771f95206c" style="vertical-align: -0.338ex; width:1.202ex; height:1.676ex;"/>
# https://wikimedia.org/api/rest_v1/media/math/render/svg/38a7dcde9730ef0853809fefc18d88771f95206c
# <img alt="" class="thumbimage" data-file-height="700" data-file-width="950" decoding="async" height="221" src="//upload.wikimedia.org/wikipedia/commons/thumb/1/18/Population-doubling.svg/300px-Population-doubling.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/1/18/Population-doubling.svg/450px-Population-doubling.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/1/18/Population-doubling.svg/600px-Population-doubling.svg.png 2x" width="300"/>
# //upload.wikimedia.org/wikipedia/commons/thumb/1/18/Population-doubling.svg/300px-Population-doubling.svg.png
# <img alt="" class="noviewer" data-file-height="3002" data-file-width="3000" decoding="async" height="28" src="//upload.wikimedia.org/wikipedia/commons/thumb/9/97/The_Earth_seen_from_Apollo_17.jpg/28px-The_Earth_seen_from_Apollo_17.jpg" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/9/97/The_Earth_seen_from_Apollo_17.jpg/42px-The_Earth_seen_from_Apollo_17.jpg 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/9/97/The_Earth_seen_from_Apollo_17.jpg/56px-The_Earth_seen_from_Apollo_17.jpg 2x" width="28"/>
# //upload.wikimedia.org/wikipedia/commons/thumb/9/97/The_Earth_seen_from_Apollo_17.jpg/28px-The_Earth_seen_from_Apollo_17.jpg
# <img alt="" class="noviewer" data-file-height="1376" data-file-width="1024" decoding="async" height="40" src="//upload.wikimedia.org/wikipedia/en/thumb/4/4a/Commons-logo.svg/30px-Commons-logo.svg.png" srcset="//upload.wikimedia.org/wikipedia/en/thumb/4/4a/Commons-logo.svg/45px-Commons-logo.svg.png 1.5x, //upload.wikimedia.org/wikipedia/en/thumb/4/4a/Commons-logo.svg/59px-Commons-logo.svg.png 2x" width="30"/>
# //upload.wikimedia.org/wikipedia/en/thumb/4/4a/Commons-logo.svg/30px-Commons-logo.svg.png
# <img alt="" class="noviewer" data-file-height="1376" data-file-width="1024" decoding="async" height="16" src="//upload.wikimedia.org/wikipedia/en/thumb/4/4a/Commons-logo.svg/12px-Commons-logo.svg.png" srcset="//upload.wikimedia.org/wikipedia/en/thumb/4/4a/Commons-logo.svg/18px-Commons-logo.svg.png 1.5x, //upload.wikimedia.org/wikipedia/en/thumb/4/4a/Commons-logo.svg/24px-Commons-logo.svg.png 2x" title="Commons page" width="12"/>
# //upload.wikimedia.org/wikipedia/en/thumb/4/4a/Commons-logo.svg/12px-Commons-logo.svg.png
# <img alt="" class="noviewer" data-file-height="185" data-file-width="180" decoding="async" height="16" src="//upload.wikimedia.org/wikipedia/en/thumb/9/96/Symbol_category_class.svg/16px-Symbol_category_class.svg.png" srcset="//upload.wikimedia.org/wikipedia/en/thumb/9/96/Symbol_category_class.svg/23px-Symbol_category_class.svg.png 1.5x, //upload.wikimedia.org/wikipedia/en/thumb/9/96/Symbol_category_class.svg/31px-Symbol_category_class.svg.png 2x" title="Category" width="16"/>
# //upload.wikimedia.org/wikipedia/en/thumb/9/96/Symbol_category_class.svg/16px-Symbol_category_class.svg.png
# <img alt="" class="noviewer" data-file-height="1376" data-file-width="1024" decoding="async" height="16" src="//upload.wikimedia.org/wikipedia/en/thumb/4/4a/Commons-logo.svg/12px-Commons-logo.svg.png" srcset="//upload.wikimedia.org/wikipedia/en/thumb/4/4a/Commons-logo.svg/18px-Commons-logo.svg.png 1.5x, //upload.wikimedia.org/wikipedia/en/thumb/4/4a/Commons-logo.svg/24px-Commons-logo.svg.png 2x" title="Commons page" width="12"/>
# //upload.wikimedia.org/wikipedia/en/thumb/4/4a/Commons-logo.svg/12px-Commons-logo.svg.png
# <img alt="" class="noviewer" data-file-height="185" data-file-width="180" decoding="async" height="16" src="//upload.wikimedia.org/wikipedia/en/thumb/9/96/Symbol_category_class.svg/16px-Symbol_category_class.svg.png" srcset="//upload.wikimedia.org/wikipedia/en/thumb/9/96/Symbol_category_class.svg/23px-Symbol_category_class.svg.png 1.5x, //upload.wikimedia.org/wikipedia/en/thumb/9/96/Symbol_category_class.svg/31px-Symbol_category_class.svg.png 2x" title="Category" width="16"/>
# //upload.wikimedia.org/wikipedia/en/thumb/9/96/Symbol_category_class.svg/16px-Symbol_category_class.svg.png
# <img alt="" class="noviewer" data-file-height="200" data-file-width="130" decoding="async" height="16" src="//upload.wikimedia.org/wikipedia/commons/thumb/4/41/Global_thinking.svg/10px-Global_thinking.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/4/41/Global_thinking.svg/15px-Global_thinking.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/4/41/Global_thinking.svg/21px-Global_thinking.svg.png 2x" title="Outline" width="10"/>
# //upload.wikimedia.org/wikipedia/commons/thumb/4/41/Global_thinking.svg/10px-Global_thinking.svg.png
# <img alt="" class="noviewer" data-file-height="185" data-file-width="180" decoding="async" height="16" src="//upload.wikimedia.org/wikipedia/en/thumb/9/96/Symbol_category_class.svg/16px-Symbol_category_class.svg.png" srcset="//upload.wikimedia.org/wikipedia/en/thumb/9/96/Symbol_category_class.svg/23px-Symbol_category_class.svg.png 1.5x, //upload.wikimedia.org/wikipedia/en/thumb/9/96/Symbol_category_class.svg/31px-Symbol_category_class.svg.png 2x" title="Category" width="16"/>
# //upload.wikimedia.org/wikipedia/en/thumb/9/96/Symbol_category_class.svg/16px-Symbol_category_class.svg.png
# <img alt="Emblem-money.svg" class="noviewer" data-file-height="48" data-file-width="48" decoding="async" height="28" src="//upload.wikimedia.org/wikipedia/commons/thumb/f/f3/Emblem-money.svg/28px-Emblem-money.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/f/f3/Emblem-money.svg/42px-Emblem-money.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/f/f3/Emblem-money.svg/56px-Emblem-money.svg.png 2x" width="28"/>
# //upload.wikimedia.org/wikipedia/commons/thumb/f/f3/Emblem-money.svg/28px-Emblem-money.svg.png
# <img alt="Edit this at Wikidata" class="noprint" data-file-height="20" data-file-width="20" decoding="async" height="10" src="//upload.wikimedia.org/wikipedia/en/thumb/8/8a/OOjs_UI_icon_edit-ltr-progressive.svg/10px-OOjs_UI_icon_edit-ltr-progressive.svg.png" srcset="//upload.wikimedia.org/wikipedia/en/thumb/8/8a/OOjs_UI_icon_edit-ltr-progressive.svg/15px-OOjs_UI_icon_edit-ltr-progressive.svg.png 1.5x, //upload.wikimedia.org/wikipedia/en/thumb/8/8a/OOjs_UI_icon_edit-ltr-progressive.svg/20px-OOjs_UI_icon_edit-ltr-progressive.svg.png 2x" style="vertical-align: text-top" width="10"/>
# //upload.wikimedia.org/wikipedia/en/thumb/8/8a/OOjs_UI_icon_edit-ltr-progressive.svg/10px-OOjs_UI_icon_edit-ltr-progressive.svg.png
# <img alt="" height="1" src="//en.wikipedia.org/wiki/Special:CentralAutoLogin/start?type=1x1" style="border: none; position: absolute;" title="" width="1"/>
# //en.wikipedia.org/wiki/Special:CentralAutoLogin/start?type=1x1
# <img alt="Wikimedia Foundation" height="31" loading="lazy" src="/static/images/footer/wikimedia-button.png" srcset="/static/images/footer/wikimedia-button-1.5x.png 1.5x, /static/images/footer/wikimedia-button-2x.png 2x" width="88"/>
# /static/images/footer/wikimedia-button.png
# <img alt="Powered by MediaWiki" height="31" loading="lazy" src="/static/images/footer/poweredby_mediawiki_88x31.png" srcset="/static/images/footer/poweredby_mediawiki_132x47.png 1.5x, /static/images/footer/poweredby_mediawiki_176x62.png 2x" width="88"/>
# /static/images/footer/poweredby_mediawiki_88x31.png

# %% [markdown]
# ## Authors

# %% [markdown]
# Ramesh Sannareddy

# %% [markdown]
# ### Other Contributors

# %% [markdown]
# Rav Ahuja

# %% [markdown]
# ## Change Log

# %% [markdown]
# | Date (YYYY-MM-DD) | Version | Changed By                                               | Change Description |
# | ----------------- | ------- | -------------------------------------------------------- | ------------------ |
# | 2021-08-04        | 0.2     | Made changes to markdown of nextsibling                  |                    |
# | 2020-10-17        | 0.1     | Joseph Santarcangelo  Created initial version of the lab |                    |

# %% [markdown]
# Copyright © 2020 IBM Corporation. This notebook and its source code are released under the terms of the [MIT License](https://cognitiveclass.ai/mit-license?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkPY0220ENSkillsNetwork23455606-2021-01-01&cm_mmc=Email_Newsletter-\_-Developer_Ed%2BTech-\_-WW_WW-\_-SkillsNetwork-Courses-IBMDeveloperSkillsNetwork-PY0101EN-SkillsNetwork-19487395&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ).
